# %% [markdown]
# # ZMS  Pitu Case - Julia

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Kiedy-ruina-=-RUINA-?" data-toc-modified-id="Kiedy-ruina-=-RUINA-?-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Kiedy ruina = RUINA ?</a></span></li><li><span><a href="#Weryfikacja-hipotez-i-wyznaczanie-parametrów" data-toc-modified-id="Weryfikacja-hipotez-i-wyznaczanie-parametrów-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Weryfikacja hipotez i wyznaczanie parametrów</a></span></li><li><span><a href="#Wielkość-szkód" data-toc-modified-id="Wielkość-szkód-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Wielkość szkód</a></span></li><li><span><a href="#Model-symulacji" data-toc-modified-id="Model-symulacji-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Model symulacji</a></span></li><li><span><a href="#Symulacja" data-toc-modified-id="Symulacja-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Symulacja</a></span></li><li><span><a href="#Praca" data-toc-modified-id="Raport-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Praca domowa</a></span><ul class="toc-item"><li><span><a href="#Zbadaj-płynność-firmy-w-zależności-od-parametrów" data-toc-modified-id="Zbadaj-płynność-firmy-w-zależności-od-parametrów-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Zbadaj płynność firmy w zależności od parametrów</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Kiedy ruina = RUINA ?
#
# *opr. P. Wojewnik na podstawie:*
#
# *„Optymalizacja portfela szkód” K. Saduś, M. Kwiecień, R. Lipiński* oraz *„Ubezpieczenia komunikacyjne firmy ABC” A. Kołota, M. Mączyńska*
#
#
# Prezes zarządu zakładu ubezpieczeń PiTU S.A., Marcin R., zasłyszał, że Prezydent planuje naturalizować wszystkich chętnych z Dżydżykistanu. *No to teraz się zacznie*, pomyślał, *Dżydżykowie jeżdżą jak wariaci, wzrośnie szkodowość, a więc musimy podnieść dla nich ceny.*
#
# Marcin R. dzwoni do aktuariuszki – Aldony P., ale tu czeka go niespodzianka. *Mój synek zachorował... Grypa to nic wielkiego... Ale w świńskim wydaniu bywa niebezpieczna.* Marcin z bólem serca odsyła Aldonę do domu, a zlecenie dostaje Marek T., asystent Aldony. Pytanie brzmi: **czy składka 500 zł jest wystarczająca ?**
#
# Dotychczasowe doświadczenia PiTU S.A. z Dżydżykami są następujące:
#
# <table>
# <tr></tr>
# <tr><td>
#
# | Liczba szkód    | Liczba polis
# |-----------------|-------------
# | 0               | 3 437
# | 1               | 522
# | 2               | 40
# | 3               | 2
# | 4               | 0
# | 5               | 0
#
# </td><td>
#
# | Wielkość szkody | Liczba szkód
# |-----------------|-------------
# | -               | 0
# | 100             | 0
# | 200             | 2
# | 500             | 27
# | 1 000           | 52
# | 2 000           | 115
# | 5 000           | 203
# | 10 000          | 106
# | 20 000          | 42
# | 40 000          | 14
# | 50 000          | 0
# | 55 000          | 0
# | 60 000          | 1
#
# </td></tr> </table>
#
# Aldona rzuciła jeszcze przez telefon, że **liczbę szkód dobrze opisuje rozkład Poissona**, natomiast **wielkość szkód – rozkład log-normalny**. Z Marcina udało się wydusić **oczekiwaną liczbę klientów – 100** – oraz **aktualną nadwyżkę 10 000**.
#
#
# **Pytania:**
# 1.	Jaką ustalić składkę OC, aby ruina kierowców nie była udziałem PiTU S.A.?
# 2.	Czy nadwyżka końcowa będzie równa początkowej?
# 3.	Jakie jest zagrożenie ruiną?
# 4.	Jaka powinna być nadwyżka i składka, żeby prawdopodobieństwo ruiny było mniejsze niż 0,01?

# %% [markdown]
# ## Weryfikacja hipotez i wyznaczanie parametrów

# %%
import Pkg
Pkg.add("Plots")
# Pkg.update("Plots")
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`

# %%
Pkg.add("PyPlot")
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`

# %%
#import Pkg; Pkg.add("Distributions")

# %%
#import Pkg; Pkg.add("HypothesisTests")
#import Pkg; Pkg.add("Random")

# %%
Pkg.add("DataFrames")
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`

# %%
using Plots
using Distributions
using HypothesisTests
using Random
using DataFrames

# %%
liczba_szkod = Dict(0 => 3437,
                1 => 522,
                2 => 40,
                3 => 2,
                4 => 0, 
                5 => 0);

# %%
# Średnia liczba szkód:
liczba_polis = sum(values(liczba_szkod))
srednia_liczba_szkod = (sum([x * y for (x, y) in liczba_szkod]) / 
                        liczba_polis)

# Czy liczba szkód ma faktycznie rozkład Poissona?
poiss = Poisson(srednia_liczba_szkod)
k = length(liczba_szkod)-1
poisson_test = pdf.(poiss, 0:k) * liczba_polis

bar(liczba_szkod, fillcolor = :blue, legend=false, title= "empiryczna liczba szkód")

# %%
println(srednia_liczba_szkod)
println(pdf.(poiss, 0:k))
println(liczba_szkod)
println([liczba_szkod[i] for i in 0:k])
print(poisson_test)
# Out:
# 0.1519620094976256
# [0.85902091475733, 0.1305385444070124, 0.009918449762492322, 0.0005024091856698595, 1.9086777361114376e-5, 5.80093008525747e-7]
# Dict(0 => 3437, 4 => 0, 5 => 0, 2 => 40, 3 => 2, 1 => 522)
# [3437, 522, 40, 2, 0, 0]
# [3436.9426799440776, 522.2847161724566, 39.68371749973178, 2.0101391518651077, 0.07636619622181862, 0.002320952127111514]

# %%
#ok. 85% osoób bedzie miało 0 wypadków

# %%
#[3437, 522, 40, 2, 0, 0] ->
#[3436.9426799440776, 522.2847161724566, 39.68371749973178, 2.0101391518651077, 0.07636619622181862, 0.002320952127111514] -> prognozy
#rozkład Poisson jest widocznie dobrze dopasowany, ponieważ te liczby zostały wygenerowane z tego rozkładu xd

# %%
bar(0:k, poisson_test, fillcolor = :green, legend = false, title = "teoretyczna liczba szkód")

# %%
# Test chi-kwadrat z biblioteki HypothesisTests pomoże odpowiedziec na pytanie
χ = ChisqTest([liczba_szkod[i] for i in 0:k],poisson_test/sum(poisson_test));
pval = pvalue(χ)
println("p-value=",pval)
if pval > 0.05
    print("Brak podstaw do odrzucenia hipotezy zerowej")
else
    print("Należy odrzucić hipotezę zerową")
end
# Out:
# p-value=0.9999022759058723
# Brak podstaw do odrzucenia hipotezy zerowej

# %% [markdown]
# ## Wielkość szkód

# %%
szkody = [parse(Int,x[2]) for x in split.(readlines("./szkody.txt"), ';')];

# %%
histogram(szkody, xlabel = "Wielkosc szkody", ylabel = "Liczba szkod", legend = false, bins = 100)

# %%
println("Średnia wielkość szkod: ", round(mean(szkody)))
# Out:
# Średnia wielkość szkod: 4742.0

# %%
# Wielkość szkód ma rozkład log-normalny:
szkody_ln = log.(szkody);
histogram(szkody_ln, fillcolor=:khaki, legend = false, bins = 50)

# %%
# ... czy faktycznie? test Kolmogorova-Smirnova - test do sprawdzania czy rozklad normalny
#lepiej uzyc shapiro-wilka
kstest = ExactOneSampleKSTest(szkody_ln, Normal(mean(szkody_ln), std(szkody_ln)))
kspval = pvalue(kstest)
if kspval > 0.05
    println("p-value wyniosło:", kspval, 
           "\nBrak więc podstaw do odrzucenia hipotezy " *
           "o log-normalności rozkładu zmiennej")
else
    println("należy odrzucic hipotezę zerowa")
end
# Out:
# ┌ Warning: This test is inaccurate with ties
# └ @ HypothesisTests ~/.julia/packages/HypothesisTests/zKkJv/src/kolmogorov_smirnov.jl:68
# p-value wyniosło:0.9970804174500004
# Brak więc podstaw do odrzucenia hipotezy o log-normalności rozkładu zmiennej

# %%
#potrzebujemy parametry tego rozkladu na później, z logarytmu tych szkód
#
# Parametry wielkości szkód potrzebne do symulacji:
SR_SZKODA_LN = mean(szkody_ln)
STD_SZKODA_LN = std(szkody_ln);

# %%
LICZBA_POWTORZEN = 100
LICZBA_KLIENTOW = 100 #załozenie do projektu
HORYZONT = 2 # Długość obowiązywania umowy - zakładamy 2 lata #założeni do projektu
# Out:
# 2

# %% [markdown]
# ## Model symulacji

# %%
function model(liczba_klientow::S, 
                srednia_liczba_szkod::T, 
                sr_szkoda_ln::T, 
                std_szkoda_ln::T, 
                horyzont::S, 
                nadwyzka::T, 
                skladka::T;
                seed::S=-1) where {T<:AbstractFloat, S<:Int} #domyślna wartość to -1

    # Common Random Numbers aby móc porównać różne scenariusze:
    seed == -1 || Random.seed!(seed) #-1 nie będzie porównywalnosci, trzeba ustawic inne żeby była powtarzalność
    #|| - OR, czyli albo to jest spełnione, albo to po prawej
    #dobrze ustawić ziarno

    # Definiujemy daty umów klientów w symulacji:
    daty_umow = [rand(1:365) for i in 1:liczba_klientow]
    kalendarz_wplat = zeros(Int,365)
    for dataUmowy in daty_umow
        kalendarz_wplat[dataUmowy] += 1
    end
    # Liczymy liczbę szkód przypadających na jednego klienta:
    liczba_szkod_klienta = rand(Poisson(srednia_liczba_szkod),liczba_klientow)
    
    # Ustalamy daty wypłaty dla wszystkich polis:
    kalendarz_wyplat = zeros(Int,365*horyzont) 
    for k in 1:liczba_klientow
        for s in 1:liczba_szkod_klienta[k]
            data_wyplaty = daty_umow[k] + rand(1:365) #symulujemy 1rok polisy, jeden cykl życia polisy
            kalendarz_wyplat[data_wyplaty] += 1
        end
    end
    
    # Analiza wyników firmy dla danego horyzontu czasowego i danych szkód:
    for dzien in 1:365*horyzont
        dzien ≤ 364 && (nadwyzka += kalendarz_wplat[dzien] * skladka)
        liczba_wyplat = kalendarz_wyplat[dzien]
        odszkodowania = sum(exp.(rand(Normal(sr_szkoda_ln,std_szkoda_ln),liczba_wyplat)))
        nadwyzka -= odszkodowania
        nadwyzka ≤ 0 && return nadwyzka #można zakomentować, wtedy nie trzeba wysokiej nadwyżki ustawiać - tylko mozna komentowac dla 3 podejścia
    end
    return nadwyzka
end
# Out:
# model (generic function with 1 method)

# %%
function wywolanie(nadwyzka::T, skladka::T, liczba_powtorzen::S, 
              liczba_klientow::S, srednia_liczba_szkod::T, 
              sr_szkoda_ln::T, std_szkoda_ln::T, horyzont::S) where {T<:AbstractFloat,S<:Int}
    wynik = []
    for seed in 1:liczba_powtorzen
        push!(wynik, model(liczba_klientow, srednia_liczba_szkod, sr_szkoda_ln, std_szkoda_ln, horyzont, nadwyzka, skladka, seed = seed))
    end

    return (liczba_ruin = sum(wynik.<=0), p_bankructwa = sum(wynik.<0)/liczba_powtorzen, sredni_wynik = mean(wynik[wynik.>0])) #wazne w pkt 3 zeby pozwolic sie kręcic po 0
end
# Out:
# wywolanie (generic function with 2 methods)

# %% [markdown]
# ## Symulacja

# %%
nadwyzka = 10000.0:10000.0:10000.0
skladka = 500.0:100.0:1000.0
# Out:
# 500.0:100.0:1000.0

# %%
# zmienne i parametry w modelu:
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
nadwyzka = 10000.0:10000.0:10000.0
skladka = 500.0:100.0:1000.0

LICZBA_POWTORZEN = 100

for nd in nadwyzka, skl in skladka
    wynik = wywolanie(nd, skl, 
            LICZBA_POWTORZEN, LICZBA_KLIENTOW, 
            srednia_liczba_szkod , SR_SZKODA_LN, 
            STD_SZKODA_LN, HORYZONT)
    push!(liczba_ruin, wynik.liczba_ruin)
    push!(prawd_bankr, wynik.p_bankructwa)
    push!(sr_wynik, wynik.sredni_wynik)
    println("Nadwyzka: ", nd, " Skladka: ", skl, 
              " Liczba ruin: ", wynik.liczba_ruin, " Średni wynik: ",
              round(wynik.sredni_wynik), " Prawd_bankr: ", wynik.p_bankructwa)
end
# Out:
# Nadwyzka: 10000.0 Skladka: 500.0 Liczba ruin: 60 Średni wynik: 15777.0 Prawd_bankr: 0.6
# Nadwyzka: 10000.0 Skladka: 600.0 Liczba ruin: 49 Średni wynik: 21174.0 Prawd_bankr: 0.49
# Nadwyzka: 10000.0 Skladka: 700.0 Liczba ruin: 35 Średni wynik: 25476.0 Prawd_bankr: 0.35
# Nadwyzka: 10000.0 Skladka: 800.0 Liczba ruin: 26 Średni wynik: 31786.0 Prawd_bankr: 0.26
# Nadwyzka: 10000.0 Skladka: 900.0 Liczba ruin: 19 Średni wynik: 38709.0 Prawd_bankr: 0.19
# Nadwyzka: 10000.0 Skladka: 1000.0 Liczba ruin: 12 Średni wynik: 45201.0 Prawd_bankr: 0.12

# %%
#ENV["GKS_ENCODING"] = "utf-8"      

plot(collect(skladka), prawd_bankr, markershape=:circle,
ylabel = "Prawdopodobieństwo bankructwa",
xlabel = "Wysokość składki",
legend = false)

# %% [markdown]
# ## Indywidualna praca domowa
#
# ### Zbadaj płynność firmy w zależności od parametrów
#
# ---
# Udziel proszę odpowiedzi na poniże pytania, uzupełniając komórki Waszym kodem Julii. Zapisz proszę uzupełniony notebook pod nazwą `[SN-ZMS_2_praca_domowa.ipynb` prześlijcie proszę na adres mzawisz@sgh.waw.pl o tytule: __[D-ZMS] 2. praca domowa__ .
#
# __Termin oddania:__ Zgodnie z datą podaną na Teamsach. Każdy rozpoczęty dzień spóźnienia kosztuje 1 punkt mniej.
#
# __Maksymalna liczba punktów do zdobycia:__ 5 punktów
#
# ---
# **Pytania**
# # 1. Jaką ustalić składkę OC, aby prawdopodobieństwo ruiny było mniejsze niż 0,01? (analiza 1 parametru)

# %%
# miejsce na odpowiedź

# %%
#Przeprowadzę analizę wrażliwości jednego parametru – zmieniam wysokość składki i dla każdego robię np. 10k symulacji i sprawdzam
#Definiuję prawdopodobieństwo ruiny jako liczbę symulacji które uderzyły w zero. 
#Nawet gdyby potem wyjdziemy na plus, to jak uderzy w zero to firma w biznesie nie ma możliwości finansowania.

# %%
# zmienne i parametry w modelu:
nadwyzka = 10000.0:10000.0:10000.0
skladka = 500.0:50.0:2000.0
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
LICZBA_POWTORZEN = 100
for nd in nadwyzka, skl in skladka
    wynik = wywolanie(nd, skl, 
            LICZBA_POWTORZEN, LICZBA_KLIENTOW, 
            srednia_liczba_szkod , SR_SZKODA_LN, 
            STD_SZKODA_LN, HORYZONT)
    push!(liczba_ruin, wynik.liczba_ruin)
    push!(prawd_bankr, wynik.p_bankructwa)
    push!(sr_wynik, wynik.sredni_wynik)
    #println("Nadwyzka: ", nd, " Skladka: ", skl, " Liczba ruin: ", wynik.liczba_ruin, " Średni wynik: ",round(wynik.sredni_wynik), " Prawd_bankr: ", wynik.p_bankructwa)
end
p=plot(collect(skladka), prawd_bankr, markershape=:circle, ylabel = "Prawdopodobieństwo bankructwa", xlabel = "Wysokość składki", legend = false)
hline!([0], color=:red, lw=2, linestyle=:dash)
display(p)

# %%
#sprawdzam wyniki symulacji przy większej licznie powtórzeń symulacji
nadwyzka = 10000.0:10000.0:10000.0
skladka = 1000.0:100.0:3000.0
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
LICZBA_POWTORZEN = 100

for nd in nadwyzka, skl in skladka
    wynik = wywolanie(nd, skl, 
            LICZBA_POWTORZEN, LICZBA_KLIENTOW, 
            srednia_liczba_szkod , SR_SZKODA_LN, 
            STD_SZKODA_LN, HORYZONT)
    push!(liczba_ruin, wynik.liczba_ruin)
    push!(prawd_bankr, wynik.p_bankructwa)
    push!(sr_wynik, wynik.sredni_wynik)
    #println("Nadwyzka: ", nd, " Skladka: ", skl, " Liczba ruin: ", wynik.liczba_ruin, " Średni wynik: ",round(wynik.sredni_wynik), " Prawd_bankr: ", wynik.p_bankructwa)
end
p=plot(collect(skladka), prawd_bankr, markershape=:circle, ylabel = "Prawdopodobieństwo bankructwa", xlabel = "Wysokość składki", legend = false)
hline!([0], color=:red, lw=2, linestyle=:dash)
display(p)

# %%
#sprawdzam wyniki symulacji przy większej licznie powtórzeń symulacji
nadwyzka = 10000.0:10000.0:10000.0
skladka = 1000.0:100.0:3000.0
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
LICZBA_POWTORZEN = 100
skladka_koncowa = skladka[1]
for nd in nadwyzka, skl in skladka
    wynik = wywolanie(nd, skl, 
            LICZBA_POWTORZEN, LICZBA_KLIENTOW, 
            srednia_liczba_szkod , SR_SZKODA_LN, 
            STD_SZKODA_LN, HORYZONT)
    push!(liczba_ruin, wynik.liczba_ruin)
    push!(prawd_bankr, wynik.p_bankructwa)
    push!(sr_wynik, wynik.sredni_wynik)
    if wynik.p_bankructwa <= 0.01
        println("Nadwyzka: ", nd, " Skladka: ", skl, " Liczba ruin: ", wynik.liczba_ruin, " Średni wynik: ", round(wynik.sredni_wynik), " Prawd_bankr: ", wynik.p_bankructwa)
        break
    end
    skladka_koncowa = skl
end
skladka = skladka[1]:skladka[2]-skladka[1]:skladka_koncowa+skladka[2]-skladka[1]
p=plot(collect(skladka), prawd_bankr, markershape=:circle, ylabel = "Prawdopodobieństwo bankructwa", xlabel = "Wysokość składki", legend = false)
hline!([0.01], color=:red, lw=2, linestyle=:dash)
display(p)
# Out:
# Nadwyzka: 10000.0 Skladka: 1400.0 Liczba ruin: 1 Średni wynik: 78799.0 Prawd_bankr: 0.01

# %%
#sprawdzam wyniki symulacji przy większej licznie powtórzeń symulacji
nadwyzka = 10000.0:10000.0:10000.0
skladka = 1000.0:50.0:3000.0
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
LICZBA_POWTORZEN = 10000
skladka_koncowa = skladka[1]
for nd in nadwyzka, skl in skladka
    wynik = wywolanie(nd, skl, 
            LICZBA_POWTORZEN, LICZBA_KLIENTOW, 
            srednia_liczba_szkod , SR_SZKODA_LN, 
            STD_SZKODA_LN, HORYZONT)
    push!(liczba_ruin, wynik.liczba_ruin)
    push!(prawd_bankr, wynik.p_bankructwa)
    push!(sr_wynik, wynik.sredni_wynik)
    if wynik.p_bankructwa <= 0.01
        println("Nadwyzka: ", nd, " Skladka: ", skl, " Liczba ruin: ", wynik.liczba_ruin, " Średni wynik: ",round(wynik.sredni_wynik), " Prawd_bankr: ", wynik.p_bankructwa)
        break
    end
    skladka_koncowa = skl
end
skladka = skladka[1]:skladka[2]-skladka[1]:skladka_koncowa+skladka[2]-skladka[1]
p=plot(collect(skladka), prawd_bankr, markershape=:circle, ylabel = "Prawdopodobieństwo bankructwa", xlabel = "Wysokość składki", legend = false)
hline!([0.01], color=:red, lw=2, linestyle=:dash)
display(p)
# Out:
# Nadwyzka: 10000.0 Skladka: 1650.0 Liczba ruin: 99 Średni wynik: 103149.0 Prawd_bankr: 0.0099

# %%
#Dla LICZBA_POWTORZEN = 10000, składka wynosi 1650.0

# %%
#sprawdzam wyniki symulacji przy większej licznie powtórzeń symulacji
nadwyzka = 10000.0:10000.0:10000.0
skladka = 1000.0:50.0:3000.0
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
LICZBA_POWTORZEN = 100000
skladka_koncowa = skladka[1]
for nd in nadwyzka, skl in skladka
    wynik = wywolanie(nd, skl, 
            LICZBA_POWTORZEN, LICZBA_KLIENTOW, 
            srednia_liczba_szkod , SR_SZKODA_LN, 
            STD_SZKODA_LN, HORYZONT)
    push!(liczba_ruin, wynik.liczba_ruin)
    push!(prawd_bankr, wynik.p_bankructwa)
    push!(sr_wynik, wynik.sredni_wynik)
    if wynik.p_bankructwa <= 0.01
        println("Nadwyzka: ", nd, " Skladka: ", skl, " Liczba ruin: ", wynik.liczba_ruin, " Średni wynik: ",round(wynik.sredni_wynik), " Prawd_bankr: ", wynik.p_bankructwa)
        break
    end
    skladka_koncowa = skl
end
skladka = skladka[1]:skladka[2]-skladka[1]:skladka_koncowa+skladka[2]-skladka[1]
p=plot(collect(skladka), prawd_bankr, markershape=:circle, ylabel = "Prawdopodobieństwo bankructwa", xlabel = "Wysokość składki", legend = false)
hline!([0.01], color=:red, lw=2, linestyle=:dash)
display(p)
# Out:
# Nadwyzka: 10000.0 Skladka: 1700.0 Liczba ruin: 874 Średni wynik: 108539.0 Prawd_bankr: 0.00874

# %%
##Dla LICZBA_POWTORZEN = 10000, składka wynosi 1700.0

# %%
#sprawdzam wyniki symulacji przy większej licznie powtórzeń symulacji
nadwyzka = 10000.0:10000.0:10000.0
skladka = 1300.0:50.0:2000.0
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
LICZBA_POWTORZEN = 1000000
skladka_koncowa = skladka[1]
for nd in nadwyzka, skl in skladka
    wynik = wywolanie(nd, skl, 
            LICZBA_POWTORZEN, LICZBA_KLIENTOW, 
            srednia_liczba_szkod , SR_SZKODA_LN, 
            STD_SZKODA_LN, HORYZONT)
    push!(liczba_ruin, wynik.liczba_ruin)
    push!(prawd_bankr, wynik.p_bankructwa)
    push!(sr_wynik, wynik.sredni_wynik)
    if wynik.p_bankructwa <= 0.01
        println("Nadwyzka: ", nd, " Skladka: ", skl, " Liczba ruin: ", wynik.liczba_ruin, " Średni wynik: ",round(wynik.sredni_wynik), " Prawd_bankr: ", wynik.p_bankructwa)
        break
    end
    skladka_koncowa = skl
end
skladka = skladka[1]:skladka[2]-skladka[1]:skladka_koncowa+skladka[2]-skladka[1]
p=plot(collect(skladka), prawd_bankr, markershape=:circle, ylabel = "Prawdopodobieństwo bankructwa", xlabel = "Wysokość składki", legend = false)
hline!([0.01], color=:red, lw=2, linestyle=:dash)
display(p)
# Out:
# Nadwyzka: 10000.0 Skladka: 1650.0 Liczba ruin: 9796 Średni wynik: 103584.0 Prawd_bankr: 0.009796

# %%
#sprawdzam wyniki symulacji przy większej licznie powtórzeń symulacji
nadwyzka = 10000.0:5000.0:20000.0
skladka = 1300.0:50.0:2000.0
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
LICZBA_POWTORZEN = 1000000
skladka_koncowa = skladka[1]
for nd in nadwyzka, skl in skladka
    wynik = wywolanie(nd, skl, 
            LICZBA_POWTORZEN, LICZBA_KLIENTOW, 
            srednia_liczba_szkod , SR_SZKODA_LN, 
            STD_SZKODA_LN, HORYZONT)
    push!(liczba_ruin, wynik.liczba_ruin)
    push!(prawd_bankr, wynik.p_bankructwa)
    push!(sr_wynik, wynik.sredni_wynik)
    if wynik.p_bankructwa <= 0.01
        println("Nadwyzka: ", nd, " Skladka: ", skl, " Liczba ruin: ", wynik.liczba_ruin, " Średni wynik: ",round(wynik.sredni_wynik), " Prawd_bankr: ", wynik.p_bankructwa)
        break
    end
    skladka_koncowa = skl
end
skladka = skladka[1]:skladka[2]-skladka[1]:skladka_koncowa+skladka[2]-skladka[1]
p=plot(collect(skladka), prawd_bankr, markershape=:circle, ylabel = "Prawdopodobieństwo bankructwa", xlabel = "Wysokość składki", legend = false)
hline!([0.01], color=:red, lw=2, linestyle=:dash)
display(p)
# Out:
# Nadwyzka: 10000.0 Skladka: 1650.0 Liczba ruin: 9796 Średni wynik: 103584.0 Prawd_bankr: 0.009796

# %%
#Dla LICZBA_POWTORZEN = 1 000 000, składka wynosi 1650.0

# %%
#sprawdzam wyniki symulacji przy większej licznie powtórzeń symulacji
nadwyzka = 10000.0:10000.0:10000.0
skladka = 1500.0:50.0:1800.0
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
LICZBA_POWTORZEN = 10000000
skladka_koncowa = skladka[1]
for nd in nadwyzka, skl in skladka
    wynik = wywolanie(nd, skl, 
            LICZBA_POWTORZEN, LICZBA_KLIENTOW, 
            srednia_liczba_szkod , SR_SZKODA_LN, 
            STD_SZKODA_LN, HORYZONT)
    push!(liczba_ruin, wynik.liczba_ruin)
    push!(prawd_bankr, wynik.p_bankructwa)
    push!(sr_wynik, wynik.sredni_wynik)
    if wynik.p_bankructwa <= 0.01
        println("Nadwyzka: ", nd, " Skladka: ", skl, " Liczba ruin: ", wynik.liczba_ruin, " Średni wynik: ",round(wynik.sredni_wynik), " Prawd_bankr: ", wynik.p_bankructwa)
        break
    end
    skladka_koncowa = skl
end
skladka = skladka[1]:skladka[2]-skladka[1]:skladka_koncowa+skladka[2]-skladka[1]
p=plot(collect(skladka), prawd_bankr, markershape=:circle, ylabel = "Prawdopodobieństwo bankructwa", xlabel = "Wysokość składki", legend = false)
hline!([0.01], color=:red, lw=2, linestyle=:dash)
display(p)

# %%
#Dla LICZBA_POWTORZEN = 10 000 000, składka wynosi ...

# %% [markdown]
# # 2. Jaka powinna być nadwyżka i składka, żeby prawdopodobieństwo ruiny było mniejsze niż 0,01? (analiza 2 parametrów)

# %%
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`

# %%
#sprawdzam wyniki symulacji przy większej licznie powtórzeń symulacji
nadwyzka = 10000.0:500:20000.0
skladka = 1000.0:100.0:2000.0
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
LICZBA_POWTORZEN = 10000
skladka_koncowa = skladka[1]
df = DataFrame(c_nadwyzka=Float64[], c_skladka=Float64[], c_prawd_ruiny=Float64[])

for nd in nadwyzka, skl in skladka
    wynik = wywolanie(nd, skl, 
            LICZBA_POWTORZEN, LICZBA_KLIENTOW, 
            srednia_liczba_szkod , SR_SZKODA_LN, 
            STD_SZKODA_LN, HORYZONT)
    push!(liczba_ruin, wynik.liczba_ruin)
    push!(prawd_bankr, wynik.p_bankructwa)
    push!(sr_wynik, wynik.sredni_wynik)
    #heatmap_data = combine(groupby(df, []))
    #end
    skladka_koncowa = skl
    push!(df,[nd, skl, wynik.p_bankructwa])
end

# %%
df
# Out:
# 1111×3 DataFrame
#   Row │ c_nadwyzka  c_skladka  c_prawd_ruiny
#       │ Float64     Float64    Float64
# ──────┼──────────────────────────────────────
#     1 │    10000.0     1000.0         0.1095
#     2 │    10000.0     1100.0         0.0713
#     3 │    10000.0     1200.0         0.0455
#     4 │    10000.0     1300.0         0.0309
#     5 │    10000.0     1400.0         0.021
#     6 │    10000.0     1500.0         0.0141
#     7 │    10000.0     1600.0         0.011
#     8 │    10000.0     1700.0         0.0087
#     9 │    10000.0     1800.0         0.0073
#    10 │    10000.0     1900.0         0.0061
#    11 │    10000.0     2000.0         0.005
#   ⋮   │     ⋮           ⋮            ⋮
#  1102 │    20000.0     1100.0         0.0431
#  1103 │    20000.0     1200.0         0.0283
#  1104 │    20000.0     1300.0         0.0187
#  1105 │    20000.0     1400.0         0.0124
#  1106 │    20000.0     1500.0         0.0091
#  1107 │    20000.0     1600.0         0.0066
#  1108 │    20000.0     1700.0         0.0056
#  1109 │    20000.0     1800.0         0.0044
#  1110 │    20000.0     1900.0         0.0034
#  1111 │    20000.0     2000.0         0.0027
#                             1090 rows omitted

# %%
df = combine(groupby(df, [:c_nadwyzka, :c_skladka]), :c_prawd_ruiny => mean)
# Out:
# 1111×3 DataFrame
#   Row │ c_nadwyzka  c_skladka  c_prawd_ruiny_mean
#       │ Float64     Float64    Float64
# ──────┼───────────────────────────────────────────
#     1 │    10000.0     1000.0              0.1095
#     2 │    10000.0     1100.0              0.0713
#     3 │    10000.0     1200.0              0.0455
#     4 │    10000.0     1300.0              0.0309
#     5 │    10000.0     1400.0              0.021
#     6 │    10000.0     1500.0              0.0141
#     7 │    10000.0     1600.0              0.011
#     8 │    10000.0     1700.0              0.0087
#     9 │    10000.0     1800.0              0.0073
#    10 │    10000.0     1900.0              0.0061
#    11 │    10000.0     2000.0              0.005
#   ⋮   │     ⋮           ⋮              ⋮
#  1102 │    20000.0     1100.0              0.0431
#  1103 │    20000.0     1200.0              0.0283
#  1104 │    20000.0     1300.0              0.0187
#  1105 │    20000.0     1400.0              0.0124
#  1106 │    20000.0     1500.0              0.0091
#  1107 │    20000.0     1600.0              0.0066
#  1108 │    20000.0     1700.0              0.0056
#  1109 │    20000.0     1800.0              0.0044
#  1110 │    20000.0     1900.0              0.0034
#  1111 │    20000.0     2000.0              0.0027
#                                  1090 rows omitted

# %%
z_prob
# Out:
# UndefVarError: z_prob not defined

# %%
reshape(z_prob, length(nadwyzka), length(skladka))
# Out:
# UndefVarError: z_prob not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[31]:1

# %%
#df = combine(groupby(df, [:c_nadwyzka, :c_skladka]), :c_prawd_ruiny => mean) 
df
#df = heatmap_data

# nazwy kolumn 
# x_col = :c_nadwyzka 
# y_col = :c_skladka 
# z_col = :c_prawd_ruiny 

x_col = "Nadwyzka"
y_col = "Skladka"
z_col = "Prawd"

# Binning the data 
x_nadwyzka = collect(nadwyzka)
y_skladka = collect(skladka)
z_prob = df.c_prawd_ruiny_mean
mat = reshape(z_prob, length(y_skladka), length(x_nadwyzka)) 

#heatmap(values, orientation=:vertical, xticks=(1:length(values), values), c=:blues, colorbar=false) 

# Plotting the heatmap 
hmap = Plots.heatmap(x_nadwyzka, y_skladka, mat, xticks=x_nadwyzka, xlabel = string(x_col), ylabel = string(y_col), color = :viridis, grid=true, rotation=90)

display(hmap)

# %%
#Dla nadwyzka = 10000.0:500:50000.0 i skladka = 500.0:500.0:2000.0
df
x_col = "Nadwyzka"
y_col = "Skladka"
z_col = "Prawd"

# Binning the data 
x_nadwyzka = collect(nadwyzka)
y_skladka = collect(skladka)
z_prob = df.c_prawd_ruiny_mean
mat = reshape(z_prob, length(y_skladka), length(x_nadwyzka)) 

# Plotting the heatmap 
plot_size = (800, 600)
hmap = Plots.heatmap(x_nadwyzka, y_skladka, mat, xticks=10000.0:500:20000.0, xlabel = string(x_col), ylabel = string(y_col), color = :viridis, grid=true, rotation=90) 
plot!(legend=false, size=plot_size)
#display(hmap)
gdzie_male_prawd_ruiny = findall(x -> x <= 0.01, mat)
# Get the corresponding x and y values for those indices
x_values = y_skladka[[i[1] for i in gdzie_male_prawd_ruiny]]
y_values = x_nadwyzka[[i[2] for i in gdzie_male_prawd_ruiny]]
scatter!(y_values, x_values, color=:red, marker=:circle)

# %%
gdzie_male_prawd_ruiny = findall(x -> x <= 0.01, mat)
# Out:
# 501-element Vector{CartesianIndex{2}}:
#  CartesianIndex(8, 1)
#  CartesianIndex(9, 1)
#  CartesianIndex(10, 1)
#  CartesianIndex(11, 1)
#  CartesianIndex(8, 2)
#  CartesianIndex(9, 2)
#  CartesianIndex(10, 2)
#  CartesianIndex(11, 2)
#  CartesianIndex(8, 3)
#  CartesianIndex(9, 3)
#  CartesianIndex(10, 3)
#  CartesianIndex(11, 3)
#  CartesianIndex(8, 4)
#  ⋮
#  CartesianIndex(6, 100)
#  CartesianIndex(7, 100)
#  CartesianIndex(8, 100)
#  CartesianIndex(9, 100)
#  CartesianIndex(10, 100)
#  CartesianIndex(11, 100)
#  CartesianIndex(6, 101)
#  CartesianIndex(7, 101)
#  CartesianIndex(8, 101)
#  CartesianIndex(9, 101)
#  CartesianIndex(10, 101)
#  CartesianIndex(11, 101)

# %%
# miejsce na odpowiedź

# %% [markdown]
# # 3. Kiedy nadwyżka końcowa będzie równa początkowej? Oszacuj na podstawie modelu regresji.

# %%
function model(liczba_klientow::S, 
                srednia_liczba_szkod::T, 
                sr_szkoda_ln::T, 
                std_szkoda_ln::T, 
                horyzont::S, 
                nadwyzka::T, 
                skladka::T;
                seed::S=-1) where {T<:AbstractFloat, S<:Int} #domyślna wartość to -1

    # Common Random Numbers aby móc porównać różne scenariusze:
    seed == -1 || Random.seed!(seed) #-1 nie będzie porównywalnosci, trzeba ustawic inne żeby była powtarzalność
    #|| - OR, czyli albo to jest spełnione, albo to po prawej
    #dobrze ustawić ziarno

    # Definiujemy daty umów klientów w symulacji:
    daty_umow = [rand(1:365) for i in 1:liczba_klientow]
    kalendarz_wplat = zeros(Int,365)
    for dataUmowy in daty_umow
        kalendarz_wplat[dataUmowy] += 1
    end
    # Liczymy liczbę szkód przypadających na jednego klienta:
    liczba_szkod_klienta = rand(Poisson(srednia_liczba_szkod),liczba_klientow)
    
    # Ustalamy daty wypłaty dla wszystkich polis:
    kalendarz_wyplat = zeros(Int,365*horyzont) 
    for k in 1:liczba_klientow
        for s in 1:liczba_szkod_klienta[k]
            data_wyplaty = daty_umow[k] + rand(1:365) #symulujemy 1rok polisy, jeden cykl życia polisy
            kalendarz_wyplat[data_wyplaty] += 1
        end
    end
    
    # Analiza wyników firmy dla danego horyzontu czasowego i danych szkód:
    for dzien in 1:365*horyzont
        dzien ≤ 364 && (nadwyzka += kalendarz_wplat[dzien] * skladka)
        liczba_wyplat = kalendarz_wyplat[dzien]
        odszkodowania = sum(exp.(rand(Normal(sr_szkoda_ln,std_szkoda_ln),liczba_wyplat)))
        nadwyzka -= odszkodowania
        nadwyzka ≤ 0 && return nadwyzka #można zakomentować, wtedy nie trzeba wysokiej nadwyżki ustawiać - tylko mozna komentowac dla 3 podejścia
    end
    return nadwyzka
end
# Out:
# model (generic function with 1 method)

# %%
function wywolanie(nadwyzka::T, skladka::T, liczba_powtorzen::S, 
              liczba_klientow::S, srednia_liczba_szkod::T, 
              sr_szkoda_ln::T, std_szkoda_ln::T, horyzont::S) where {T<:AbstractFloat,S<:Int}
    wynik = []
    for seed in 1:liczba_powtorzen
        push!(wynik, model(liczba_klientow, srednia_liczba_szkod, sr_szkoda_ln, std_szkoda_ln, horyzont, nadwyzka, skladka, seed = seed))
    end
    #print(wynik)
    return (liczba_ruin = sum(wynik.<=0), p_bankructwa = sum(wynik.<0)/liczba_powtorzen, sredni_wynik = mean(wynik[wynik.>0])) #wazne w pkt 3 zeby pozwolic sie kręcic po 0
end
# Out:
# wywolanie (generic function with 2 methods)

# %%
#sprawdzam wyniki symulacji przy większej licznie powtórzeń symulacji
nadwyzka = 10000.0:10000.0:10000.0
skladka = 1000.0:100.0:2000.0
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
LICZBA_POWTORZEN = 10000
skladka_koncowa = skladka[1]
for nd in nadwyzka, skl in skladka
    wynik = wywolanie(nd, skl, 
            LICZBA_POWTORZEN, LICZBA_KLIENTOW, 
            srednia_liczba_szkod , SR_SZKODA_LN, 
            STD_SZKODA_LN, HORYZONT)
    push!(liczba_ruin, wynik.liczba_ruin)
    push!(prawd_bankr, wynik.p_bankructwa)
    push!(sr_wynik, wynik.sredni_wynik)
    if wynik.p_bankructwa <= 0.01
        println("Nadwyzka: ", nd, " Skladka: ", skl, " Liczba ruin: ", wynik.liczba_ruin, " Średni wynik: ",round(wynik.sredni_wynik), " Prawd_bankr: ", wynik.p_bankructwa)
        break
    end
    skladka_koncowa = skl
end
skladka = skladka[1]:skladka[2]-skladka[1]:skladka_koncowa+skladka[2]-skladka[1]
p=plot(collect(skladka), prawd_bankr, markershape=:circle, ylabel = "Prawdopodobieństwo bankructwa", xlabel = "Wysokość składki", legend = false)
hline!([0.01], color=:red, lw=2, linestyle=:dash)
display(p)
# Out:
# Nadwyzka: 10000.0 Skladka: 1700.0 Liczba ruin: 87 Średni wynik: 108009.0 Prawd_bankr: 0.0087

# %%
nadwyzka = 1000000.0:1000000.0:1000000.0
skladka = 100.0:0.5:50000.0
LICZBA_POWTORZEN = 100
skladka_target = 0.0
for nd in nadwyzka, skl in skladka
    wynik = wywolanie(nd, skl, LICZBA_POWTORZEN, LICZBA_KLIENTOW, srednia_liczba_szkod, SR_SZKODA_LN, STD_SZKODA_LN, HORYZONT)
    if wynik.sredni_wynik > nadwyzka[1]
        #print(wynik.sredni_wynik, nadwyzka[1])
        skladka_target = skl
        #println(skl)
        #break
    end
end
println(skladka_target)
FMCG stands for Fast-Moving Consumer Goods

# %%
#718.5 to minimalna skladka przy ktorej nadwyzka końcowa bedzie rowna koncowej

# %%
# zmienne i parametry w modelu:
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
nadwyzka = 10000.0:10000.0:10000.0
skladka = 500.0:500.0:500.0
LICZBA_POWTORZEN = 100

for nd in nadwyzka, skl in skladka
    wynik = wywolanie(nd, skl, LICZBA_POWTORZEN, LICZBA_KLIENTOW, srednia_liczba_szkod, SR_SZKODA_LN, STD_SZKODA_LN, HORYZONT)
    push!(liczba_ruin, wynik.liczba_ruin)
    push!(prawd_bankr, wynik.p_bankructwa)
    push!(sr_wynik, wynik.sredni_wynik)
    println("Nadwyzka: ", nd, " Skladka: ", skl, " Liczba ruin: ", wynik.liczba_ruin, " Średni wynik: ",round(wynik.sredni_wynik), " Prawd_bankr: ", wynik.p_bankructwa)
end
# Out:
# Any[24567.245154600474, -13760.798696175178, -17423.004524034815, 20870.46993813547, 4221.913502693855, 40253.52818983296, 233.24356572643092, 24738.634768847936, -3948.997019825062, 18799.458279144175, -570.5120173022997, 5932.250431520458, -1908.3389005308018, 8086.404855104046, -2695.0328909623404, -1827.8111859841083, -721.3872295176354, -2196.651410182044, -3264.3852065974443, 2756.029496828909, 19591.39676425859, -3771.213629903058, -4593.175775390442, -13710.07356835927, -8978.622629035615, -1232.9822575465214, 5357.8581050321645, -1170.475638921298, 13915.135630729468, 12040.005571923033, -3220.81490771907, -9883.239088776078, 796.654396067577, -6901.83261776214, -5912.738297945715, 831.253750961863, 28735.174038471898, -50729.838101425965, -1662.7639121136344, -973.2624783076744, -668.376512499317, -24098.570399501736, 10281.753667991958, -15735.13780236918, 5646.387008546775, -7764.08497903074, -204.4396858184664, -1944.6398836555582, 270.6669221634491, 27419.43707816881, -6946.4491982458185, 7853.845386610624, -5036.991600913641, 11582.798310407396, -36.94054895465615, 13935.14426486464, -10663.99075403814, 18642.24827035845, -2516.8522738336615, 23237.78290717454, -11990.291654801134, -4690.0180949725345, -2265.9417430303765, -4918.334626489506, -14291.575357325497, -10855.976719422562, -10134.52930454231, -1150.6021316804472, 30869.71322091687, -7182.515431844973, -8030.347400218248, -3946.011896348733, 30909.759011406575, -1318.3601531393506, -3668.5941055996336, -4960.179315650823, -4148.1215792442545, 17080.69805211825, 27741.76029456844, 12610.87718273154, 34174.87398507049, 14625.370175083177, 4952.954362292401, -5703.932027108878, -12185.145560178456, -16610.560377924314, -15538.318463717169, -1293.5578965942823, 1166.501538031511, 22996.956063934093, -14984.245447765934, 23178.194721154592, 22181.052730309213, 15874.956135965076, 22129.22352375827, -2586.872708990608, -4156.999875937594, -1065.440093403542, -1530.3029489964756, -317.0324097496841]Nadwyzka: 10000.0 Skladka: 500.0 Liczba ruin: 60 Średni wynik: 15777.0 Prawd_bankr: 0.6

# %%
nadwyzka[1]
# Out:
# 10000.0

# %%
# miejsce na odpowiedź

# %% [markdown]
# # 4. Jak liczba symulacji wpływa na wyniki?

# %%
function model(liczba_klientow::S, 
                srednia_liczba_szkod::T, 
                sr_szkoda_ln::T, 
                std_szkoda_ln::T, 
                horyzont::S, 
                nadwyzka::T, 
                skladka::T;
                seed::S=-1) where {T<:AbstractFloat, S<:Int} #domyślna wartość to -1
    
    # Common Random Numbers aby móc porównać różne scenariusze:
    seed == -1 || Random.seed!(seed) #-1 nie będzie porównywalnosci, trzeba ustawic inne żeby była powtarzalność
    #|| - OR, czyli albo to jest spełnione, albo to po prawej
    #dobrze ustawić ziarno

    # Definiujemy daty umów klientów w symulacji:
    daty_umow = [rand(1:365) for i in 1:liczba_klientow]
    kalendarz_wplat = zeros(Int,365)
    for dataUmowy in daty_umow
        kalendarz_wplat[dataUmowy] += 1
    end
    # Liczymy liczbę szkód przypadających na jednego klienta:
    liczba_szkod_klienta = rand(Poisson(srednia_liczba_szkod),liczba_klientow)
    
    # Ustalamy daty wypłaty dla wszystkich polis:
    kalendarz_wyplat = zeros(Int,365*horyzont) 
    for k in 1:liczba_klientow
        for s in 1:liczba_szkod_klienta[k]
            data_wyplaty = daty_umow[k] + rand(1:365) #symulujemy 1rok polisy, jeden cykl życia polisy
            kalendarz_wyplat[data_wyplaty] += 1
        end
    end
    
    # Analiza wyników firmy dla danego horyzontu czasowego i danych szkód:
    for dzien in 1:365*horyzont
        dzien ≤ 364 && (nadwyzka += kalendarz_wplat[dzien] * skladka)
        liczba_wyplat = kalendarz_wyplat[dzien]
        odszkodowania = sum(exp.(rand(Normal(sr_szkoda_ln,std_szkoda_ln),liczba_wyplat)))
        nadwyzka -= odszkodowania
        nadwyzka ≤ 0 && return nadwyzka #można zakomentować, wtedy nie trzeba wysokiej nadwyżki ustawiać - tylko mozna komentowac dla 3 podejścia
    end
    return nadwyzka
end
# Out:
# model (generic function with 1 method)

# %%
function wywolanie(nadwyzka::T, skladka::T, liczba_powtorzen::T, 
              liczba_klientow::S, srednia_liczba_szkod::T, 
              sr_szkoda_ln::T, std_szkoda_ln::T, horyzont::S) where {T<:AbstractFloat,S<:Int}
    wynik = []
    liczba_powtorzen = trunc(Int, liczba_powtorzen)
    for seed in 1:liczba_powtorzen
        push!(wynik, model(liczba_klientow, srednia_liczba_szkod, sr_szkoda_ln, std_szkoda_ln, horyzont, nadwyzka, skladka, seed = seed))
    end
    
    return (liczba_ruin = sum(wynik.<=0), p_bankructwa = sum(wynik.<0)/liczba_powtorzen, 
        sredni_wynik = mean(wynik[wynik.>0]),
        mediana_wynik = median(wynik[wynik.>0]),
        q0_05_wynik = quantile(wynik[wynik.>0], 0.05),
        q0_95_wynik = quantile(wynik[wynik.>0], 0.95)
        ) #wazne w pkt 3 zeby pozwolic sie kręcic po 0
end
# Out:
# wywolanie (generic function with 2 methods)

# %%
#symulacja

LICZBA_KLIENTOW = 100 #załozenie do projektu
HORYZONT = 2 # Długość obowiązywania umowy - zakładamy 2 lata #założeni do projektu
nadwyzka = 10000.0:10000.0:10000.0
skladka = 500.0:500.0:2000.0
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
lower_quants = []
upper_quants = []
medians = []
LICZBA_POWTORZEN = 1.0:50.0:100.0
nd = nadwyzka[1]
skl = skladka[1]
for lp in LICZBA_POWTORZEN
    wynik = wywolanie(nd, skl, lp, LICZBA_KLIENTOW, srednia_liczba_szkod, SR_SZKODA_LN, STD_SZKODA_LN, HORYZONT)
    push!(liczba_ruin, wynik.liczba_ruin)
    push!(prawd_bankr, wynik.p_bankructwa)
    push!(sr_wynik, wynik.sredni_wynik)
    push!(medians, wynik.mediana_wynik)
    push!(lower_quants, wynik.q0_05_wynik)
    push!(upper_quants, wynik.q0_95_wynik)
    #println("Nadwyzka: ", nd, " Skladka: ", skl, " Liczba ruin: ", wynik.liczba_ruin, " Średni wynik: ",round(wynik.sredni_wynik), " Prawd_bankr: ", wynik.p_bankructwa)
end

# %%
using Plots
x_values = LICZBA_POWTORZEN
plot(x_values, upper_quants, title="LICZBA_POWTORZEN: 1 - 100")
plot!(x_values,  medians)
plot!(x_values, lower_quants)
plot!(legend=:bottomright)
xlabel!("Liczba symulacji")
ylabel!("Średni wynik dla firmy bez ruiny")

# %%
#symulacja

LICZBA_KLIENTOW = 100 #załozenie do projektu
HORYZONT = 2 # Długość obowiązywania umowy - zakładamy 2 lata #założeni do projektu
nadwyzka = 10000.0:10000.0:10000.0
skladka = 500.0:500.0:2000.0
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
lower_quants = []
upper_quants = []
medians = []
LICZBA_POWTORZEN = 1.0:50.0:1000.0
nd = nadwyzka[1]
skl = skladka[1]
for lp in LICZBA_POWTORZEN
    wynik = wywolanie(nd, skl, lp, LICZBA_KLIENTOW, srednia_liczba_szkod, SR_SZKODA_LN, STD_SZKODA_LN, HORYZONT)
    push!(liczba_ruin, wynik.liczba_ruin)
    push!(prawd_bankr, wynik.p_bankructwa)
    push!(sr_wynik, wynik.sredni_wynik)
    push!(medians, wynik.mediana_wynik)
    push!(lower_quants, wynik.q0_05_wynik)
    push!(upper_quants, wynik.q0_95_wynik)
    #println("Nadwyzka: ", nd, " Skladka: ", skl, " Liczba ruin: ", wynik.liczba_ruin, " Średni wynik: ",round(wynik.sredni_wynik), " Prawd_bankr: ", wynik.p_bankructwa)
end

# %%
using PyPlot
x_values = LICZBA_POWTORZEN
plot(x_values, [upper_quants, medians, sr_wynik, lower_quants], label=["kwantyl 0.95" "mediana" "srednia" "kwantyl 0.05"],
    title="LICZBA_POWTORZEN: 1 - 1 000", lw = 3)
plot!(legend=:bottomright)
xlabel!("Liczba symulacji")
ylabel!("Średni wynik")
#ticklabel_format(axis="x", style="plain", useOffset=false); 
#display(p)

# %%
#symulacja

LICZBA_KLIENTOW = 100 #załozenie do projektu
HORYZONT = 2 # Długość obowiązywania umowy - zakładamy 2 lata #założeni do projektu
nadwyzka = 10000.0:10000.0:10000.0
skladka = 500.0:500.0:2000.0
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
lower_quants = []
upper_quants = []
medians = []
LICZBA_POWTORZEN = 1.0:50.0:10000.0
nd = nadwyzka[1]
skl = skladka[1]
for lp in LICZBA_POWTORZEN
    wynik = wywolanie(nd, skl, lp, LICZBA_KLIENTOW, srednia_liczba_szkod, SR_SZKODA_LN, STD_SZKODA_LN, HORYZONT)
    push!(liczba_ruin, wynik.liczba_ruin)
    push!(prawd_bankr, wynik.p_bankructwa)
    push!(sr_wynik, wynik.sredni_wynik)
    push!(medians, wynik.mediana_wynik)
    push!(lower_quants, wynik.q0_05_wynik)
    push!(upper_quants, wynik.q0_95_wynik)
    #println("Nadwyzka: ", nd, " Skladka: ", skl, " Liczba ruin: ", wynik.liczba_ruin, " Średni wynik: ",round(wynik.sredni_wynik), " Prawd_bankr: ", wynik.p_bankructwa)
end
#using PyPlot
x_values = LICZBA_POWTORZEN
plot(x_values, [upper_quants, medians, sr_wynik, lower_quants], label=["kwantyl 0.95" "mediana" "srednia" "kwantyl 0.05"],
    title="LICZBA_POWTORZEN: 1 - 10 000")
plot!(legend=:bottomright)
xlabel!("Liczba symulacji")
ylabel!("Średni wynik")
#xlabel("Liczba symulacji")

# %%
#symulacja
LICZBA_KLIENTOW = 100 #załozenie do projektu
HORYZONT = 2 # Długość obowiązywania umowy - zakładamy 2 lata #założeni do projektu
nadwyzka = 10000.0:10000.0:10000.0
skladka = 500.0:500.0:2000.0
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
lower_quants = []
upper_quants = []
medians = []
LICZBA_POWTORZEN = 1.0:50.0:100000.0
nd = nadwyzka[1]
skl = skladka[1]
for lp in LICZBA_POWTORZEN
    wynik = wywolanie(nd, skl, lp, LICZBA_KLIENTOW, srednia_liczba_szkod, SR_SZKODA_LN, STD_SZKODA_LN, HORYZONT)
    push!(liczba_ruin, wynik.liczba_ruin)
    push!(prawd_bankr, wynik.p_bankructwa)
    push!(sr_wynik, wynik.sredni_wynik)
    push!(medians, wynik.mediana_wynik)
    push!(lower_quants, wynik.q0_05_wynik)
    push!(upper_quants, wynik.q0_95_wynik)
    #println("Nadwyzka: ", nd, " Skladka: ", skl, " Liczba ruin: ", wynik.liczba_ruin, " Średni wynik: ",round(wynik.sredni_wynik), " Prawd_bankr: ", wynik.p_bankructwa)
end
#using PyPlot
x_values = LICZBA_POWTORZEN
plot(x_values, [upper_quants, medians, sr_wynik, lower_quants], label=["kwantyl 0.95" "mediana" "srednia" "kwantyl 0.05"],
    title="LICZBA_POWTORZEN: 1 - "*last(LICZBA_POWTORZEN))
plot!(legend=:bottomright)
xlabel!("Liczba symulacji")
ylabel!("Średni wynik")
#xlabel("Liczba symulacji")
# Out:
# InterruptException:
#
# Stacktrace:
#   [1] Array
#     @ ./boot.jl:459 [inlined]
#   [2] Array
#     @ ./boot.jl:468 [inlined]
#   [3] Array
#     @ ./boot.jl:476 [inlined]
#   [4] similar
#     @ ./abstractarray.jl:841 [inlined]
#   [5] similar
#     @ ./abstractarray.jl:840 [inlined]
#   [6] similar
#     @ ./broadcast.jl:212 [inlined]
#   [7] similar
#     @ ./broadcast.jl:211 [inlined]
#   [8] copy
#     @ ./broadcast.jl:885 [inlined]
#   [9] materialize
#     @ ./broadcast.jl:860 [inlined]
#  [10] model(liczba_klientow::Int64, srednia_liczba_szkod::Float64, sr_szkoda_ln::Float64, std_szkoda_ln::Float64, horyzont::Int64, nadwyzka::Float64, skladka::Float64; seed::Int64)
#     @ Main ./In[36]:37
#  [11] wywolanie(nadwyzka::Float64, skladka::Float64, liczba_powtorzen::Float64, liczba_klientow::Int64, srednia_liczba_szkod::Float64, sr_szkoda_ln::Float64, std_szkoda_ln::Float64, horyzont::Int64)
#     @ Main ./In[37]:7
#  [12] top-level scope
#     @ ./In[64]:17

# %%
function wywolanie(nadwyzka::T, skladka::T, liczba_powtorzen::T, 
              liczba_klientow::S, srednia_liczba_szkod::T, 
              sr_szkoda_ln::T, std_szkoda_ln::T, horyzont::S) where {T<:AbstractFloat,S<:Int}
    wynik = []
    liczba_powtorzen = trunc(Int, liczba_powtorzen)
    for seed in 1:liczba_powtorzen
        push!(wynik, model(liczba_klientow, srednia_liczba_szkod, sr_szkoda_ln, std_szkoda_ln, horyzont, nadwyzka, skladka, seed = seed))
    end
    
    return (liczba_ruin = sum(wynik.<=0), p_bankructwa = sum(wynik.<0)/liczba_powtorzen, 
        sredni_wynik = mean(wynik),
        mean_wynik = mean(wynik),
        mediana_wynik = median(wynik),
        q0_05_wynik = quantile(wynik, 0.05),
        q0_95_wynik = quantile(wynik, 0.95)
        ) #wazne w pkt 3 zeby pozwolic sie kręcic po 0
end
# Out:
# wywolanie (generic function with 2 methods)

# %%
LICZBA_SYMULACJI = 10.0:10.0:10000.0
nadwyzka = 10000.0:1000.0:10000.0
skladka = 1000.0:100.0:2000.0
medians = []
means = []
lower_quants = []
upper_quants= []
nd = 10000.0
skl = 1000.0
for ls in LICZBA_SYMULACJI
    wynik = wywolanie(nd, skl, ls, LICZBA_KLIENTOW, srednia_liczba_szkod , SR_SZKODA_LN, STD_SZKODA_LN, HORYZONT)
            #     push!(len, ls)
    push!(means, wynik.mean_wynik)
    push!(medians, wynik.mediana_wynik)
    push!(lower_quants, wynik.q0_05_wynik)
    push!(upper_quants, wynik.q0_95_wynik)
end
# Out:
# InterruptException:
#
# Stacktrace:
#   [1] Array
#     @ ./boot.jl:459 [inlined]
#   [2] Array
#     @ ./boot.jl:468 [inlined]
#   [3] Array
#     @ ./boot.jl:476 [inlined]
#   [4] similar
#     @ ./abstractarray.jl:841 [inlined]
#   [5] similar
#     @ ./abstractarray.jl:840 [inlined]
#   [6] similar
#     @ ./broadcast.jl:212 [inlined]
#   [7] similar
#     @ ./broadcast.jl:211 [inlined]
#   [8] copy
#     @ ./broadcast.jl:885 [inlined]
#   [9] materialize
#     @ ./broadcast.jl:860 [inlined]
#  [10] model(liczba_klientow::Int64, srednia_liczba_szkod::Float64, sr_szkoda_ln::Float64, std_szkoda_ln::Float64, horyzont::Int64, nadwyzka::Float64, skladka::Float64; seed::Int64)
#     @ Main ./In[36]:37
#  [11] wywolanie(nadwyzka::Float64, skladka::Float64, liczba_powtorzen::Float64, liczba_klientow::Int64, srednia_liczba_szkod::Float64, sr_szkoda_ln::Float64, std_szkoda_ln::Float64, horyzont::Int64)
#     @ Main ./In[181]:7
#  [12] top-level scope
#     @ ./In[195]:11

# %%
x_values = LICZBA_SYMULACJI
plot(x_values, [upper_quants, medians, means, lower_quants], label=["kwantyl 0.95" "mediana" "srednia" "kwantyl 0.05"],
    title="LICZBA_POWTORZEN: 10 - 10 000")
plot!(legend=:bottomright)
xlabel!("Liczba symulacji")
ylabel!("Wynik")
#xlabel("Liczba symulacji")

# %%
LICZBA_SYMULACJI = 10.0:10.0:100000.0
nadwyzka = 10000.0:1000.0:10000.0
skladka = 1000.0:100.0:2000.0
medians = []
means = []
lower_quants = []
upper_quants= []
nd = 10000.0
skl = 1000.0
for ls in LICZBA_SYMULACJI
    wynik = wywolanie(nd, skl, ls, LICZBA_KLIENTOW, srednia_liczba_szkod , SR_SZKODA_LN, STD_SZKODA_LN, HORYZONT)
            #     push!(len, ls)
    push!(means, wynik.mean_wynik)
    push!(medians, wynik.mediana_wynik)
    push!(lower_quants, wynik.q0_05_wynik)
    push!(upper_quants, wynik.q0_95_wynik)
end
x_values = LICZBA_SYMULACJI
plot(x_values, [upper_quants, medians, means, lower_quants], label=["kwantyl 0.95" "mediana" "srednia" "kwantyl 0.05"],
    title="LICZBA_POWTORZEN: 10 - 100 000")
plot!(legend=:bottomright)
xlabel!("Liczba symulacji")
ylabel!("Wynik")
#xlabel("Liczba symulacji")
# Out:
# BoundsError: attempt to access 5651-element Vector{Float64} at index [1:10000]
#
# Stacktrace:
#   [1] throw_boundserror(A::Vector{Float64}, I::Tuple{UnitRange{Int64}})
#     @ Base ./abstractarray.jl:703
#   [2] checkbounds
#     @ ./abstractarray.jl:668 [inlined]
#   [3] getindex(A::Vector{Float64}, I::UnitRange{Int64})
#     @ Base ./array.jl:930
#   [4] gr_draw_segments(series::Plots.Series, x::StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, y::Vector{Float64}, z::Nothing, fillrange::Nothing, clims::Tuple{Float64, Float64})
#     @ Plots ~/.julia/packages/Plots/esM5q/src/backends/gr.jl:1825
#   [5] gr_add_series(sp::Plots.Subplot{Plots.GRBackend}, series::Plots.Series)
#     @ Plots ~/.julia/packages/Plots/esM5q/src/backends/gr.jl:1742
#   [6] gr_display(sp::Plots.Subplot{Plots.GRBackend}, w::Measures.AbsoluteLength, h::Measures.AbsoluteLength, vp_canvas::Plots.GRViewport{Float64})
#     @ Plots ~/.julia/packages/Plots/esM5q/src/backends/gr.jl:964
#   [7] (::Plots.var"#534#535"{Int64, Int64, Plots.GRViewport{Float64}})(sp::Plots.Subplot{Plots.GRBackend})
#     @ Plots ~/.julia/packages/Plots/esM5q/src/backends/gr.jl:688
#   [8] foreach(f::Plots.var"#534#535"{Int64, Int64, Plots.GRViewport{Float64}}, itr::Vector{Plots.Subplot})
#     @ Base ./abstractarray.jl:2774
#   [9] gr_display(plt::Plots.Plot{Plots.GRBackend}, dpi_factor::Int64)
#     @ Plots ~/.julia/packages/Plots/esM5q/src/backends/gr.jl:688
#  [10] #577
#     @ ~/.julia/packages/Plots/esM5q/src/backends/gr.jl:2052 [inlined]
#  [11] withenv(::Plots.var"#577#578"{Plots.Plot{Plots.GRBackend}, Int64}, ::Pair{String, String}, ::Vararg{Pair{String, String}})
#     @ Base ./env.jl:172
#  [12] _show(io::IOBuffer, #unused#::MIME{Symbol("image/svg+xml")}, plt::Plots.Plot{Plots.GRBackend})
#     @ Plots ~/.julia/packages/Plots/esM5q/src/backends/gr.jl:2047
#  [13] #invokelatest#2
#     @ ./essentials.jl:729 [inlined]
#  [14] invokelatest
#     @ ./essentials.jl:726 [inlined]
#  [15] show(io::IOBuffer, m::MIME{Symbol("image/svg+xml")}, plt::Plots.Plot{Plots.GRBackend})
#     @ Plots ~/.julia/packages/Plots/esM5q/src/output.jl:232
#  [16] sprint(::Function, ::MIME{Symbol("image/svg+xml")}, ::Vararg{Any}; context::Nothing, sizehint::Int64)
#     @ Base ./strings/io.jl:114
#  [17] sprint
#     @ ./strings/io.jl:107 [inlined]
#  [18] _ijulia_display_dict(plt::Plots.Plot{Plots.GRBackend})
#     @ Plots.IJuliaExt ~/.julia/packages/Plots/esM5q/ext/IJuliaExt.jl:53
#  [19] display_dict(plt::Plots.Plot{Plots.GRBackend})
#     @ Plots.IJuliaExt ~/.julia/packages/Plots/esM5q/ext/IJuliaExt.jl:69
#  [20] #invokelatest#2
#     @ ./essentials.jl:729 [inlined]
#  [21] invokelatest
#     @ ./essentials.jl:726 [inlined]
#  [22] execute_request(socket::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia ~/.julia/packages/IJulia/6TIq1/src/execute_request.jl:112
#  [23] #invokelatest#2
#     @ ./essentials.jl:729 [inlined]
#  [24] invokelatest
#     @ ./essentials.jl:726 [inlined]
#  [25] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/6TIq1/src/eventloop.jl:8
#  [26] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:484

# %%
using Random
using Statistics
using Plots

# Przykładowa funkcja symulacyjna
function simulate(n)
    return [randn() for _ in 1:n]
end

# Liczba symulacji
num_simulations = 10:10:100

# Inicjalizacja wektorów na wyniki
standard_deviations = []
variances = []
ranges = []

# Wykonanie symulacji dla różnych liczb prób
for n in num_simulations
    simulation_data = simulate(n)
    push!(standard_deviations, std(simulation_data))
    push!(variances, var(simulation_data))
    push!(ranges, maximum(simulation_data) - minimum(simulation_data))
end

# Rysowanie wykresu
plot(num_simulations, standard_deviations, label = "Odchylenie standardowe", xlabel = "Liczba symulacji", ylabel = "Rozrzut błędu wartości", color = :blue)
plot!(num_simulations, variances, label = "Wariancja", color = :red)
plot!(num_simulations, ranges, label = "Rozstęp", color = :green)
title!("Rozrzut błędu wartości w zależności od liczby symulacji")

# %%
nadwyzka = 10000.0:10000.0:10000.0
skladka = 1000.0:100.0:2000.0
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
LICZBA_POWTORZEN = 10:10:1000
LICZBA_SYMULACJI = 10.0:100.0:1000.0
skladka_koncowa = skladka[1]
skladka_idealna = []
medians = []
means = []
lower_quants = []
upper_quants= []
len = []
mean_wynik = []
mediana_wynik = []
q0_05_wynik = []
q0_95_wynik = []
for ls in LICZBA_SYMULACJI
    mean_wynik = []
    mediana_wynik = []
    q0_05_wynik = []
    q0_95_wynik = []
    skladka_idealna = []
    for lp in LICZBA_POWTORZEN
        for skl in skladka
            wynik = wywolanie(nd, skl, ls, LICZBA_KLIENTOW, srednia_liczba_szkod , SR_SZKODA_LN, STD_SZKODA_LN, HORYZONT)
            push!(liczba_ruin, wynik.liczba_ruin)
            push!(prawd_bankr, wynik.p_bankructwa)
            push!(sr_wynik, wynik.sredni_wynik)
            
            println("P BANKRUCTWA ", wynik.p_bankructwa, "SKLADKA ", skl)
            if wynik.p_bankructwa <= 0.01
                #println("Nadwyzka: ", nd, " Skladka: ", skl, " Liczba ruin: ", wynik.liczba_ruin, " Średni wynik: ",round(wynik.sredni_wynik), " Prawd_bankr: ", wynik.p_bankructwa)
                push!(skladka_idealna, skl)
                break
            end
            #print(skl)
        end
    end
        
    if length(skladka_idealna) != 0
        mean_wynik = mean(skladka_idealna)
        mediana_wynik = median(skladka_idealna)
        q0_05_wynik = quantile(skladka_idealna, 0.05)
        q0_95_wynik = quantile(skladka_idealna, 0.95)
        println(skladka_idealna)
    end
# if length(mediana_wynik) != 0
#     push!(len, ls)
#     push!(means, mean_wynik)
#     push!(medians, mediana_wynik)
#     push!(lower_quants, q0_05_wynik)
#     push!(upper_quants, q0_95_wynik)
end
# Out:
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.0SKLADKA 1000.0
# P BANKRUCTWA 0.0SKLADKA 1100.0
# P BANKRUCTWA 0.0SKLADKA 1200.0
# P BANKRUCTWA 0.0SKLADKA 1300.0
# P BANKRUCTWA 0.0SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# Any[1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400 ...
# P BANKRUCTWA 0.11818181818181818SKLADKA 1000.0
# P BANKRUCTWA 0.07272727272727272SKLADKA 1100.0
# P BANKRUCTWA 0.03636363636363636SKLADKA 1200.0
# P BANKRUCTWA 0.02727272727272727SKLADKA 1300.0
# P BANKRUCTWA 0.00909090909090909SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.11818181818181818SKLADKA 1000.0
# P BANKRUCTWA 0.07272727272727272SKLADKA 1100.0
# P BANKRUCTWA 0.03636363636363636SKLADKA 1200.0
# P BANKRUCTWA 0.02727272727272727SKLADKA 1300.0
# P BANKRUCTWA 0.00909090909090909SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.11818181818181818SKLADKA 1000.0
# P BANKRUCTWA 0.07272727272727272SKLADKA 1100.0
# P BANKRUCTWA 0.03636363636363636SKLADKA 1200.0
# P BANKRUCTWA 0.02727272727272727SKLADKA 1300.0
# P BANKRUCTWA 0.00909090909090909SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.11818181818181818SKLADKA 1000.0
# P BANKRUCTWA 0.07272727272727272SKLADKA 1100.0
# P BANKRUCTWA 0.03636363636363636SKLADKA 1200.0
# P BANKRUCTWA 0.02727272727272727SKLADKA 1300.0
# P BANKRUCTWA 0.00909090909090909SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.11818181818181818SKLADKA 1000.0
# P BANKRUCTWA 0.07272727272727272SKLADKA 1100.0
# P BANKRUCTWA 0.03636363636363636SKLADKA 1200.0
# P BANKRUCTWA 0.02727272727272727SKLADKA 1300.0
# P BANKRUCTWA 0.00909090909090909SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.11818181818181818SKLADKA 1000.0
# P BANKRUCTWA 0.07272727272727272SKLADKA 1100.0
# P BANKRUCTWA 0.03636363636363636SKLADKA 1200.0
# P BANKRUCTWA 0.02727272727272727SKLADKA 1300.0
# P BANKRUCTWA 0.00909090909090909SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.11818181818181818SKLADKA 1000.0
# P BANKRUCTWA 0.07272727272727272SKLADKA 1100.0
# P BANKRUCTWA 0.03636363636363636SKLADKA 1200.0
# P BANKRUCTWA 0.02727272727272727SKLADKA 1300.0
# P BANKRUCTWA 0.00909090909090909SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.11818181818181818SKLADKA 1000.0
# P BANKRUCTWA 0.07272727272727272SKLADKA 1100.0
# P BANKRUCTWA 0.03636363636363636SKLADKA 1200.0
# P BANKRUCTWA 0.02727272727272727SKLADKA 1300.0
# P BANKRUCTWA 0.00909090909090909SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.11818181818181818SKLADKA 1000.0
# P BANKRUCTWA 0.07272727272727272SKLADKA 1100.0
# P BANKRUCTWA 0.03636363636363636SKLADKA 1200.0
# P BANKRUCTWA 0.02727272727272727SKLADKA 1300.0
# P BANKRUCTWA 0.00909090909090909SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.11818181818181818SKLADKA 1000.0
# P BANKRUCTWA 0.07272727272727272SKLADKA 1100.0
# P BANKRUCTWA 0.03636363636363636SKLADKA 1200.0
# P BANKRUCTWA 0.02727272727272727SKLADKA 1300.0
# P BANKRUCTWA 0.00909090909090909SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.11818181818181818SKLADKA 1000.0
# P BANKRUCTWA 0.07272727272727272SKLADKA 1100.0
# P BANKRUCTWA 0.03636363636363636SKLADKA 1200.0
# P BANKRUCTWA 0.02727272727272727SKLADKA 1300.0
# P BANKRUCTWA 0.00909090909090909SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.11818181818181818SKLADKA 1000.0
# P BANKRUCTWA 0.07272727272727272SKLADKA 1100.0
# P BANKRUCTWA 0.03636363636363636SKLADKA 1200.0
# P BANKRUCTWA 0.02727272727272727SKLADKA 1300.0
# P BANKRUCTWA 0.00909090909090909SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.11818181818181818SKLADKA 1000.0
# P BANKRUCTWA 0.07272727272727272SKLADKA 1100.0
# P BANKRUCTWA 0.03636363636363636SKLADKA 1200.0
# P BANKRUCTWA 0.02727272727272727SKLADKA 1300.0
# P BANKRUCTWA 0.00909090909090909SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.11818181818181818SKLADKA 1000.0
# P BANKRUCTWA 0.07272727272727272SKLADKA 1100.0
# P BANKRUCTWA 0.03636363636363636SKLADKA 1200.0
# P BANKRUCTWA 0.02727272727272727SKLADKA 1300.0
# P BANKRUCTWA 0.00909090909090909SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.11818181818181818SKLADKA 1000.0
# P BANKRUCTWA 0.07272727272727272SKLADKA 1100.0
# P BANKRUCTWA 0.03636363636363636SKLADKA 1200.0
# P BANKRUCTWA 0.02727272727272727SKLADKA 1300.0
# P BANKRUCTWA 0.00909090909090909SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.11818181818181818SKLADKA 1000.0
# P BANKRUCTWA 0.07272727272727272SKLADKA 1100.0
# P BANKRUCTWA 0.03636363636363636SKLADKA 1200.0
# P BANKRUCTWA 0.02727272727272727SKLADKA 1300.0
# P BANKRUCTWA 0.00909090909090909SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.11818181818181818SKLADKA 1000.0
# P BANKRUCTWA 0.07272727272727272SKLADKA 1100.0
# P BANKRUCTWA 0.03636363636363636SKLADKA 1200.0
# P BANKRUCTWA 0.02727272727272727SKLADKA 1300.0
# P BANKRUCTWA 0.00909090909090909SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.11818181818181818SKLADKA 1000.0
# P BANKRUCTWA 0.07272727272727272SKLADKA 1100.0
# P BANKRUCTWA 0.03636363636363636SKLADKA 1200.0
# P BANKRUCTWA 0.02727272727272727SKLADKA 1300.0
# P BANKRUCTWA 0.00909090909090909SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.11818181818181818SKLADKA 1000.0
# P BANKRUCTWA 0.07272727272727272SKLADKA 1100.0
# P BANKRUCTWA 0.03636363636363636SKLADKA 1200.0
# P BANKRUCTWA 0.02727272727272727SKLADKA 1300.0
# P BANKRUCTWA 0.00909090909090909SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.11818181818181818SKLADKA 1000.0
# P BANKRUCTWA 0.07272727272727272SKLADKA 1100.0
# P BANKRUCTWA 0.03636363636363636SKLADKA 1200.0
# P BANKRUCTWA 0.02727272727272727SKLADKA 1300.0
# P BANKRUCTWA 0.00909090909090909SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.11818181818181818SKLADKA 1000.0
# P BANKRUCTWA 0.07272727272727272SKLADKA 1100.0
# P BANKRUCTWA 0.03636363636363636SKLADKA 1200.0
# P BANKRUCTWA 0.02727272727272727SKLADKA 1300.0
# P BANKRUCTWA 0.00909090909090909SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.11818181818181818SKLADKA 1000.0
# P BANKRUCTWA 0.07272727272727272SKLADKA 1100.0
# P BANKRUCTWA 0.03636363636363636SKLADKA 1200.0
# P BANKRUCTWA 0.02727272727272727SKLADKA 1300.0
# P BANKRUCTWA 0.00909090909090909SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.11818181818181818SKLADKA 1000.0
# P BANKRUCTWA 0.07272727272727272SKLADKA 1100.0
# P BANKRUCTWA 0.03636363636363636SKLADKA 1200.0
# P BANKRUCTWA 0.02727272727272727SKLADKA 1300.0
# P BANKRUCTWA 0.00909090909090909SKLADKA 1400.0
# P BANKRUCTWA 0.0SKLADKA 1500.0
# P BANKRUCTWA 0.0SKLADKA 1600.0
# P BANKRUCTWA 0.0SKLADKA 1700.0
# P BANKRUCTWA 0.0SKLADKA 1800.0
# P BANKRUCTWA 0.0SKLADKA 1900.0
# P BANKRUCTWA 0.0SKLADKA 2000.0
# P BANKRUCTWA 0.11818181818181818SKLADKA 1000.0
# P BANKRUCTWA 0.07272727272727272SKLADKA 1100.0
# P BANKRUCTWA 0.03636363636363636SKLADKA 1200.0
# P BANKRUCTWA 0.02727272727272727SKLADKA 1300.0
# ...
# P BANKRUCTWA 0.02967032967032967SKLADKA 1300.0
# P BANKRUCTWA 0.020879120879120878SKLADKA 1400.0
# P BANKRUCTWA 0.00989010989010989SKLADKA 1500.0
# P BANKRUCTWA 0.008791208791208791SKLADKA 1600.0
# P BANKRUCTWA 0.007692307692307693SKLADKA 1700.0
# P BANKRUCTWA 0.006593406593406593SKLADKA 1800.0
# P BANKRUCTWA 0.005494505494505495SKLADKA 1900.0
# P BANKRUCTWA 0.0032967032967032967SKLADKA 2000.0
# P BANKRUCTWA 0.11538461538461539SKLADKA 1000.0
# P BANKRUCTWA 0.07582417582417582SKLADKA 1100.0
# P BANKRUCTWA 0.046153846153846156SKLADKA 1200.0
# P BANKRUCTWA 0.02967032967032967SKLADKA 1300.0
# P BANKRUCTWA 0.020879120879120878SKLADKA 1400.0
# P BANKRUCTWA 0.00989010989010989SKLADKA 1500.0
# P BANKRUCTWA 0.008791208791208791SKLADKA 1600.0
# P BANKRUCTWA 0.007692307692307693SKLADKA 1700.0
# P BANKRUCTWA 0.006593406593406593SKLADKA 1800.0
# P BANKRUCTWA 0.005494505494505495SKLADKA 1900.0
# P BANKRUCTWA 0.0032967032967032967SKLADKA 2000.0
# P BANKRUCTWA 0.11538461538461539SKLADKA 1000.0
# P BANKRUCTWA 0.07582417582417582SKLADKA 1100.0
# P BANKRUCTWA 0.046153846153846156SKLADKA 1200.0
# P BANKRUCTWA 0.02967032967032967SKLADKA 1300.0
# P BANKRUCTWA 0.020879120879120878SKLADKA 1400.0
# P BANKRUCTWA 0.00989010989010989SKLADKA 1500.0
# P BANKRUCTWA 0.008791208791208791SKLADKA 1600.0
# P BANKRUCTWA 0.007692307692307693SKLADKA 1700.0
# P BANKRUCTWA 0.006593406593406593SKLADKA 1800.0
# P BANKRUCTWA 0.005494505494505495SKLADKA 1900.0
# P BANKRUCTWA 0.0032967032967032967SKLADKA 2000.0
# P BANKRUCTWA 0.11538461538461539SKLADKA 1000.0
# P BANKRUCTWA 0.07582417582417582SKLADKA 1100.0
# P BANKRUCTWA 0.046153846153846156SKLADKA 1200.0
# P BANKRUCTWA 0.02967032967032967SKLADKA 1300.0
# P BANKRUCTWA 0.020879120879120878SKLADKA 1400.0
# P BANKRUCTWA 0.00989010989010989SKLADKA 1500.0
# P BANKRUCTWA 0.008791208791208791SKLADKA 1600.0
# P BANKRUCTWA 0.007692307692307693SKLADKA 1700.0
# P BANKRUCTWA 0.006593406593406593SKLADKA 1800.0
# P BANKRUCTWA 0.005494505494505495SKLADKA 1900.0
# P BANKRUCTWA 0.0032967032967032967SKLADKA 2000.0
# P BANKRUCTWA 0.11538461538461539SKLADKA 1000.0
# P BANKRUCTWA 0.07582417582417582SKLADKA 1100.0
# P BANKRUCTWA 0.046153846153846156SKLADKA 1200.0
# P BANKRUCTWA 0.02967032967032967SKLADKA 1300.0
# P BANKRUCTWA 0.020879120879120878SKLADKA 1400.0
# P BANKRUCTWA 0.00989010989010989SKLADKA 1500.0
# P BANKRUCTWA 0.008791208791208791SKLADKA 1600.0
# P BANKRUCTWA 0.007692307692307693SKLADKA 1700.0
# P BANKRUCTWA 0.006593406593406593SKLADKA 1800.0
# P BANKRUCTWA 0.005494505494505495SKLADKA 1900.0
# P BANKRUCTWA 0.0032967032967032967SKLADKA 2000.0
# P BANKRUCTWA 0.11538461538461539SKLADKA 1000.0
# P BANKRUCTWA 0.07582417582417582SKLADKA 1100.0
# P BANKRUCTWA 0.046153846153846156SKLADKA 1200.0
# P BANKRUCTWA 0.02967032967032967SKLADKA 1300.0
# P BANKRUCTWA 0.020879120879120878SKLADKA 1400.0
# P BANKRUCTWA 0.00989010989010989SKLADKA 1500.0
# P BANKRUCTWA 0.008791208791208791SKLADKA 1600.0
# P BANKRUCTWA 0.007692307692307693SKLADKA 1700.0
# P BANKRUCTWA 0.006593406593406593SKLADKA 1800.0
# P BANKRUCTWA 0.005494505494505495SKLADKA 1900.0
# P BANKRUCTWA 0.0032967032967032967SKLADKA 2000.0
# P BANKRUCTWA 0.11538461538461539SKLADKA 1000.0
# P BANKRUCTWA 0.07582417582417582SKLADKA 1100.0
# P BANKRUCTWA 0.046153846153846156SKLADKA 1200.0
# P BANKRUCTWA 0.02967032967032967SKLADKA 1300.0
# P BANKRUCTWA 0.020879120879120878SKLADKA 1400.0
# P BANKRUCTWA 0.00989010989010989SKLADKA 1500.0
# P BANKRUCTWA 0.008791208791208791SKLADKA 1600.0
# P BANKRUCTWA 0.007692307692307693SKLADKA 1700.0
# P BANKRUCTWA 0.006593406593406593SKLADKA 1800.0
# P BANKRUCTWA 0.005494505494505495SKLADKA 1900.0
# P BANKRUCTWA 0.0032967032967032967SKLADKA 2000.0
# P BANKRUCTWA 0.11538461538461539SKLADKA 1000.0
# P BANKRUCTWA 0.07582417582417582SKLADKA 1100.0
# P BANKRUCTWA 0.046153846153846156SKLADKA 1200.0
# P BANKRUCTWA 0.02967032967032967SKLADKA 1300.0
# P BANKRUCTWA 0.020879120879120878SKLADKA 1400.0
# P BANKRUCTWA 0.00989010989010989SKLADKA 1500.0
# P BANKRUCTWA 0.008791208791208791SKLADKA 1600.0
# P BANKRUCTWA 0.007692307692307693SKLADKA 1700.0
# P BANKRUCTWA 0.006593406593406593SKLADKA 1800.0
# P BANKRUCTWA 0.005494505494505495SKLADKA 1900.0
# P BANKRUCTWA 0.0032967032967032967SKLADKA 2000.0
# P BANKRUCTWA 0.11538461538461539SKLADKA 1000.0
# P BANKRUCTWA 0.07582417582417582SKLADKA 1100.0
# P BANKRUCTWA 0.046153846153846156SKLADKA 1200.0
# P BANKRUCTWA 0.02967032967032967SKLADKA 1300.0
# P BANKRUCTWA 0.020879120879120878SKLADKA 1400.0
# P BANKRUCTWA 0.00989010989010989SKLADKA 1500.0
# P BANKRUCTWA 0.008791208791208791SKLADKA 1600.0
# P BANKRUCTWA 0.007692307692307693SKLADKA 1700.0
# P BANKRUCTWA 0.006593406593406593SKLADKA 1800.0
# P BANKRUCTWA 0.005494505494505495SKLADKA 1900.0
# P BANKRUCTWA 0.0032967032967032967SKLADKA 2000.0
# P BANKRUCTWA 0.11538461538461539SKLADKA 1000.0
# P BANKRUCTWA 0.07582417582417582SKLADKA 1100.0
# P BANKRUCTWA 0.046153846153846156SKLADKA 1200.0
# P BANKRUCTWA 0.02967032967032967SKLADKA 1300.0
# P BANKRUCTWA 0.020879120879120878SKLADKA 1400.0
# P BANKRUCTWA 0.00989010989010989SKLADKA 1500.0
# P BANKRUCTWA 0.008791208791208791SKLADKA 1600.0
# P BANKRUCTWA 0.007692307692307693SKLADKA 1700.0
# P BANKRUCTWA 0.006593406593406593SKLADKA 1800.0
# P BANKRUCTWA 0.005494505494505495SKLADKA 1900.0
# P BANKRUCTWA 0.0032967032967032967SKLADKA 2000.0
# P BANKRUCTWA 0.11538461538461539SKLADKA 1000.0
# P BANKRUCTWA 0.07582417582417582SKLADKA 1100.0
# P BANKRUCTWA 0.046153846153846156SKLADKA 1200.0
# P BANKRUCTWA 0.02967032967032967SKLADKA 1300.0
# P BANKRUCTWA 0.020879120879120878SKLADKA 1400.0
# P BANKRUCTWA 0.00989010989010989SKLADKA 1500.0
# P BANKRUCTWA 0.008791208791208791SKLADKA 1600.0
# P BANKRUCTWA 0.007692307692307693SKLADKA 1700.0
# P BANKRUCTWA 0.006593406593406593SKLADKA 1800.0
# P BANKRUCTWA 0.005494505494505495SKLADKA 1900.0
# P BANKRUCTWA 0.0032967032967032967SKLADKA 2000.0
# P BANKRUCTWA 0.11538461538461539SKLADKA 1000.0
# P BANKRUCTWA 0.07582417582417582SKLADKA 1100.0
# P BANKRUCTWA 0.046153846153846156SKLADKA 1200.0
# P BANKRUCTWA 0.02967032967032967SKLADKA 1300.0
# P BANKRUCTWA 0.020879120879120878SKLADKA 1400.0
# P BANKRUCTWA 0.00989010989010989SKLADKA 1500.0
# P BANKRUCTWA 0.008791208791208791SKLADKA 1600.0
# P BANKRUCTWA 0.007692307692307693SKLADKA 1700.0
# P BANKRUCTWA 0.006593406593406593SKLADKA 1800.0
# P BANKRUCTWA 0.005494505494505495SKLADKA 1900.0
# P BANKRUCTWA 0.0032967032967032967SKLADKA 2000.0
# P BANKRUCTWA 0.11538461538461539SKLADKA 1000.0
# P BANKRUCTWA 0.07582417582417582SKLADKA 1100.0
# P BANKRUCTWA 0.046153846153846156SKLADKA 1200.0
# P BANKRUCTWA 0.02967032967032967SKLADKA 1300.0
# P BANKRUCTWA 0.020879120879120878SKLADKA 1400.0
# P BANKRUCTWA 0.00989010989010989SKLADKA 1500.0
# P BANKRUCTWA 0.008791208791208791SKLADKA 1600.0
# P BANKRUCTWA 0.007692307692307693SKLADKA 1700.0
# P BANKRUCTWA 0.006593406593406593SKLADKA 1800.0
# P BANKRUCTWA 0.005494505494505495SKLADKA 1900.0
# P BANKRUCTWA 0.0032967032967032967SKLADKA 2000.0
# P BANKRUCTWA 0.11538461538461539SKLADKA 1000.0
# P BANKRUCTWA 0.07582417582417582SKLADKA 1100.0
# P BANKRUCTWA 0.046153846153846156SKLADKA 1200.0
# P BANKRUCTWA 0.02967032967032967SKLADKA 1300.0
# P BANKRUCTWA 0.020879120879120878SKLADKA 1400.0
# P BANKRUCTWA 0.00989010989010989SKLADKA 1500.0
# P BANKRUCTWA 0.008791208791208791SKLADKA 1600.0
# P BANKRUCTWA 0.007692307692307693SKLADKA 1700.0
# P BANKRUCTWA 0.006593406593406593SKLADKA 1800.0
# P BANKRUCTWA 0.005494505494505495SKLADKA 1900.0
# P BANKRUCTWA 0.0032967032967032967SKLADKA 2000.0
# P BANKRUCTWA 0.11538461538461539SKLADKA 1000.0
# P BANKRUCTWA 0.07582417582417582SKLADKA 1100.0
# P BANKRUCTWA 0.046153846153846156SKLADKA 1200.0
# P BANKRUCTWA 0.02967032967032967SKLADKA 1300.0
# P BANKRUCTWA 0.020879120879120878SKLADKA 1400.0
# P BANKRUCTWA 0.00989010989010989SKLADKA 1500.0
# P BANKRUCTWA 0.008791208791208791SKLADKA 1600.0
# P BANKRUCTWA 0.007692307692307693SKLADKA 1700.0
# P BANKRUCTWA 0.006593406593406593SKLADKA 1800.0
# P BANKRUCTWA 0.005494505494505495SKLADKA 1900.0
# P BANKRUCTWA 0.0032967032967032967SKLADKA 2000.0
# P BANKRUCTWA 0.11538461538461539SKLADKA 1000.0
# P BANKRUCTWA 0.07582417582417582SKLADKA 1100.0
# P BANKRUCTWA 0.046153846153846156SKLADKA 1200.0
# P BANKRUCTWA 0.02967032967032967SKLADKA 1300.0
# P BANKRUCTWA 0.020879120879120878SKLADKA 1400.0
# P BANKRUCTWA 0.00989010989010989SKLADKA 1500.0
# P BANKRUCTWA 0.008791208791208791SKLADKA 1600.0
# P BANKRUCTWA 0.007692307692307693SKLADKA 1700.0
# P BANKRUCTWA 0.006593406593406593SKLADKA 1800.0
# P BANKRUCTWA 0.005494505494505495SKLADKA 1900.0
# P BANKRUCTWA 0.0032967032967032967SKLADKA 2000.0
# P BANKRUCTWA 0.11538461538461539SKLADKA 1000.0
# P BANKRUCTWA 0.07582417582417582SKLADKA 1100.0
# P BANKRUCTWA 0.046153846153846156SKLADKA 1200.0
# P BANKRUCTWA 0.02967032967032967SKLADKA 1300.0
# P BANKRUCTWA 0.020879120879120878SKLADKA 1400.0
# P BANKRUCTWA 0.00989010989010989SKLADKA 1500.0
# P BANKRUCTWA 0.008791208791208791SKLADKA 1600.0
# P BANKRUCTWA 0.007692307692307693SKLADKA 1700.0
# P BANKRUCTWA 0.006593406593406593SKLADKA 1800.0
# P BANKRUCTWA 0.005494505494505495SKLADKA 1900.0
# P BANKRUCTWA 0.0032967032967032967SKLADKA 2000.0
# P BANKRUCTWA 0.11538461538461539SKLADKA 1000.0
# P BANKRUCTWA 0.07582417582417582SKLADKA 1100.0
# P BANKRUCTWA 0.046153846153846156SKLADKA 1200.0
# P BANKRUCTWA 0.02967032967032967SKLADKA 1300.0
# P BANKRUCTWA 0.020879120879120878SKLADKA 1400.0
# P BANKRUCTWA 0.00989010989010989SKLADKA 1500.0
# P BANKRUCTWA 0.008791208791208791SKLADKA 1600.0
# P BANKRUCTWA 0.007692307692307693SKLADKA 1700.0
# P BANKRUCTWA 0.006593406593406593SKLADKA 1800.0
# P BANKRUCTWA 0.005494505494505495SKLADKA 1900.0
# P BANKRUCTWA 0.0032967032967032967SKLADKA 2000.0
# P BANKRUCTWA 0.11538461538461539SKLADKA 1000.0
# P BANKRUCTWA 0.07582417582417582SKLADKA 1100.0
# P BANKRUCTWA 0.046153846153846156SKLADKA 1200.0
# P BANKRUCTWA 0.02967032967032967SKLADKA 1300.0
# P BANKRUCTWA 0.020879120879120878SKLADKA 1400.0
# P BANKRUCTWA 0.00989010989010989SKLADKA 1500.0
# P BANKRUCTWA 0.008791208791208791SKLADKA 1600.0
# P BANKRUCTWA 0.007692307692307693SKLADKA 1700.0
# P BANKRUCTWA 0.006593406593406593SKLADKA 1800.0
# P BANKRUCTWA 0.005494505494505495SKLADKA 1900.0
# P BANKRUCTWA 0.0032967032967032967SKLADKA 2000.0
# P BANKRUCTWA 0.11538461538461539SKLADKA 1000.0
# P BANKRUCTWA 0.07582417582417582SKLADKA 1100.0
# P BANKRUCTWA 0.046153846153846156SKLADKA 1200.0
# P BANKRUCTWA 0.02967032967032967SKLADKA 1300.0
# P BANKRUCTWA 0.020879120879120878SKLADKA 1400.0
# P BANKRUCTWA 0.00989010989010989SKLADKA 1500.0
# P BANKRUCTWA 0.008791208791208791SKLADKA 1600.0
# P BANKRUCTWA 0.007692307692307693SKLADKA 1700.0
# P BANKRUCTWA 0.006593406593406593SKLADKA 1800.0
# P BANKRUCTWA 0.005494505494505495SKLADKA 1900.0
# P BANKRUCTWA 0.0032967032967032967SKLADKA 2000.0
# P BANKRUCTWA 0.11538461538461539SKLADKA 1000.0
# P BANKRUCTWA 0.07582417582417582SKLADKA 1100.0
# P BANKRUCTWA 0.046153846153846156SKLADKA 1200.0
# P BANKRUCTWA 0.02967032967032967SKLADKA 1300.0
# P BANKRUCTWA 0.020879120879120878SKLADKA 1400.0
# P BANKRUCTWA 0.00989010989010989SKLADKA 1500.0
# P BANKRUCTWA 0.008791208791208791SKLADKA 1600.0
# P BANKRUCTWA 0.007692307692307693SKLADKA 1700.0
# P BANKRUCTWA 0.006593406593406593SKLADKA 1800.0
# P BANKRUCTWA 0.005494505494505495SKLADKA 1900.0
# P BANKRUCTWA 0.0032967032967032967SKLADKA 2000.0
# P BANKRUCTWA 0.11538461538461539SKLADKA 1000.0
# P BANKRUCTWA 0.07582417582417582SKLADKA 1100.0
# P BANKRUCTWA 0.046153846153846156SKLADKA 1200.0
# P BANKRUCTWA 0.02967032967032967SKLADKA 1300.0
# P BANKRUCTWA 0.020879120879120878SKLADKA 1400.0
# P BANKRUCTWA 0.00989010989010989SKLADKA 1500.0
# P BANKRUCTWA 0.008791208791208791SKLADKA 1600.0
# P BANKRUCTWA 0.007692307692307693SKLADKA 1700.0
# P BANKRUCTWA 0.006593406593406593SKLADKA 1800.0
# P BANKRUCTWA 0.005494505494505495SKLADKA 1900.0
# P BANKRUCTWA 0.0032967032967032967SKLADKA 2000.0
# P BANKRUCTWA 0.11538461538461539SKLADKA 1000.0
# P BANKRUCTWA 0.07582417582417582SKLADKA 1100.0
# P BANKRUCTWA 0.046153846153846156SKLADKA 1200.0
# P BANKRUCTWA 0.02967032967032967SKLADKA 1300.0
# P BANKRUCTWA 0.020879120879120878SKLADKA 1400.0
# P BANKRUCTWA 0.00989010989010989SKLADKA 1500.0
# P BANKRUCTWA 0.008791208791208791SKLADKA 1600.0
# P BANKRUCTWA 0.007692307692307693SKLADKA 1700.0
# P BANKRUCTWA 0.006593406593406593SKLADKA 1800.0
# Excessive output truncated after 524294 bytes.
# P BANKRUCTWA 0.005494505494505495SKLADKA 1900.0
# P BANKRUCTWA 0.0032967032967032967SKLADKA 2000.0
# Any[1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900.0, 2000.0, 1500.0, 1600 ...

# %%
x_values = LICZBA_SYMULACJI
plot(len, [upper_quants, medians, means, lower_quants], label=["kwantyl 0.95" "mediana" "srednia" "kwantyl 0.05"], title="LICZBA_POWTORZEN: 1 - 1000")
plot!(legend=:bottomright)
xlabel!("Liczba symulacji")
ylabel!("Skladka")

# %%
nadwyzka = 10000.0:10000.0:10000.0
skladka = 1000.0:100.0:2000.0
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
LICZBA_POWTORZEN = 10:10:1000
LICZBA_SYMULACJI = 10.0:100.0:10000.0
skladka_koncowa = skladka[1]
skladka_idealna = []
medians = []
means = []
lower_quants = []
upper_quants= []
len = []
mean_wynik = []
mediana_wynik = []
q0_05_wynik = []
q0_95_wynik = []
for ls in LICZBA_SYMULACJI
    mean_wynik = []
    mediana_wynik = []
    q0_05_wynik = []
    q0_95_wynik = []
    skladka_idealna = []
    for lp in LICZBA_POWTORZEN
        for skl in skladka
            wynik = wywolanie(nd, skl, ls, LICZBA_KLIENTOW, srednia_liczba_szkod , SR_SZKODA_LN, STD_SZKODA_LN, HORYZONT)
            push!(liczba_ruin, wynik.liczba_ruin)
            push!(prawd_bankr, wynik.p_bankructwa)
            push!(sr_wynik, wynik.sredni_wynik)
            #println("P BANKRUCTWA ", wynik.p_bankructwa, "SKLADKA ", skl)
            if wynik.p_bankructwa <= 0.01
                #println("Nadwyzka: ", nd, " Skladka: ", skl, " Liczba ruin: ", wynik.liczba_ruin, " Średni wynik: ",round(wynik.sredni_wynik), " Prawd_bankr: ", wynik.p_bankructwa)
                push!(skladka_idealna, skl)
                break
            end
        end
    end
        
    if length(skladka_idealna) != 0
        mean_wynik = mean(skladka_idealna)
        mediana_wynik = median(skladka_idealna)
        q0_05_wynik = quantile(skladka_idealna, 0.05)
        q0_95_wynik = quantile(skladka_idealna, 0.95)
    end
end
x_values = LICZBA_SYMULACJI
plot(len, [upper_quants, medians, means, lower_quants], label=["kwantyl 0.95" "mediana" "srednia" "kwantyl 0.05"], title="Zaleznosc miedzy liczba powtorzen a wielkoscia skladki \n LICZBA_POWTORZEN: 1 - 10 000")
plot!(legend=:bottomright)
xlabel!("Liczba symulacji")
ylabel!("Skladka")

# %%
x_values = LICZBA_SYMULACJI
plot(len, [upper_quants, medians, means, lower_quants], label=["kwantyl 0.95" "mediana" "srednia" "kwantyl 0.05"], title="LICZBA_POWTORZEN: 1 - 10 000")
plot!(legend=:bottomright)
xlabel!("Liczba symulacji")
ylabel!("Skladka")

# %%
nadwyzka = 10000.0:10000.0:10000.0
skladka = 1000.0:100.0:2000.0
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
LICZBA_POWTORZEN = 10:10:1000
LICZBA_SYMULACJI = 10.0:100.0:10000.0
skladka_koncowa = skladka[1]
skladka_idealna = []
medians = []
means = []
lower_quants = []
upper_quants= []
len = []
mean_wynik = []
mediana_wynik = []
q0_05_wynik = []
q0_95_wynik = []
for ls in LICZBA_SYMULACJI
    mean_wynik = []
    mediana_wynik = []
    q0_05_wynik = []
    q0_95_wynik = []
    skladka_idealna = []
    for lp in LICZBA_POWTORZEN
        for skl in skladka
            wynik = wywolanie(nd, skl, ls, LICZBA_KLIENTOW, srednia_liczba_szkod , SR_SZKODA_LN, STD_SZKODA_LN, HORYZONT)
            push!(liczba_ruin, wynik.liczba_ruin)
            push!(prawd_bankr, wynik.p_bankructwa)
            push!(sr_wynik, wynik.sredni_wynik)
            #println("P BANKRUCTWA ", wynik.p_bankructwa, "SKLADKA ", skl)
        end
    end
    mean_wynik = mean(prawd_bankr)
    mediana_wynik = median(prawd_bankr)
    q0_05_wynik = quantile(prawd_bankr, 0.05)
    q0_95_wynik = quantile(prawd_bankr, 0.95)
    end
end
x_values = LICZBA_SYMULACJI
plot(x_values, [upper_quants, medians, means, lower_quants], label=["kwantyl 0.95" "mediana" "srednia" "kwantyl 0.05"], title="Zaleznosc miedzy liczba powtorzen a prawdopodobieństwem ruiny \n LICZBA_POWTORZEN: 1 - 10 000")
plot!(legend=:bottomright)
xlabel!("Liczba symulacji")
ylabel!("Prawdopodobieństwo ruiny")

# %%
medians
# Out:
# 9-element Vector{Any}:
#  1000.0
#  1400.0
#  2000.0
#  2000.0
#  1900.0
#  1800.0
#  1700.0
#  1600.0
#  1500.0

# %%
x = range(0, 10, length=100)
y1 = sin.(x)
y2 = cos.(x)
plot(x, [y1 y2], title="Trigonometric functions", label=["sin(x)" "cos(x)"], linewidth=3)
