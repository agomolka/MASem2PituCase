# %% [markdown]
# # ZMS  Pitu Case - Julia

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Kiedy-ruina-=-RUINA-?" data-toc-modified-id="Kiedy-ruina-=-RUINA-?-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Kiedy ruina = RUINA ?</a></span></li><li><span><a href="#Weryfikacja-hipotez-i-wyznaczanie-parametrów" data-toc-modified-id="Weryfikacja-hipotez-i-wyznaczanie-parametrów-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Weryfikacja hipotez i wyznaczanie parametrów</a></span></li><li><span><a href="#Wielkość-szkód" data-toc-modified-id="Wielkość-szkód-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Wielkość szkód</a></span></li><li><span><a href="#Model-symulacji" data-toc-modified-id="Model-symulacji-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Model symulacji</a></span></li><li><span><a href="#Symulacja" data-toc-modified-id="Symulacja-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Symulacja</a></span></li><li><span><a href="#Praca" data-toc-modified-id="Raport-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Praca domowa</a></span><ul class="toc-item"><li><span><a href="#Zbadaj-płynność-firmy-w-zależności-od-parametrów" data-toc-modified-id="Zbadaj-płynność-firmy-w-zależności-od-parametrów-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Zbadaj płynność firmy w zależności od parametrów</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Kiedy ruina = RUINA ?
#
# *opr. P. Wojewnik na podstawie:*
#
# *„Optymalizacja portfela szkód” K. Saduś, M. Kwiecień, R. Lipiński* oraz *„Ubezpieczenia komunikacyjne firmy ABC” A. Kołota, M. Mączyńska*
#
#
# Prezes zarządu zakładu ubezpieczeń PiTU S.A., Marcin R., zasłyszał, że Prezydent planuje naturalizować wszystkich chętnych z Dżydżykistanu. *No to teraz się zacznie*, pomyślał, *Dżydżykowie jeżdżą jak wariaci, wzrośnie szkodowość, a więc musimy podnieść dla nich ceny.*
#
# Marcin R. dzwoni do aktuariuszki – Aldony P., ale tu czeka go niespodzianka. *Mój synek zachorował... Grypa to nic wielkiego... Ale w świńskim wydaniu bywa niebezpieczna.* Marcin z bólem serca odsyła Aldonę do domu, a zlecenie dostaje Marek T., asystent Aldony. Pytanie brzmi: **czy składka 500 zł jest wystarczająca ?**
#
# Dotychczasowe doświadczenia PiTU S.A. z Dżydżykami są następujące:
#
# <table>
# <tr></tr>
# <tr><td>
#
# | Liczba szkód    | Liczba polis
# |-----------------|-------------
# | 0               | 3 437
# | 1               | 522
# | 2               | 40
# | 3               | 2
# | 4               | 0
# | 5               | 0
#
# </td><td>
#
# | Wielkość szkody | Liczba szkód
# |-----------------|-------------
# | -               | 0
# | 100             | 0
# | 200             | 2
# | 500             | 27
# | 1 000           | 52
# | 2 000           | 115
# | 5 000           | 203
# | 10 000          | 106
# | 20 000          | 42
# | 40 000          | 14
# | 50 000          | 0
# | 55 000          | 0
# | 60 000          | 1
#
# </td></tr> </table>
#
# Aldona rzuciła jeszcze przez telefon, że **liczbę szkód dobrze opisuje rozkład Poissona**, natomiast **wielkość szkód – rozkład log-normalny**. Z Marcina udało się wydusić **oczekiwaną liczbę klientów – 100** – oraz **aktualną nadwyżkę 10 000**.
#
#
# **Pytania:**
# 1.	Jaką ustalić składkę OC, aby ruina kierowców nie była udziałem PiTU S.A.?
# 2.	Czy nadwyżka końcowa będzie równa początkowej?
# 3.	Jakie jest zagrożenie ruiną?
# 4.	Jaka powinna być nadwyżka i składka, żeby prawdopodobieństwo ruiny było mniejsze niż 0,01?

# %% [markdown]
# ## Weryfikacja hipotez i wyznaczanie parametrów

# %%
import Pkg
Pkg.add("Plots")
# Pkg.update("Plots")
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`

# %%
Pkg.add("PyPlot")
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`

# %%
#import Pkg; Pkg.add("Distributions")

# %%
#import Pkg; Pkg.add("HypothesisTests")
#import Pkg; Pkg.add("Random")

# %%
Pkg.add("DataFrames")
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`

# %%
using Plots
using Distributions
using HypothesisTests
using Random
using DataFrames

# %%
liczba_szkod = Dict(0 => 3437,
                1 => 522,
                2 => 40,
                3 => 2,
                4 => 0, 
                5 => 0);

# %%
# Średnia liczba szkód:
liczba_polis = sum(values(liczba_szkod))
srednia_liczba_szkod = (sum([x * y for (x, y) in liczba_szkod]) / 
                        liczba_polis)

# Czy liczba szkód ma faktycznie rozkład Poissona?
poiss = Poisson(srednia_liczba_szkod)
k = length(liczba_szkod)-1
poisson_test = pdf.(poiss, 0:k) * liczba_polis

bar(liczba_szkod, fillcolor = :blue, legend=false, title= "empiryczna liczba szkód")

# %%
println(srednia_liczba_szkod)
println(pdf.(poiss, 0:k))
println(liczba_szkod)
println([liczba_szkod[i] for i in 0:k])
print(poisson_test)
# Out:
# 0.1519620094976256
# [0.85902091475733, 0.1305385444070124, 0.009918449762492322, 0.0005024091856698595, 1.9086777361114376e-5, 5.80093008525747e-7]
# Dict(0 => 3437, 4 => 0, 5 => 0, 2 => 40, 3 => 2, 1 => 522)
# [3437, 522, 40, 2, 0, 0]
# [3436.9426799440776, 522.2847161724566, 39.68371749973178, 2.0101391518651077, 0.07636619622181862, 0.002320952127111514]

# %%
#ok. 85% osoób bedzie miało 0 wypadków

# %%
#[3437, 522, 40, 2, 0, 0] ->
#[3436.9426799440776, 522.2847161724566, 39.68371749973178, 2.0101391518651077, 0.07636619622181862, 0.002320952127111514] -> prognozy
#rozkład Poisson jest widocznie dobrze dopasowany, ponieważ te liczby zostały wygenerowane z tego rozkładu xd

# %%
bar(0:k, poisson_test, fillcolor = :green, legend = false, title = "teoretyczna liczba szkód")

# %%
# Test chi-kwadrat z biblioteki HypothesisTests pomoże odpowiedziec na pytanie
χ = ChisqTest([liczba_szkod[i] for i in 0:k],poisson_test/sum(poisson_test));
pval = pvalue(χ)
println("p-value=",pval)
if pval > 0.05
    print("Brak podstaw do odrzucenia hipotezy zerowej")
else
    print("Należy odrzucić hipotezę zerową")
end
# Out:
# p-value=0.9999022759058723
# Brak podstaw do odrzucenia hipotezy zerowej

# %% [markdown]
# ## Wielkość szkód

# %%
szkody = [parse(Int,x[2]) for x in split.(readlines("./szkody.txt"), ';')];

# %%
histogram(szkody, xlabel = "Wielkosc szkody", ylabel = "Liczba szkod", legend = false, bins = 100)

# %%
println("Średnia wielkość szkod: ", round(mean(szkody)))
# Out:
# Średnia wielkość szkod: 4742.0

# %%
# Wielkość szkód ma rozkład log-normalny:
szkody_ln = log.(szkody);
histogram(szkody_ln, fillcolor=:khaki, legend = false, bins = 50)

# %%
# ... czy faktycznie? test Kolmogorova-Smirnova - test do sprawdzania czy rozklad normalny
#lepiej uzyc shapiro-wilka
kstest = ExactOneSampleKSTest(szkody_ln, Normal(mean(szkody_ln), std(szkody_ln)))
kspval = pvalue(kstest)
if kspval > 0.05
    println("p-value wyniosło:", kspval, 
           "\nBrak więc podstaw do odrzucenia hipotezy " *
           "o log-normalności rozkładu zmiennej")
else
    println("należy odrzucic hipotezę zerowa")
end
# Out:
# ┌ Warning: This test is inaccurate with ties
# └ @ HypothesisTests ~/.julia/packages/HypothesisTests/zKkJv/src/kolmogorov_smirnov.jl:68
# p-value wyniosło:0.9970804174500004
# Brak więc podstaw do odrzucenia hipotezy o log-normalności rozkładu zmiennej

# %%
#potrzebujemy parametry tego rozkladu na później, z logarytmu tych szkód
#
# Parametry wielkości szkód potrzebne do symulacji:
SR_SZKODA_LN = mean(szkody_ln)
STD_SZKODA_LN = std(szkody_ln);

# %%
LICZBA_POWTORZEN = 100
LICZBA_KLIENTOW = 100 #załozenie do projektu
HORYZONT = 2 # Długość obowiązywania umowy - zakładamy 2 lata #założeni do projektu
# Out:
# 2

# %% [markdown]
# ## Model symulacji

# %%
function model(liczba_klientow::S, 
                srednia_liczba_szkod::T, 
                sr_szkoda_ln::T, 
                std_szkoda_ln::T, 
                horyzont::S, 
                nadwyzka::T, 
                skladka::T;
                seed::S=-1) where {T<:AbstractFloat, S<:Int} #domyślna wartość to -1

    # Common Random Numbers aby móc porównać różne scenariusze:
    seed == -1 || Random.seed!(seed) #-1 nie będzie porównywalnosci, trzeba ustawic inne żeby była powtarzalność
    #|| - OR, czyli albo to jest spełnione, albo to po prawej
    #dobrze ustawić ziarno

    # Definiujemy daty umów klientów w symulacji:
    daty_umow = [rand(1:365) for i in 1:liczba_klientow]
    kalendarz_wplat = zeros(Int,365)
    for dataUmowy in daty_umow
        kalendarz_wplat[dataUmowy] += 1
    end
    # Liczymy liczbę szkód przypadających na jednego klienta:
    liczba_szkod_klienta = rand(Poisson(srednia_liczba_szkod),liczba_klientow)
    
    # Ustalamy daty wypłaty dla wszystkich polis:
    kalendarz_wyplat = zeros(Int,365*horyzont) 
    for k in 1:liczba_klientow
        for s in 1:liczba_szkod_klienta[k]
            data_wyplaty = daty_umow[k] + rand(1:365) #symulujemy 1rok polisy, jeden cykl życia polisy
            kalendarz_wyplat[data_wyplaty] += 1
        end
    end
    
    # Analiza wyników firmy dla danego horyzontu czasowego i danych szkód:
    for dzien in 1:365*horyzont
        dzien ≤ 364 && (nadwyzka += kalendarz_wplat[dzien] * skladka)
        liczba_wyplat = kalendarz_wyplat[dzien]
        odszkodowania = sum(exp.(rand(Normal(sr_szkoda_ln,std_szkoda_ln),liczba_wyplat)))
        nadwyzka -= odszkodowania
        nadwyzka ≤ 0 && return nadwyzka #można zakomentować, wtedy nie trzeba wysokiej nadwyżki ustawiać - tylko mozna komentowac dla 3 podejścia
    end
    return nadwyzka
end
# Out:
# model (generic function with 1 method)

# %%
function wywolanie(nadwyzka::T, skladka::T, liczba_powtorzen::S, 
              liczba_klientow::S, srednia_liczba_szkod::T, 
              sr_szkoda_ln::T, std_szkoda_ln::T, horyzont::S) where {T<:AbstractFloat,S<:Int}
    wynik = []
    for seed in 1:liczba_powtorzen
        push!(wynik, model(liczba_klientow, srednia_liczba_szkod, sr_szkoda_ln, std_szkoda_ln, horyzont, nadwyzka, skladka, seed = seed))
    end

    return (liczba_ruin = sum(wynik.<=0), p_bankructwa = sum(wynik.<0)/liczba_powtorzen, sredni_wynik = mean(wynik[wynik.>0])) #wazne w pkt 3 zeby pozwolic sie kręcic po 0
end
# Out:
# wywolanie (generic function with 1 method)

# %% [markdown]
# ## Symulacja

# %%
nadwyzka = 10000.0:10000.0:10000.0
skladka = 500.0:100.0:1000.0
# Out:
# 500.0:100.0:1000.0

# %%
# zmienne i parametry w modelu:
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
nadwyzka = 10000.0:10000.0:10000.0
skladka = 500.0:100.0:1000.0

LICZBA_POWTORZEN = 100

for nd in nadwyzka, skl in skladka
    wynik = wywolanie(nd, skl, 
            LICZBA_POWTORZEN, LICZBA_KLIENTOW, 
            srednia_liczba_szkod , SR_SZKODA_LN, 
            STD_SZKODA_LN, HORYZONT)
    push!(liczba_ruin, wynik.liczba_ruin)
    push!(prawd_bankr, wynik.p_bankructwa)
    push!(sr_wynik, wynik.sredni_wynik)
    println("Nadwyzka: ", nd, " Skladka: ", skl, 
              " Liczba ruin: ", wynik.liczba_ruin, " Średni wynik: ",
              round(wynik.sredni_wynik), " Prawd_bankr: ", wynik.p_bankructwa)
end
# Out:
# Nadwyzka: 10000.0 Skladka: 500.0 Liczba ruin: 60 Średni wynik: 15777.0 Prawd_bankr: 0.6
# Nadwyzka: 10000.0 Skladka: 600.0 Liczba ruin: 49 Średni wynik: 21174.0 Prawd_bankr: 0.49
# Nadwyzka: 10000.0 Skladka: 700.0 Liczba ruin: 35 Średni wynik: 25476.0 Prawd_bankr: 0.35
# Nadwyzka: 10000.0 Skladka: 800.0 Liczba ruin: 26 Średni wynik: 31786.0 Prawd_bankr: 0.26
# Nadwyzka: 10000.0 Skladka: 900.0 Liczba ruin: 19 Średni wynik: 38709.0 Prawd_bankr: 0.19
# Nadwyzka: 10000.0 Skladka: 1000.0 Liczba ruin: 12 Średni wynik: 45201.0 Prawd_bankr: 0.12

# %%
#ENV["GKS_ENCODING"] = "utf-8"      

plot(collect(skladka), prawd_bankr, markershape=:circle,
ylabel = "Prawdopodobieństwo bankructwa",
xlabel = "Wysokość składki",
legend = false)

# %% [markdown]
# ## Indywidualna praca domowa
#
# ### Zbadaj płynność firmy w zależności od parametrów
#
# ---
# Udziel proszę odpowiedzi na poniże pytania, uzupełniając komórki Waszym kodem Julii. Zapisz proszę uzupełniony notebook pod nazwą `[SN-ZMS_2_praca_domowa.ipynb` prześlijcie proszę na adres mzawisz@sgh.waw.pl o tytule: __[D-ZMS] 2. praca domowa__ .
#
# __Termin oddania:__ Zgodnie z datą podaną na Teamsach. Każdy rozpoczęty dzień spóźnienia kosztuje 1 punkt mniej.
#
# __Maksymalna liczba punktów do zdobycia:__ 5 punktów
#
# ---
# **Pytania**
# # Jaką ustalić składkę OC, aby prawdopodobieństwo ruiny było mniejsze niż 0,01? (analiza 1 parametru)

# %%
# miejsce na odpowiedź

# %%
#Przeprowadzę analizę wrażliwości jednego parametru – zmieniam wysokość składki i dla każdego robię np. 10k symulacji i sprawdzam
#Definiuję prawdopodobieństwo ruiny jako liczbę symulacji które uderzyły w zero. 
#Nawet gdyby potem wyjdziemy na plus, to jak uderzy w zero to firma w biznesie nie ma możliwości finansowania.

# %%
# zmienne i parametry w modelu:
nadwyzka = 10000.0:10000.0:10000.0
skladka = 500.0:50.0:2000.0
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
LICZBA_POWTORZEN = 100
for nd in nadwyzka, skl in skladka
    wynik = wywolanie(nd, skl, 
            LICZBA_POWTORZEN, LICZBA_KLIENTOW, 
            srednia_liczba_szkod , SR_SZKODA_LN, 
            STD_SZKODA_LN, HORYZONT)
    push!(liczba_ruin, wynik.liczba_ruin)
    push!(prawd_bankr, wynik.p_bankructwa)
    push!(sr_wynik, wynik.sredni_wynik)
    #println("Nadwyzka: ", nd, " Skladka: ", skl, " Liczba ruin: ", wynik.liczba_ruin, " Średni wynik: ",round(wynik.sredni_wynik), " Prawd_bankr: ", wynik.p_bankructwa)
end
p=plot(collect(skladka), prawd_bankr, markershape=:circle, ylabel = "Prawdopodobieństwo bankructwa", xlabel = "Wysokość składki", legend = false)
hline!([0], color=:red, lw=2, linestyle=:dash)
display(p)

# %%
#sprawdzam wyniki symulacji przy większej licznie powtórzeń symulacji
nadwyzka = 10000.0:10000.0:10000.0
skladka = 1000.0:100.0:3000.0
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
LICZBA_POWTORZEN = 100

for nd in nadwyzka, skl in skladka
    wynik = wywolanie(nd, skl, 
            LICZBA_POWTORZEN, LICZBA_KLIENTOW, 
            srednia_liczba_szkod , SR_SZKODA_LN, 
            STD_SZKODA_LN, HORYZONT)
    push!(liczba_ruin, wynik.liczba_ruin)
    push!(prawd_bankr, wynik.p_bankructwa)
    push!(sr_wynik, wynik.sredni_wynik)
    #println("Nadwyzka: ", nd, " Skladka: ", skl, " Liczba ruin: ", wynik.liczba_ruin, " Średni wynik: ",round(wynik.sredni_wynik), " Prawd_bankr: ", wynik.p_bankructwa)
end
p=plot(collect(skladka), prawd_bankr, markershape=:circle, ylabel = "Prawdopodobieństwo bankructwa", xlabel = "Wysokość składki", legend = false)
hline!([0], color=:red, lw=2, linestyle=:dash)
display(p)

# %%
#sprawdzam wyniki symulacji przy większej licznie powtórzeń symulacji
nadwyzka = 10000.0:10000.0:10000.0
skladka = 1000.0:100.0:3000.0
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
LICZBA_POWTORZEN = 100
skladka_koncowa = skladka[1]
for nd in nadwyzka, skl in skladka
    wynik = wywolanie(nd, skl, 
            LICZBA_POWTORZEN, LICZBA_KLIENTOW, 
            srednia_liczba_szkod , SR_SZKODA_LN, 
            STD_SZKODA_LN, HORYZONT)
    push!(liczba_ruin, wynik.liczba_ruin)
    push!(prawd_bankr, wynik.p_bankructwa)
    push!(sr_wynik, wynik.sredni_wynik)
    if wynik.p_bankructwa <= 0.01
        println("Nadwyzka: ", nd, " Skladka: ", skl, " Liczba ruin: ", wynik.liczba_ruin, " Średni wynik: ", round(wynik.sredni_wynik), " Prawd_bankr: ", wynik.p_bankructwa)
        break
    end
    skladka_koncowa = skl
end
skladka = skladka[1]:skladka[2]-skladka[1]:skladka_koncowa+skladka[2]-skladka[1]
p=plot(collect(skladka), prawd_bankr, markershape=:circle, ylabel = "Prawdopodobieństwo bankructwa", xlabel = "Wysokość składki", legend = false)
hline!([0.01], color=:red, lw=2, linestyle=:dash)
display(p)
# Out:
# Nadwyzka: 10000.0 Skladka: 1400.0 Liczba ruin: 1 Średni wynik: 78799.0 Prawd_bankr: 0.01

# %%
#sprawdzam wyniki symulacji przy większej licznie powtórzeń symulacji
nadwyzka = 10000.0:10000.0:10000.0
skladka = 1000.0:50.0:3000.0
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
LICZBA_POWTORZEN = 10000
skladka_koncowa = skladka[1]
for nd in nadwyzka, skl in skladka
    wynik = wywolanie(nd, skl, 
            LICZBA_POWTORZEN, LICZBA_KLIENTOW, 
            srednia_liczba_szkod , SR_SZKODA_LN, 
            STD_SZKODA_LN, HORYZONT)
    push!(liczba_ruin, wynik.liczba_ruin)
    push!(prawd_bankr, wynik.p_bankructwa)
    push!(sr_wynik, wynik.sredni_wynik)
    if wynik.p_bankructwa <= 0.01
        println("Nadwyzka: ", nd, " Skladka: ", skl, " Liczba ruin: ", wynik.liczba_ruin, " Średni wynik: ",round(wynik.sredni_wynik), " Prawd_bankr: ", wynik.p_bankructwa)
        break
    end
    skladka_koncowa = skl
end
skladka = skladka[1]:skladka[2]-skladka[1]:skladka_koncowa+skladka[2]-skladka[1]
p=plot(collect(skladka), prawd_bankr, markershape=:circle, ylabel = "Prawdopodobieństwo bankructwa", xlabel = "Wysokość składki", legend = false)
hline!([0.01], color=:red, lw=2, linestyle=:dash)
display(p)
# Out:
# Nadwyzka: 10000.0 Skladka: 1650.0 Liczba ruin: 99 Średni wynik: 103149.0 Prawd_bankr: 0.0099

# %%
#Dla LICZBA_POWTORZEN = 10000, składka wynosi 1650.0

# %%
#sprawdzam wyniki symulacji przy większej licznie powtórzeń symulacji
nadwyzka = 10000.0:10000.0:10000.0
skladka = 1000.0:50.0:3000.0
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
LICZBA_POWTORZEN = 100000
skladka_koncowa = skladka[1]
for nd in nadwyzka, skl in skladka
    wynik = wywolanie(nd, skl, 
            LICZBA_POWTORZEN, LICZBA_KLIENTOW, 
            srednia_liczba_szkod , SR_SZKODA_LN, 
            STD_SZKODA_LN, HORYZONT)
    push!(liczba_ruin, wynik.liczba_ruin)
    push!(prawd_bankr, wynik.p_bankructwa)
    push!(sr_wynik, wynik.sredni_wynik)
    if wynik.p_bankructwa <= 0.01
        println("Nadwyzka: ", nd, " Skladka: ", skl, " Liczba ruin: ", wynik.liczba_ruin, " Średni wynik: ",round(wynik.sredni_wynik), " Prawd_bankr: ", wynik.p_bankructwa)
        break
    end
    skladka_koncowa = skl
end
skladka = skladka[1]:skladka[2]-skladka[1]:skladka_koncowa+skladka[2]-skladka[1]
p=plot(collect(skladka), prawd_bankr, markershape=:circle, ylabel = "Prawdopodobieństwo bankructwa", xlabel = "Wysokość składki", legend = false)
hline!([0.01], color=:red, lw=2, linestyle=:dash)
display(p)
# Out:
# Nadwyzka: 10000.0 Skladka: 1700.0 Liczba ruin: 874 Średni wynik: 108539.0 Prawd_bankr: 0.00874

# %%
##Dla LICZBA_POWTORZEN = 10000, składka wynosi 1700.0

# %%
#sprawdzam wyniki symulacji przy większej licznie powtórzeń symulacji
nadwyzka = 10000.0:10000.0:10000.0
skladka = 1300.0:50.0:2000.0
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
LICZBA_POWTORZEN = 1000000
skladka_koncowa = skladka[1]
for nd in nadwyzka, skl in skladka
    wynik = wywolanie(nd, skl, 
            LICZBA_POWTORZEN, LICZBA_KLIENTOW, 
            srednia_liczba_szkod , SR_SZKODA_LN, 
            STD_SZKODA_LN, HORYZONT)
    push!(liczba_ruin, wynik.liczba_ruin)
    push!(prawd_bankr, wynik.p_bankructwa)
    push!(sr_wynik, wynik.sredni_wynik)
    if wynik.p_bankructwa <= 0.01
        println("Nadwyzka: ", nd, " Skladka: ", skl, " Liczba ruin: ", wynik.liczba_ruin, " Średni wynik: ",round(wynik.sredni_wynik), " Prawd_bankr: ", wynik.p_bankructwa)
        break
    end
    skladka_koncowa = skl
end
skladka = skladka[1]:skladka[2]-skladka[1]:skladka_koncowa+skladka[2]-skladka[1]
p=plot(collect(skladka), prawd_bankr, markershape=:circle, ylabel = "Prawdopodobieństwo bankructwa", xlabel = "Wysokość składki", legend = false)
hline!([0.01], color=:red, lw=2, linestyle=:dash)
display(p)
# Out:
# Nadwyzka: 10000.0 Skladka: 1650.0 Liczba ruin: 9796 Średni wynik: 103584.0 Prawd_bankr: 0.009796

# %%
#sprawdzam wyniki symulacji przy większej licznie powtórzeń symulacji
nadwyzka = 10000.0:5000.0:20000.0
skladka = 1300.0:50.0:2000.0
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
LICZBA_POWTORZEN = 1000000
skladka_koncowa = skladka[1]
for nd in nadwyzka, skl in skladka
    wynik = wywolanie(nd, skl, 
            LICZBA_POWTORZEN, LICZBA_KLIENTOW, 
            srednia_liczba_szkod , SR_SZKODA_LN, 
            STD_SZKODA_LN, HORYZONT)
    push!(liczba_ruin, wynik.liczba_ruin)
    push!(prawd_bankr, wynik.p_bankructwa)
    push!(sr_wynik, wynik.sredni_wynik)
    if wynik.p_bankructwa <= 0.01
        println("Nadwyzka: ", nd, " Skladka: ", skl, " Liczba ruin: ", wynik.liczba_ruin, " Średni wynik: ",round(wynik.sredni_wynik), " Prawd_bankr: ", wynik.p_bankructwa)
        break
    end
    skladka_koncowa = skl
end
skladka = skladka[1]:skladka[2]-skladka[1]:skladka_koncowa+skladka[2]-skladka[1]
p=plot(collect(skladka), prawd_bankr, markershape=:circle, ylabel = "Prawdopodobieństwo bankructwa", xlabel = "Wysokość składki", legend = false)
hline!([0.01], color=:red, lw=2, linestyle=:dash)
display(p)
# Out:
# Nadwyzka: 10000.0 Skladka: 1650.0 Liczba ruin: 9796 Średni wynik: 103584.0 Prawd_bankr: 0.009796

# %%
#Dla LICZBA_POWTORZEN = 1 000 000, składka wynosi 1650.0

# %%
#sprawdzam wyniki symulacji przy większej licznie powtórzeń symulacji
nadwyzka = 10000.0:10000.0:10000.0
skladka = 1500.0:50.0:1800.0
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
LICZBA_POWTORZEN = 10000000
skladka_koncowa = skladka[1]
for nd in nadwyzka, skl in skladka
    wynik = wywolanie(nd, skl, 
            LICZBA_POWTORZEN, LICZBA_KLIENTOW, 
            srednia_liczba_szkod , SR_SZKODA_LN, 
            STD_SZKODA_LN, HORYZONT)
    push!(liczba_ruin, wynik.liczba_ruin)
    push!(prawd_bankr, wynik.p_bankructwa)
    push!(sr_wynik, wynik.sredni_wynik)
    if wynik.p_bankructwa <= 0.01
        println("Nadwyzka: ", nd, " Skladka: ", skl, " Liczba ruin: ", wynik.liczba_ruin, " Średni wynik: ",round(wynik.sredni_wynik), " Prawd_bankr: ", wynik.p_bankructwa)
        break
    end
    skladka_koncowa = skl
end
skladka = skladka[1]:skladka[2]-skladka[1]:skladka_koncowa+skladka[2]-skladka[1]
p=plot(collect(skladka), prawd_bankr, markershape=:circle, ylabel = "Prawdopodobieństwo bankructwa", xlabel = "Wysokość składki", legend = false)
hline!([0.01], color=:red, lw=2, linestyle=:dash)
display(p)

# %%
#Dla LICZBA_POWTORZEN = 10 000 000, składka wynosi ...

# %% [markdown]
# # 2. Jaka powinna być nadwyżka i składka, żeby prawdopodobieństwo ruiny było mniejsze niż 0,01? (analiza 2 parametrów)

# %%
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`

# %%
#sprawdzam wyniki symulacji przy większej licznie powtórzeń symulacji
nadwyzka = 10000.0:500:20000.0
skladka = 1000.0:100.0:2000.0
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
LICZBA_POWTORZEN = 10000
skladka_koncowa = skladka[1]
df = DataFrame(c_nadwyzka=Float64[], c_skladka=Float64[], c_prawd_ruiny=Float64[])

for nd in nadwyzka, skl in skladka
    wynik = wywolanie(nd, skl, 
            LICZBA_POWTORZEN, LICZBA_KLIENTOW, 
            srednia_liczba_szkod , SR_SZKODA_LN, 
            STD_SZKODA_LN, HORYZONT)
    push!(liczba_ruin, wynik.liczba_ruin)
    push!(prawd_bankr, wynik.p_bankructwa)
    push!(sr_wynik, wynik.sredni_wynik)
    #heatmap_data = combine(groupby(df, []))
    #end
    skladka_koncowa = skl
    push!(df,[nd, skl, wynik.p_bankructwa])
end

# %%
df
# Out:
# 1111×3 DataFrame
#   Row │ c_nadwyzka  c_skladka  c_prawd_ruiny
#       │ Float64     Float64    Float64
# ──────┼──────────────────────────────────────
#     1 │    10000.0     1000.0         0.1095
#     2 │    10000.0     1100.0         0.0713
#     3 │    10000.0     1200.0         0.0455
#     4 │    10000.0     1300.0         0.0309
#     5 │    10000.0     1400.0         0.021
#     6 │    10000.0     1500.0         0.0141
#     7 │    10000.0     1600.0         0.011
#     8 │    10000.0     1700.0         0.0087
#     9 │    10000.0     1800.0         0.0073
#    10 │    10000.0     1900.0         0.0061
#    11 │    10000.0     2000.0         0.005
#   ⋮   │     ⋮           ⋮            ⋮
#  1102 │    20000.0     1100.0         0.0431
#  1103 │    20000.0     1200.0         0.0283
#  1104 │    20000.0     1300.0         0.0187
#  1105 │    20000.0     1400.0         0.0124
#  1106 │    20000.0     1500.0         0.0091
#  1107 │    20000.0     1600.0         0.0066
#  1108 │    20000.0     1700.0         0.0056
#  1109 │    20000.0     1800.0         0.0044
#  1110 │    20000.0     1900.0         0.0034
#  1111 │    20000.0     2000.0         0.0027
#                             1090 rows omitted

# %%
df = combine(groupby(df, [:c_nadwyzka, :c_skladka]), :c_prawd_ruiny => mean)
# Out:
# 1111×3 DataFrame
#   Row │ c_nadwyzka  c_skladka  c_prawd_ruiny_mean
#       │ Float64     Float64    Float64
# ──────┼───────────────────────────────────────────
#     1 │    10000.0     1000.0              0.1095
#     2 │    10000.0     1100.0              0.0713
#     3 │    10000.0     1200.0              0.0455
#     4 │    10000.0     1300.0              0.0309
#     5 │    10000.0     1400.0              0.021
#     6 │    10000.0     1500.0              0.0141
#     7 │    10000.0     1600.0              0.011
#     8 │    10000.0     1700.0              0.0087
#     9 │    10000.0     1800.0              0.0073
#    10 │    10000.0     1900.0              0.0061
#    11 │    10000.0     2000.0              0.005
#   ⋮   │     ⋮           ⋮              ⋮
#  1102 │    20000.0     1100.0              0.0431
#  1103 │    20000.0     1200.0              0.0283
#  1104 │    20000.0     1300.0              0.0187
#  1105 │    20000.0     1400.0              0.0124
#  1106 │    20000.0     1500.0              0.0091
#  1107 │    20000.0     1600.0              0.0066
#  1108 │    20000.0     1700.0              0.0056
#  1109 │    20000.0     1800.0              0.0044
#  1110 │    20000.0     1900.0              0.0034
#  1111 │    20000.0     2000.0              0.0027
#                                  1090 rows omitted

# %%
z_prob
# Out:
# UndefVarError: z_prob not defined

# %%
reshape(z_prob, length(nadwyzka), length(skladka))
# Out:
# UndefVarError: z_prob not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[31]:1

# %%
#df = combine(groupby(df, [:c_nadwyzka, :c_skladka]), :c_prawd_ruiny => mean) 
df
#df = heatmap_data

# nazwy kolumn 
# x_col = :c_nadwyzka 
# y_col = :c_skladka 
# z_col = :c_prawd_ruiny 

x_col = "Nadwyzka"
y_col = "Skladka"
z_col = "Prawd"

# Binning the data 
x_nadwyzka = collect(nadwyzka)
y_skladka = collect(skladka)
z_prob = df.c_prawd_ruiny_mean
mat = reshape(z_prob, length(y_skladka), length(x_nadwyzka)) 

#heatmap(values, orientation=:vertical, xticks=(1:length(values), values), c=:blues, colorbar=false) 

# Plotting the heatmap 
hmap = Plots.heatmap(x_nadwyzka, y_skladka, mat, xticks=x_nadwyzka, xlabel = string(x_col), ylabel = string(y_col), color = :viridis, grid=true, rotation=90)

display(hmap)

# %%
#Dla nadwyzka = 10000.0:500:50000.0 i skladka = 500.0:500.0:2000.0
df
x_col = "Nadwyzka"
y_col = "Skladka"
z_col = "Prawd"

# Binning the data 
x_nadwyzka = collect(nadwyzka)
y_skladka = collect(skladka)
z_prob = df.c_prawd_ruiny_mean
mat = reshape(z_prob, length(y_skladka), length(x_nadwyzka)) 

# Plotting the heatmap 
plot_size = (800, 600)
hmap = Plots.heatmap(x_nadwyzka, y_skladka, mat, xticks=10000.0:500:20000.0, xlabel = string(x_col), ylabel = string(y_col), color = :viridis, grid=true, rotation=90) 
plot!(legend=false, size=plot_size)
#display(hmap)
gdzie_male_prawd_ruiny = findall(x -> x <= 0.01, mat)
# Get the corresponding x and y values for those indices
x_values = y_skladka[[i[1] for i in gdzie_male_prawd_ruiny]]
y_values = x_nadwyzka[[i[2] for i in gdzie_male_prawd_ruiny]]
scatter!(y_values, x_values, color=:red, marker=:circle)

# %%
gdzie_male_prawd_ruiny = findall(x -> x <= 0.01, mat)
# Out:
# 501-element Vector{CartesianIndex{2}}:
#  CartesianIndex(8, 1)
#  CartesianIndex(9, 1)
#  CartesianIndex(10, 1)
#  CartesianIndex(11, 1)
#  CartesianIndex(8, 2)
#  CartesianIndex(9, 2)
#  CartesianIndex(10, 2)
#  CartesianIndex(11, 2)
#  CartesianIndex(8, 3)
#  CartesianIndex(9, 3)
#  CartesianIndex(10, 3)
#  CartesianIndex(11, 3)
#  CartesianIndex(8, 4)
#  ⋮
#  CartesianIndex(6, 100)
#  CartesianIndex(7, 100)
#  CartesianIndex(8, 100)
#  CartesianIndex(9, 100)
#  CartesianIndex(10, 100)
#  CartesianIndex(11, 100)
#  CartesianIndex(6, 101)
#  CartesianIndex(7, 101)
#  CartesianIndex(8, 101)
#  CartesianIndex(9, 101)
#  CartesianIndex(10, 101)
#  CartesianIndex(11, 101)

# %%
# miejsce na odpowiedź

# %% [markdown]
# # 3. Kiedy nadwyżka końcowa będzie równa początkowej? Oszacuj na podstawie modelu regresji.

# %%
function model(liczba_klientow::S, 
                srednia_liczba_szkod::T, 
                sr_szkoda_ln::T, 
                std_szkoda_ln::T, 
                horyzont::S, 
                nadwyzka::T, 
                skladka::T;
                seed::S=-1) where {T<:AbstractFloat, S<:Int} #domyślna wartość to -1

    # Common Random Numbers aby móc porównać różne scenariusze:
    seed == -1 || Random.seed!(seed) #-1 nie będzie porównywalnosci, trzeba ustawic inne żeby była powtarzalność
    #|| - OR, czyli albo to jest spełnione, albo to po prawej
    #dobrze ustawić ziarno

    # Definiujemy daty umów klientów w symulacji:
    daty_umow = [rand(1:365) for i in 1:liczba_klientow]
    kalendarz_wplat = zeros(Int,365)
    for dataUmowy in daty_umow
        kalendarz_wplat[dataUmowy] += 1
    end
    # Liczymy liczbę szkód przypadających na jednego klienta:
    liczba_szkod_klienta = rand(Poisson(srednia_liczba_szkod),liczba_klientow)
    
    # Ustalamy daty wypłaty dla wszystkich polis:
    kalendarz_wyplat = zeros(Int,365*horyzont) 
    for k in 1:liczba_klientow
        for s in 1:liczba_szkod_klienta[k]
            data_wyplaty = daty_umow[k] + rand(1:365) #symulujemy 1rok polisy, jeden cykl życia polisy
            kalendarz_wyplat[data_wyplaty] += 1
        end
    end
    
    # Analiza wyników firmy dla danego horyzontu czasowego i danych szkód:
    for dzien in 1:365*horyzont
        dzien ≤ 364 && (nadwyzka += kalendarz_wplat[dzien] * skladka)
        liczba_wyplat = kalendarz_wyplat[dzien]
        odszkodowania = sum(exp.(rand(Normal(sr_szkoda_ln,std_szkoda_ln),liczba_wyplat)))
        nadwyzka -= odszkodowania
        nadwyzka ≤ 0 && return nadwyzka #można zakomentować, wtedy nie trzeba wysokiej nadwyżki ustawiać - tylko mozna komentowac dla 3 podejścia
    end
    return nadwyzka
end
# Out:
# model (generic function with 1 method)

# %%
function wywolanie(nadwyzka::T, skladka::T, liczba_powtorzen::S, 
              liczba_klientow::S, srednia_liczba_szkod::T, 
              sr_szkoda_ln::T, std_szkoda_ln::T, horyzont::S) where {T<:AbstractFloat,S<:Int}
    wynik = []
    for seed in 1:liczba_powtorzen
        push!(wynik, model(liczba_klientow, srednia_liczba_szkod, sr_szkoda_ln, std_szkoda_ln, horyzont, nadwyzka, skladka, seed = seed))
    end
    #print(wynik)
    return (liczba_ruin = sum(wynik.<=0), p_bankructwa = sum(wynik.<0)/liczba_powtorzen, sredni_wynik = mean(wynik[wynik.>0])) #wazne w pkt 3 zeby pozwolic sie kręcic po 0
end
# Out:
# wywolanie (generic function with 1 method)

# %%
#sprawdzam wyniki symulacji przy większej licznie powtórzeń symulacji
nadwyzka = 10000.0:10000.0:10000.0
skladka = 1000.0:100.0:2000.0
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
LICZBA_POWTORZEN = 10000
skladka_koncowa = skladka[1]
for nd in nadwyzka, skl in skladka
    wynik = wywolanie(nd, skl, 
            LICZBA_POWTORZEN, LICZBA_KLIENTOW, 
            srednia_liczba_szkod , SR_SZKODA_LN, 
            STD_SZKODA_LN, HORYZONT)
    push!(liczba_ruin, wynik.liczba_ruin)
    push!(prawd_bankr, wynik.p_bankructwa)
    push!(sr_wynik, wynik.sredni_wynik)
    if wynik.p_bankructwa <= 0.01
        println("Nadwyzka: ", nd, " Skladka: ", skl, " Liczba ruin: ", wynik.liczba_ruin, " Średni wynik: ",round(wynik.sredni_wynik), " Prawd_bankr: ", wynik.p_bankructwa)
        break
    end
    skladka_koncowa = skl
end
skladka = skladka[1]:skladka[2]-skladka[1]:skladka_koncowa+skladka[2]-skladka[1]
p=plot(collect(skladka), prawd_bankr, markershape=:circle, ylabel = "Prawdopodobieństwo bankructwa", xlabel = "Wysokość składki", legend = false)
hline!([0.01], color=:red, lw=2, linestyle=:dash)
display(p)

# %%
nadwyzka = 1000000000.0:1000000000.0:1000000000.0
skladka = 100.0:0.5:50000.0
LICZBA_POWTORZEN = 100
skladka_target = zero(eltype(skladka))
for nd in nadwyzka, skl in skladka
    wynik = wywolanie(nd, skl, LICZBA_POWTORZEN, LICZBA_KLIENTOW, srednia_liczba_szkod, SR_SZKODA_LN, STD_SZKODA_LN, HORYZONT)
    if wynik.sredni_wynik > nadwyzka[1]
        print(wynik.sredni_wynik, nadwyzka[1])
        skladka_target = skl
        #println(skl)
        #break
    end
end
println(skladka_target)
# Out:
# 1.000000012183205e91.0e9718.5
# 1.000000062053205e91.0e9719.0
# 1.0000001119232049e91.0e9719.5
# 1.0000001617932049e91.0e9720.0
# 1.0000002116632049e91.0e9720.5
# 1.0000002615332049e91.0e9721.0
# 1.0000003114032049e91.0e9721.5
# 1.0000003612732049e91.0e9722.0
# 1.0000004111432049e91.0e9722.5
# 1.0000004610132049e91.0e9723.0
# 1.0000005108832049e91.0e9723.5
# 1.000000560753205e91.0e9724.0
# 1.000000610623205e91.0e9724.5
# 1.000000660493205e91.0e9725.0
# 1.000000710363205e91.0e9725.5
# 1.000000760233205e91.0e9726.0
# 1.000000810103205e91.0e9726.5
# 1.000000859973205e91.0e9727.0
# 1.000000909843205e91.0e9727.5
# 1.000000959713205e91.0e9728.0
# 1.000001009583205e91.0e9728.5
# 1.000001059453205e91.0e9729.0
# 1.000001109323205e91.0e9729.5
# 1.000001159193205e91.0e9730.0
# 1.000001209063205e91.0e9730.5
# 1.000001258933205e91.0e9731.0
# 1.000001308803205e91.0e9731.5
# 1.0000013586732049e91.0e9732.0
# 1.0000014085432049e91.0e9732.5
# 1.0000014584132049e91.0e9733.0
# 1.0000015082832049e91.0e9733.5
# 1.0000015581532049e91.0e9734.0
# 1.0000016080232049e91.0e9734.5
# 1.0000016578932049e91.0e9735.0
# 1.0000017077632049e91.0e9735.5
# 1.0000017576332049e91.0e9736.0
# 1.000001807503205e91.0e9736.5
# 1.000001857373205e91.0e9737.0
# 1.000001907243205e91.0e9737.5
# 1.000001957113205e91.0e9738.0
# 1.000002006983205e91.0e9738.5
# 1.000002056853205e91.0e9739.0
# 1.000002106723205e91.0e9739.5
# 1.000002156593205e91.0e9740.0
# 1.000002206463205e91.0e9740.5
# 1.000002256333205e91.0e9741.0
# 1.000002306203205e91.0e9741.5
# 1.000002356073205e91.0e9742.0
# 1.000002405943205e91.0e9742.5
# 1.000002455813205e91.0e9743.0
# 1.000002505683205e91.0e9743.5
# 1.000002555553205e91.0e9744.0
# 1.0000026054232049e91.0e9744.5
# 1.0000026552932049e91.0e9745.0
# 1.0000027051632049e91.0e9745.5
# 1.0000027550332049e91.0e9746.0
# 1.0000028049032049e91.0e9746.5
# 1.0000028547732049e91.0e9747.0
# 1.0000029046432049e91.0e9747.5
# 1.0000029545132049e91.0e9748.0
# 1.0000030043832049e91.0e9748.5
# 1.000003054253205e91.0e9749.0
# 1.000003104123205e91.0e9749.5
# 1.000003153993205e91.0e9750.0
# 1.000003203863205e91.0e9750.5
# 1.000003253733205e91.0e9751.0
# 1.000003303603205e91.0e9751.5
# 1.000003353473205e91.0e9752.0
# 1.000003403343205e91.0e9752.5
# 1.000003453213205e91.0e9753.0
# 1.000003503083205e91.0e9753.5
# 1.000003552953205e91.0e9754.0
# 1.000003602823205e91.0e9754.5
# 1.000003652693205e91.0e9755.0
# 1.000003702563205e91.0e9755.5
# 1.000003752433205e91.0e9756.0
# 1.000003802303205e91.0e9756.5
# 1.0000038521732049e91.0e9757.0
# 1.0000039020432049e91.0e9757.5
# 1.0000039519132049e91.0e9758.0
# 1.0000040017832049e91.0e9758.5
# 1.0000040516532049e91.0e9759.0
# 1.0000041015232049e91.0e9759.5
# 1.0000041513932049e91.0e9760.0
# 1.0000042012632049e91.0e9760.5
# 1.0000042511332049e91.0e9761.0
# 1.000004301003205e91.0e9761.5
# 1.000004350873205e91.0e9762.0
# 1.000004400743205e91.0e9762.5
# 1.000004450613205e91.0e9763.0
# 1.000004500483205e91.0e9763.5
# 1.000004550353205e91.0e9764.0
# 1.000004600223205e91.0e9764.5
# 1.000004650093205e91.0e9765.0
# 1.000004699963205e91.0e9765.5
# 1.000004749833205e91.0e9766.0
# 1.000004799703205e91.0e9766.5
# 1.000004849573205e91.0e9767.0
# 1.000004899443205e91.0e9767.5
# 1.000004949313205e91.0e9768.0
# 1.000004999183205e91.0e9768.5
# 1.000005049053205e91.0e9769.0
# 1.0000050989232049e91.0e9769.5
# 1.0000051487932049e91.0e9770.0
# 1.0000051986632049e91.0e9770.5
# 1.0000052485332049e91.0e9771.0
# 1.0000052984032049e91.0e9771.5
# 1.0000053482732049e91.0e9772.0
# 1.0000053981432049e91.0e9772.5
# 1.0000054480132049e91.0e9773.0
# 1.0000054978832049e91.0e9773.5
# 1.000005547753205e91.0e9774.0
# 1.000005597623205e91.0e9774.5
# 1.000005647493205e91.0e9775.0
# 1.000005697363205e91.0e9775.5
# 1.000005747233205e91.0e9776.0
# 1.000005797103205e91.0e9776.5
# 1.000005846973205e91.0e9777.0
# 1.000005896843205e91.0e9777.5
# 1.000005946713205e91.0e9778.0
# 1.000005996583205e91.0e9778.5
# 1.000006046453205e91.0e9779.0
# 1.000006096323205e91.0e9779.5
# 1.000006146193205e91.0e9780.0
# 1.000006196063205e91.0e9780.5
# 1.000006245933205e91.0e9781.0
# 1.000006295803205e91.0e9781.5
# 1.0000063456732049e91.0e9782.0
# 1.0000063955432049e91.0e9782.5
# 1.0000064454132049e91.0e9783.0
# 1.0000064952832049e91.0e9783.5
# 1.0000065451532049e91.0e9784.0
# 1.0000065950232049e91.0e9784.5
# 1.0000066448932049e91.0e9785.0
# 1.0000066947632049e91.0e9785.5
# 1.0000067446332049e91.0e9786.0
# 1.000006794503205e91.0e9786.5
# 1.000006844373205e91.0e9787.0
# 1.000006894243205e91.0e9787.5
# 1.000006944113205e91.0e9788.0
# 1.000006993983205e91.0e9788.5
# 1.000007043853205e91.0e9789.0
# 1.000007093723205e91.0e9789.5
# 1.000007143593205e91.0e9790.0
# 1.000007193463205e91.0e9790.5
# 1.000007243333205e91.0e9791.0
# 1.000007293203205e91.0e9791.5
# 1.000007343073205e91.0e9792.0
# 1.000007392943205e91.0e9792.5
# 1.000007442813205e91.0e9793.0
# 1.000007492683205e91.0e9793.5
# 1.000007542553205e91.0e9794.0
# 1.0000075924232049e91.0e9794.5
# 1.0000076422932049e91.0e9795.0
# 1.0000076921632049e91.0e9795.5
# 1.0000077420332049e91.0e9796.0
# 1.0000077919032049e91.0e9796.5
# 1.0000078417732049e91.0e9797.0
# 1.0000078916432049e91.0e9797.5
# 1.0000079415132049e91.0e9798.0
# 1.0000079913832049e91.0e9798.5
# 1.000008041253205e91.0e9799.0
# 1.000008091123205e91.0e9799.5
# 1.000008140993205e91.0e9800.0
# 1.000008190863205e91.0e9800.5
# 1.000008240733205e91.0e9801.0
# 1.000008290603205e91.0e9801.5
# 1.000008340473205e91.0e9802.0
# 1.000008390343205e91.0e9802.5
# 1.000008440213205e91.0e9803.0
# 1.000008490083205e91.0e9803.5
# 1.000008539953205e91.0e9804.0
# 1.000008589823205e91.0e9804.5
# 1.000008639693205e91.0e9805.0
# 1.000008689563205e91.0e9805.5
# 1.000008739433205e91.0e9806.0
# 1.000008789303205e91.0e9806.5
# 1.0000088391732049e91.0e9807.0
# 1.0000088890432049e91.0e9807.5
# 1.0000089389132049e91.0e9808.0
# 1.0000089887832049e91.0e9808.5
# 1.0000090386532049e91.0e9809.0
# 1.0000090885232049e91.0e9809.5
# 1.0000091383932049e91.0e9810.0
# 1.0000091882632049e91.0e9810.5
# 1.0000092381332049e91.0e9811.0
# 1.000009288003205e91.0e9811.5
# 1.000009337873205e91.0e9812.0
# 1.000009387743205e91.0e9812.5
# 1.000009437613205e91.0e9813.0
# 1.000009487483205e91.0e9813.5
# 1.000009537353205e91.0e9814.0
# 1.000009587223205e91.0e9814.5
# 1.000009637093205e91.0e9815.0
# 1.000009686963205e91.0e9815.5
# 1.000009736833205e91.0e9816.0
# 1.000009786703205e91.0e9816.5
# 1.000009836573205e91.0e9817.0
# 1.000009886443205e91.0e9817.5
# 1.000009936313205e91.0e9818.0
# 1.000009986183205e91.0e9818.5
# 1.000010036053205e91.0e9819.0
# 1.0000100859232049e91.0e9819.5
# 1.0000101357932049e91.0e9820.0
# 1.0000101856632049e91.0e9820.5
# 1.0000102355332049e91.0e9821.0
# 1.0000102854032049e91.0e9821.5
# 1.0000103352732049e91.0e9822.0
# 1.0000103851432049e91.0e9822.5
# 1.0000104350132049e91.0e9823.0
# 1.0000104848832049e91.0e9823.5
# 1.000010534753205e91.0e9824.0
# 1.000010584623205e91.0e9824.5
# 1.000010634493205e91.0e9825.0
# 1.000010684363205e91.0e9825.5
# 1.000010734233205e91.0e9826.0
# 1.000010784103205e91.0e9826.5
# 1.000010833973205e91.0e9827.0
# 1.000010883843205e91.0e9827.5
# 1.000010933713205e91.0e9828.0
# 1.000010983583205e91.0e9828.5
# 1.000011033453205e91.0e9829.0
# 1.000011083323205e91.0e9829.5
# 1.000011133193205e91.0e9830.0
# 1.000011183063205e91.0e9830.5
# 1.000011232933205e91.0e9831.0
# 1.000011282803205e91.0e9831.5
# 1.0000113326732049e91.0e9832.0
# 1.0000113825432049e91.0e9832.5
# 1.0000114324132049e91.0e9833.0
# 1.0000114822832049e91.0e9833.5
# 1.0000115321532049e91.0e9834.0
# 1.0000115820232049e91.0e9834.5
# 1.0000116318932049e91.0e9835.0
# 1.0000116817632049e91.0e9835.5
# 1.0000117316332049e91.0e9836.0
# 1.000011781503205e91.0e9836.5
# 1.000011831373205e91.0e9837.0
# 1.000011881243205e91.0e9837.5
# 1.000011931113205e91.0e9838.0
# 1.000011980983205e91.0e9838.5
# 1.000012030853205e91.0e9839.0
# 1.000012080723205e91.0e9839.5
# 1.000012130593205e91.0e9840.0
# 1.000012180463205e91.0e9840.5
# 1.000012230333205e91.0e9841.0
# 1.000012280203205e91.0e9841.5
# 1.000012330073205e91.0e9842.0
# 1.000012379943205e91.0e9842.5
# 1.000012429813205e91.0e9843.0
# 1.000012479683205e91.0e9843.5
# 1.000012529553205e91.0e9844.0
# 1.0000125794232049e91.0e9844.5
# 1.0000126292932049e91.0e9845.0
# 1.0000126791632049e91.0e9845.5
# 1.0000127290332049e91.0e9846.0
# 1.0000127789032049e91.0e9846.5
# 1.0000128287732049e91.0e9847.0
# 1.0000128786432049e91.0e9847.5
# 1.0000129285132049e91.0e9848.0
# 1.0000129783832049e91.0e9848.5
# 1.000013028253205e91.0e9849.0
# 1.000013078123205e91.0e9849.5
# 1.000013127993205e91.0e9850.0
# 1.000013177863205e91.0e9850.5
# 1.000013227733205e91.0e9851.0
# 1.000013277603205e91.0e9851.5
# 1.000013327473205e91.0e9852.0
# 1.000013377343205e91.0e9852.5
# 1.000013427213205e91.0e9853.0
# 1.000013477083205e91.0e9853.5
# 1.000013526953205e91.0e9854.0
# 1.000013576823205e91.0e9854.5
# 1.000013626693205e91.0e9855.0
# 1.000013676563205e91.0e9855.5
# 1.000013726433205e91.0e9856.0
# 1.000013776303205e91.0e9856.5
# 1.0000138261732049e91.0e9857.0
# 1.0000138760432049e91.0e9857.5
# 1.0000139259132049e91.0e9858.0
# 1.0000139757832049e91.0e9858.5
# 1.0000140256532049e91.0e9859.0
# 1.0000140755232049e91.0e9859.5
# 1.0000141253932049e91.0e9860.0
# 1.0000141752632049e91.0e9860.5
# 1.0000142251332049e91.0e9861.0
# 1.000014275003205e91.0e9861.5
# 1.000014324873205e91.0e9862.0
# 1.000014374743205e91.0e9862.5
# 1.000014424613205e91.0e9863.0
# 1.000014474483205e91.0e9863.5
# 1.000014524353205e91.0e9864.0
# 1.000014574223205e91.0e9864.5
# 1.000014624093205e91.0e9865.0
# 1.000014673963205e91.0e9865.5
# 1.000014723833205e91.0e9866.0
# 1.000014773703205e91.0e9866.5
# 1.000014823573205e91.0e9867.0
# 1.000014873443205e91.0e9867.5
# 1.000014923313205e91.0e9868.0
# 1.000014973183205e91.0e9868.5
# 1.000015023053205e91.0e9869.0
# 1.0000150729232049e91.0e9869.5
# 1.0000151227932049e91.0e9870.0
# 1.0000151726632049e91.0e9870.5
# 1.0000152225332049e91.0e9871.0
# 1.0000152724032049e91.0e9871.5
# 1.0000153222732049e91.0e9872.0
# 1.0000153721432049e91.0e9872.5
# 1.0000154220132049e91.0e9873.0
# 1.0000154718832049e91.0e9873.5
# 1.000015521753205e91.0e9874.0
# 1.000015571623205e91.0e9874.5
# 1.000015621493205e91.0e9875.0
# 1.000015671363205e91.0e9875.5
# 1.000015721233205e91.0e9876.0
# 1.000015771103205e91.0e9876.5
# 1.000015820973205e91.0e9877.0
# 1.000015870843205e91.0e9877.5
# 1.000015920713205e91.0e9878.0
# 1.000015970583205e91.0e9878.5
# 1.000016020453205e91.0e9879.0
# 1.000016070323205e91.0e9879.5
# 1.000016120193205e91.0e9880.0
# 1.000016170063205e91.0e9880.5
# 1.000016219933205e91.0e9881.0
# 1.000016269803205e91.0e9881.5
# 1.0000163196732049e91.0e9882.0
# 1.0000163695432049e91.0e9882.5
# 1.0000164194132049e91.0e9883.0
# 1.0000164692832049e91.0e9883.5
# 1.0000165191532049e91.0e9884.0
# 1.0000165690232049e91.0e9884.5
# 1.0000166188932049e91.0e9885.0
# 1.0000166687632049e91.0e9885.5
# 1.0000167186332049e91.0e9886.0
# 1.000016768503205e91.0e9886.5
# 1.000016818373205e91.0e9887.0
# 1.000016868243205e91.0e9887.5
# 1.000016918113205e91.0e9888.0
# 1.000016967983205e91.0e9888.5
# 1.000017017853205e91.0e9889.0
# 1.000017067723205e91.0e9889.5
# 1.000017117593205e91.0e9890.0
# 1.000017167463205e91.0e9890.5
# 1.000017217333205e91.0e9891.0
# 1.000017267203205e91.0e9891.5
# 1.000017317073205e91.0e9892.0
# 1.000017366943205e91.0e9892.5
# 1.000017416813205e91.0e9893.0
# 1.000017466683205e91.0e9893.5
# 1.000017516553205e91.0e9894.0
# 1.0000175664232049e91.0e9894.5
# 1.0000176162932049e91.0e9895.0
# 1.0000176661632049e91.0e9895.5
# 1.0000177160332049e91.0e9896.0
# 1.0000177659032049e91.0e9896.5
# 1.0000178157732049e91.0e9897.0
# 1.0000178656432049e91.0e9897.5
# 1.0000179155132049e91.0e9898.0
# 1.0000179653832049e91.0e9898.5
# 1.000018015253205e91.0e9899.0
# 1.000018065123205e91.0e9899.5
# 1.000018114993205e91.0e9900.0
# 1.000018164863205e91.0e9900.5
# 1.000018214733205e91.0e9901.0
# 1.000018264603205e91.0e9901.5
# 1.000018314473205e91.0e9902.0
# 1.000018364343205e91.0e9902.5
# 1.000018414213205e91.0e9903.0
# 1.000018464083205e91.0e9903.5
# 1.000018513953205e91.0e9904.0
# 1.000018563823205e91.0e9904.5
# 1.000018613693205e91.0e9905.0
# 1.000018663563205e91.0e9905.5
# 1.000018713433205e91.0e9906.0
# 1.000018763303205e91.0e9906.5
# 1.0000188131732049e91.0e9907.0
# 1.0000188630432049e91.0e9907.5
# 1.0000189129132049e91.0e9908.0
# 1.0000189627832049e91.0e9908.5
# 1.0000190126532049e91.0e9909.0
# 1.0000190625232049e91.0e9909.5
# 1.0000191123932049e91.0e9910.0
# 1.0000191622632049e91.0e9910.5
# 1.0000192121332049e91.0e9911.0
# 1.000019262003205e91.0e9911.5
# 1.000019311873205e91.0e9912.0
# 1.000019361743205e91.0e9912.5
# 1.000019411613205e91.0e9913.0
# 1.000019461483205e91.0e9913.5
# 1.000019511353205e91.0e9914.0
# 1.000019561223205e91.0e9914.5
# 1.000019611093205e91.0e9915.0
# 1.000019660963205e91.0e9915.5
# 1.000019710833205e91.0e9916.0
# 1.000019760703205e91.0e9916.5
# 1.000019810573205e91.0e9917.0
# 1.000019860443205e91.0e9917.5
# 1.000019910313205e91.0e9918.0
# 1.000019960183205e91.0e9918.5
# 1.000020010053205e91.0e9919.0
# 1.0000200599232049e91.0e9919.5
# 1.0000201097932049e91.0e9920.0
# 1.0000201596632049e91.0e9920.5
# 1.0000202095332049e91.0e9921.0
# 1.0000202594032049e91.0e9921.5
# 1.0000203092732049e91.0e9922.0
# 1.0000203591432049e91.0e9922.5
# 1.0000204090132049e91.0e9923.0
# 1.0000204588832049e91.0e9923.5
# 1.000020508753205e91.0e9924.0
# 1.000020558623205e91.0e9924.5
# 1.000020608493205e91.0e9925.0
# 1.000020658363205e91.0e9925.5
# 1.000020708233205e91.0e9926.0
# 1.000020758103205e91.0e9926.5
# 1.000020807973205e91.0e9927.0
# 1.000020857843205e91.0e9927.5
# 1.000020907713205e91.0e9928.0
# 1.000020957583205e91.0e9928.5
# 1.000021007453205e91.0e9929.0
# 1.000021057323205e91.0e9929.5
# 1.000021107193205e91.0e9930.0
# 1.000021157063205e91.0e9930.5
# 1.000021206933205e91.0e9931.0
# 1.000021256803205e91.0e9931.5
# 1.0000213066732049e91.0e9932.0
# 1.0000213565432049e91.0e9932.5
# 1.0000214064132049e91.0e9933.0
# 1.0000214562832049e91.0e9933.5
# 1.0000215061532049e91.0e9934.0
# 1.0000215560232049e91.0e9934.5
# 1.0000216058932049e91.0e9935.0
# 1.0000216557632049e91.0e9935.5
# 1.0000217056332049e91.0e9936.0
# 1.000021755503205e91.0e9936.5
# 1.000021805373205e91.0e9937.0
# 1.000021855243205e91.0e9937.5
# 1.000021905113205e91.0e9938.0
# 1.000021954983205e91.0e9938.5
# 1.000022004853205e91.0e9939.0
# 1.000022054723205e91.0e9939.5
# 1.000022104593205e91.0e9940.0
# 1.000022154463205e91.0e9940.5
# 1.000022204333205e91.0e9941.0
# 1.000022254203205e91.0e9941.5
# 1.000022304073205e91.0e9942.0
# 1.000022353943205e91.0e9942.5
# 1.000022403813205e91.0e9943.0
# 1.000022453683205e91.0e9943.5
# 1.000022503553205e91.0e9944.0
# 1.0000225534232049e91.0e9944.5
# 1.0000226032932049e91.0e9945.0
# 1.0000226531632049e91.0e9945.5
# 1.0000227030332049e91.0e9946.0
# 1.0000227529032049e91.0e9946.5
# 1.0000228027732049e91.0e9947.0
# 1.0000228526432049e91.0e9947.5
# 1.0000229025132049e91.0e9948.0
# 1.0000229523832049e91.0e9948.5
# 1.000023002253205e91.0e9949.0
# 1.000023052123205e91.0e9949.5
# 1.000023101993205e91.0e9950.0
# 1.000023151863205e91.0e9950.5
# 1.000023201733205e91.0e9951.0
# 1.000023251603205e91.0e9951.5
# 1.000023301473205e91.0e9952.0
# 1.000023351343205e91.0e9952.5
# 1.000023401213205e91.0e9953.0
# 1.000023451083205e91.0e9953.5
# 1.000023500953205e91.0e9954.0
# 1.000023550823205e91.0e9954.5
# 1.000023600693205e91.0e9955.0
# 1.000023650563205e91.0e9955.5
# 1.000023700433205e91.0e9956.0
# 1.000023750303205e91.0e9956.5
# 1.0000238001732049e91.0e9957.0
# 1.0000238500432049e91.0e9957.5
# 1.0000238999132049e91.0e9958.0
# 1.0000239497832049e91.0e9958.5
# 1.0000239996532049e91.0e9959.0
# 1.0000240495232049e91.0e9959.5
# 1.0000240993932049e91.0e9960.0
# 1.0000241492632049e91.0e9960.5
# 1.0000241991332049e91.0e9961.0
# 1.000024249003205e91.0e9961.5
# 1.000024298873205e91.0e9962.0
# 1.000024348743205e91.0e9962.5
# 1.000024398613205e91.0e9963.0
# 1.000024448483205e91.0e9963.5
# 1.000024498353205e91.0e9964.0
# 1.000024548223205e91.0e9964.5
# 1.000024598093205e91.0e9965.0
# 1.000024647963205e91.0e9965.5
# 1.000024697833205e91.0e9966.0
# 1.000024747703205e91.0e9966.5
# 1.000024797573205e91.0e9967.0
# 1.000024847443205e91.0e9967.5
# 1.000024897313205e91.0e9968.0
# 1.000024947183205e91.0e9968.5
# 1.000024997053205e91.0e9969.0
# 1.0000250469232049e91.0e9969.5
# 1.0000250967932049e91.0e9970.0
# 1.0000251466632049e91.0e9970.5
# 1.0000251965332049e91.0e9971.0
# 1.0000252464032049e91.0e9971.5
# 1.0000252962732049e91.0e9972.0
# 1.0000253461432049e91.0e9972.5
# 1.0000253960132049e91.0e9973.0
# 1.0000254458832049e91.0e9973.5
# 1.000025495753205e91.0e9974.0
# 1.000025545623205e91.0e9974.5
# 1.000025595493205e91.0e9975.0
# 1.000025645363205e91.0e9975.5
# 1.000025695233205e91.0e9976.0
# 1.000025745103205e91.0e9976.5
# 1.000025794973205e91.0e9977.0
# 1.000025844843205e91.0e9977.5
# 1.000025894713205e91.0e9978.0
# 1.000025944583205e91.0e9978.5
# 1.000025994453205e91.0e9979.0
# 1.000026044323205e91.0e9979.5
# 1.000026094193205e91.0e9980.0
# 1.000026144063205e91.0e9980.5
# 1.000026193933205e91.0e9981.0
# 1.000026243803205e91.0e9981.5
# 1.0000262936732049e91.0e9982.0
# 1.0000263435432049e91.0e9982.5
# 1.0000263934132049e91.0e9983.0
# 1.0000264432832049e91.0e9983.5
# 1.0000264931532049e91.0e9984.0
# 1.0000265430232049e91.0e9984.5
# 1.0000265928932049e91.0e9985.0
# 1.0000266427632049e91.0e9985.5
# 1.0000266926332049e91.0e9986.0
# 1.000026742503205e91.0e9986.5
# 1.000026792373205e91.0e9987.0
# 1.000026842243205e91.0e9987.5
# 1.000026892113205e91.0e9988.0
# 1.000026941983205e91.0e9988.5
# 1.000026991853205e91.0e9989.0
# 1.000027041723205e91.0e9989.5
# 1.000027091593205e91.0e9990.0
# 1.000027141463205e91.0e9990.5
# 1.000027191333205e91.0e9991.0
# 1.000027241203205e91.0e9991.5
# 1.000027291073205e91.0e9992.0
# 1.000027340943205e91.0e9992.5
# 1.000027390813205e91.0e9993.0
# 1.000027440683205e91.0e9993.5
# 1.000027490553205e91.0e9994.0
# 1.0000275404232049e91.0e9994.5
# 1.0000275902932049e91.0e9995.0
# 1.0000276401632049e91.0e9995.5
# 1.0000276900332049e91.0e9996.0
# 1.0000277399032049e91.0e9996.5
# 1.0000277897732049e91.0e9997.0
# 1.0000278396432049e91.0e9997.5
# 1.0000278895132049e91.0e9998.0
# 1.0000279393832049e91.0e9998.5
# 1.000027989253205e91.0e9999.0
# 1.000028039123205e91.0e9999.5
# 1.000028088993205e91.0e91000.0
# 1.000028138863205e91.0e91000.5
# 1.000028188733205e91.0e91001.0
# 1.000028238603205e91.0e91001.5
# 1.000028288473205e91.0e91002.0
# 1.000028338343205e91.0e91002.5
# 1.000028388213205e91.0e91003.0
# 1.000028438083205e91.0e91003.5
# 1.000028487953205e91.0e91004.0
# 1.000028537823205e91.0e91004.5
# 1.000028587693205e91.0e91005.0
# 1.000028637563205e91.0e91005.5
# 1.000028687433205e91.0e91006.0
# 1.000028737303205e91.0e91006.5
# 1.0000287871732049e91.0e91007.0
# 1.0000288370432049e91.0e91007.5
# 1.0000288869132049e91.0e91008.0
# 1.0000289367832049e91.0e91008.5
# 1.0000289866532049e91.0e91009.0
# 1.0000290365232049e91.0e91009.5
# 1.0000290863932049e91.0e91010.0
# 1.0000291362632049e91.0e91010.5
# 1.0000291861332049e91.0e91011.0
# 1.000029236003205e91.0e91011.5
# 1.000029285873205e91.0e91012.0
# 1.000029335743205e91.0e91012.5
# 1.000029385613205e91.0e91013.0
# 1.000029435483205e91.0e91013.5
# 1.000029485353205e91.0e91014.0
# 1.000029535223205e91.0e91014.5
# 1.000029585093205e91.0e91015.0
# 1.000029634963205e91.0e91015.5
# 1.000029684833205e91.0e91016.0
# 1.000029734703205e91.0e91016.5
# 1.000029784573205e91.0e91017.0
# 1.000029834443205e91.0e91017.5
# 1.000029884313205e91.0e91018.0
# 1.000029934183205e91.0e91018.5
# 1.000029984053205e91.0e91019.0
# 1.0000300339232049e91.0e91019.5
# 1.0000300837932049e91.0e91020.0
# 1.0000301336632049e91.0e91020.5
# 1.0000301835332049e91.0e91021.0
# 1.0000302334032049e91.0e91021.5
# 1.0000302832732049e91.0e91022.0
# 1.0000303331432049e91.0e91022.5
# 1.0000303830132049e91.0e91023.0
# 1.0000304328832049e91.0e91023.5
# 1.000030482753205e91.0e91024.0
# 1.000030532623205e91.0e91024.5
# 1.000030582493205e91.0e91025.0
# 1.000030632363205e91.0e91025.5
# 1.000030682233205e91.0e91026.0
# 1.000030732103205e91.0e91026.5
# 1.000030781973205e91.0e91027.0
# 1.000030831843205e91.0e91027.5
# 1.000030881713205e91.0e91028.0
# 1.000030931583205e91.0e91028.5
# 1.000030981453205e91.0e91029.0
# 1.000031031323205e91.0e91029.5
# 1.000031081193205e91.0e91030.0
# 1.000031131063205e91.0e91030.5
# 1.000031180933205e91.0e91031.0
# 1.000031230803205e91.0e91031.5
# 1.0000312806732049e91.0e91032.0
# 1.0000313305432049e91.0e91032.5
# 1.0000313804132049e91.0e91033.0
# 1.0000314302832049e91.0e91033.5
# 1.0000314801532049e91.0e91034.0
# 1.0000315300232049e91.0e91034.5
# 1.0000315798932049e91.0e91035.0
# 1.0000316297632049e91.0e91035.5
# 1.0000316796332049e91.0e91036.0
# 1.000031729503205e91.0e91036.5
# 1.000031779373205e91.0e91037.0
# 1.000031829243205e91.0e91037.5
# 1.000031879113205e91.0e91038.0
# 1.000031928983205e91.0e91038.5
# 1.000031978853205e91.0e91039.0
# 1.000032028723205e91.0e91039.5
# 1.000032078593205e91.0e91040.0
# 1.000032128463205e91.0e91040.5
# 1.000032178333205e91.0e91041.0
# 1.000032228203205e91.0e91041.5
# 1.000032278073205e91.0e91042.0
# 1.000032327943205e91.0e91042.5
# 1.000032377813205e91.0e91043.0
# 1.000032427683205e91.0e91043.5
# 1.000032477553205e91.0e91044.0
# 1.0000325274232049e91.0e91044.5
# 1.0000325772932049e91.0e91045.0
# 1.0000326271632049e91.0e91045.5
# 1.0000326770332049e91.0e91046.0
# 1.0000327269032049e91.0e91046.5
# 1.0000327767732049e91.0e91047.0
# 1.0000328266432049e91.0e91047.5
# 1.0000328765132049e91.0e91048.0
# 1.0000329263832049e91.0e91048.5
# 1.000032976253205e91.0e91049.0
# 1.000033026123205e91.0e91049.5
# 1.000033075993205e91.0e91050.0
# 1.000033125863205e91.0e91050.5
# 1.000033175733205e91.0e91051.0
# 1.000033225603205e91.0e91051.5
# 1.000033275473205e91.0e91052.0
# 1.000033325343205e91.0e91052.5
# 1.000033375213205e91.0e91053.0
# 1.000033425083205e91.0e91053.5
# 1.000033474953205e91.0e91054.0
# 1.000033524823205e91.0e91054.5
# 1.000033574693205e91.0e91055.0
# 1.000033624563205e91.0e91055.5
# 1.000033674433205e91.0e91056.0
# 1.000033724303205e91.0e91056.5
# 1.0000337741732049e91.0e91057.0
# 1.0000338240432049e91.0e91057.5
# 1.0000338739132049e91.0e91058.0
# 1.0000339237832049e91.0e91058.5
# 1.0000339736532049e91.0e91059.0
# 1.0000340235232049e91.0e91059.5
# 1.0000340733932049e91.0e91060.0
# 1.0000341232632049e91.0e91060.5
# 1.0000341731332049e91.0e91061.0
# 1.000034223003205e91.0e91061.5
# 1.000034272873205e91.0e91062.0
# 1.000034322743205e91.0e91062.5
# 1.000034372613205e91.0e91063.0
# 1.000034422483205e91.0e91063.5
# 1.000034472353205e91.0e91064.0
# 1.000034522223205e91.0e91064.5
# 1.000034572093205e91.0e91065.0
# 1.000034621963205e91.0e91065.5
# 1.000034671833205e91.0e91066.0
# 1.000034721703205e91.0e91066.5
# 1.000034771573205e91.0e91067.0
# 1.000034821443205e91.0e91067.5
# 1.000034871313205e91.0e91068.0
# 1.000034921183205e91.0e91068.5
# 1.000034971053205e91.0e91069.0
# 1.0000350209232049e91.0e91069.5
# 1.0000350707932049e91.0e91070.0
# 1.0000351206632049e91.0e91070.5
# 1.0000351705332049e91.0e91071.0
# 1.0000352204032049e91.0e91071.5
# 1.0000352702732049e91.0e91072.0
# 1.0000353201432049e91.0e91072.5
# 1.0000353700132049e91.0e91073.0
# 1.0000354198832049e91.0e91073.5
# 1.000035469753205e91.0e91074.0
# 1.000035519623205e91.0e91074.5
# 1.000035569493205e91.0e91075.0
# 1.000035619363205e91.0e91075.5
# 1.000035669233205e91.0e91076.0
# 1.000035719103205e91.0e91076.5
# 1.000035768973205e91.0e91077.0
# 1.000035818843205e91.0e91077.5
# 1.000035868713205e91.0e91078.0
# 1.000035918583205e91.0e91078.5
# 1.000035968453205e91.0e91079.0
# 1.000036018323205e91.0e91079.5
# 1.000036068193205e91.0e91080.0
# 1.000036118063205e91.0e91080.5
# 1.000036167933205e91.0e91081.0
# 1.000036217803205e91.0e91081.5
# 1.0000362676732049e91.0e91082.0
# 1.0000363175432049e91.0e91082.5
# 1.0000363674132049e91.0e91083.0
# 1.0000364172832049e91.0e91083.5
# 1.0000364671532049e91.0e91084.0
# 1.0000365170232049e91.0e91084.5
# 1.0000365668932049e91.0e91085.0
# 1.0000366167632049e91.0e91085.5
# 1.0000366666332049e91.0e91086.0
# 1.000036716503205e91.0e91086.5
# 1.000036766373205e91.0e91087.0
# 1.000036816243205e91.0e91087.5
# 1.000036866113205e91.0e91088.0
# 1.000036915983205e91.0e91088.5
# 1.000036965853205e91.0e91089.0
# 1.000037015723205e91.0e91089.5
# 1.000037065593205e91.0e91090.0
# 1.000037115463205e91.0e91090.5
# 1.000037165333205e91.0e91091.0
# 1.000037215203205e91.0e91091.5
# 1.000037265073205e91.0e91092.0
# 1.000037314943205e91.0e91092.5
# 1.000037364813205e91.0e91093.0
# 1.000037414683205e91.0e91093.5
# 1.000037464553205e91.0e91094.0
# 1.0000375144232049e91.0e91094.5
# 1.0000375642932049e91.0e91095.0
# 1.0000376141632049e91.0e91095.5
# 1.0000376640332049e91.0e91096.0
# 1.0000377139032049e91.0e91096.5
# 1.0000377637732049e91.0e91097.0
# 1.0000378136432049e91.0e91097.5
# 1.0000378635132049e91.0e91098.0
# 1.0000379133832049e91.0e91098.5
# 1.000037963253205e91.0e91099.0
# 1.000038013123205e91.0e91099.5
# 1.000038062993205e91.0e91100.0
# 1.000038112863205e91.0e91100.5
# 1.000038162733205e91.0e91101.0
# 1.000038212603205e91.0e91101.5
# 1.000038262473205e91.0e91102.0
# 1.000038312343205e91.0e91102.5
# 1.000038362213205e91.0e91103.0
# 1.000038412083205e91.0e91103.5
# 1.000038461953205e91.0e91104.0
# 1.000038511823205e91.0e91104.5
# 1.000038561693205e91.0e91105.0
# 1.000038611563205e91.0e91105.5
# 1.000038661433205e91.0e91106.0
# 1.000038711303205e91.0e91106.5
# 1.0000387611732049e91.0e91107.0
# 1.0000388110432049e91.0e91107.5
# 1.0000388609132049e91.0e91108.0
# 1.0000389107832049e91.0e91108.5
# 1.0000389606532049e91.0e91109.0
# 1.0000390105232049e91.0e91109.5
# 1.0000390603932049e91.0e91110.0
# 1.0000391102632049e91.0e91110.5
# 1.0000391601332049e91.0e91111.0
# 1.000039210003205e91.0e91111.5
# 1.000039259873205e91.0e91112.0
# 1.000039309743205e91.0e91112.5
# 1.000039359613205e91.0e91113.0
# 1.000039409483205e91.0e91113.5
# 1.000039459353205e91.0e91114.0
# 1.000039509223205e91.0e91114.5
# 1.000039559093205e91.0e91115.0
# 1.000039608963205e91.0e91115.5
# 1.000039658833205e91.0e91116.0
# 1.000039708703205e91.0e91116.5
# 1.000039758573205e91.0e91117.0
# 1.000039808443205e91.0e91117.5
# 1.000039858313205e91.0e91118.0
# 1.000039908183205e91.0e91118.5
# 1.000039958053205e91.0e91119.0
# 1.0000400079232049e91.0e91119.5
# 1.0000400577932049e91.0e91120.0
# 1.0000401076632049e91.0e91120.5
# 1.0000401575332049e91.0e91121.0
# 1.0000402074032049e91.0e91121.5
# 1.0000402572732049e91.0e91122.0
# 1.0000403071432049e91.0e91122.5
# 1.0000403570132049e91.0e91123.0
# 1.0000404068832049e91.0e91123.5
# 1.000040456753205e91.0e91124.0
# 1.000040506623205e91.0e91124.5
# 1.000040556493205e91.0e91125.0
# 1.000040606363205e91.0e91125.5
# 1.000040656233205e91.0e91126.0
# 1.000040706103205e91.0e91126.5
# 1.000040755973205e91.0e91127.0
# 1.000040805843205e91.0e91127.5
# 1.000040855713205e91.0e91128.0
# 1.000040905583205e91.0e91128.5
# 1.000040955453205e91.0e91129.0
# 1.000041005323205e91.0e91129.5
# 1.000041055193205e91.0e91130.0
# 1.000041105063205e91.0e91130.5
# 1.000041154933205e91.0e91131.0
# 1.000041204803205e91.0e91131.5
# 1.0000412546732049e91.0e91132.0
# 1.0000413045432049e91.0e91132.5
# 1.0000413544132049e91.0e91133.0
# 1.0000414042832049e91.0e91133.5
# 1.0000414541532049e91.0e91134.0
# 1.0000415040232049e91.0e91134.5
# 1.0000415538932049e91.0e91135.0
# 1.0000416037632049e91.0e91135.5
# 1.0000416536332049e91.0e91136.0
# 1.000041703503205e91.0e91136.5
# 1.000041753373205e91.0e91137.0
# 1.000041803243205e91.0e91137.5
# 1.000041853113205e91.0e91138.0
# 1.000041902983205e91.0e91138.5
# 1.000041952853205e91.0e91139.0
# 1.000042002723205e91.0e91139.5
# 1.000042052593205e91.0e91140.0
# 1.000042102463205e91.0e91140.5
# 1.000042152333205e91.0e91141.0
# 1.000042202203205e91.0e91141.5
# 1.000042252073205e91.0e91142.0
# 1.000042301943205e91.0e91142.5
# 1.000042351813205e91.0e91143.0
# 1.000042401683205e91.0e91143.5
# 1.000042451553205e91.0e91144.0
# 1.0000425014232049e91.0e91144.5
# 1.0000425512932049e91.0e91145.0
# 1.0000426011632049e91.0e91145.5
# 1.0000426510332049e91.0e91146.0
# 1.0000427009032049e91.0e91146.5
# 1.0000427507732049e91.0e91147.0
# 1.0000428006432049e91.0e91147.5
# 1.0000428505132049e91.0e91148.0
# 1.0000429003832049e91.0e91148.5
# 1.000042950253205e91.0e91149.0
# 1.000043000123205e91.0e91149.5
# 1.000043049993205e91.0e91150.0
# 1.000043099863205e91.0e91150.5
# 1.000043149733205e91.0e91151.0
# 1.000043199603205e91.0e91151.5
# 1.000043249473205e91.0e91152.0
# 1.000043299343205e91.0e91152.5
# 1.000043349213205e91.0e91153.0
# 1.000043399083205e91.0e91153.5
# 1.000043448953205e91.0e91154.0
# 1.000043498823205e91.0e91154.5
# 1.000043548693205e91.0e91155.0
# 1.000043598563205e91.0e91155.5
# 1.000043648433205e91.0e91156.0
# 1.000043698303205e91.0e91156.5
# 1.0000437481732049e91.0e91157.0
# 1.0000437980432049e91.0e91157.5
# 1.0000438479132049e91.0e91158.0
# 1.0000438977832049e91.0e91158.5
# 1.0000439476532049e91.0e91159.0
# 1.0000439975232049e91.0e91159.5
# 1.0000440473932049e91.0e91160.0
# 1.0000440972632049e91.0e91160.5
# 1.0000441471332049e91.0e91161.0
# 1.000044197003205e91.0e91161.5
# 1.000044246873205e91.0e91162.0
# 1.000044296743205e91.0e91162.5
# 1.000044346613205e91.0e91163.0
# 1.000044396483205e91.0e91163.5
# 1.000044446353205e91.0e91164.0
# 1.000044496223205e91.0e91164.5
# 1.000044546093205e91.0e91165.0
# 1.000044595963205e91.0e91165.5
# 1.000044645833205e91.0e91166.0
# 1.000044695703205e91.0e91166.5
# 1.000044745573205e91.0e91167.0
# 1.000044795443205e91.0e91167.5
# 1.000044845313205e91.0e91168.0
# 1.000044895183205e91.0e91168.5
# 1.000044945053205e91.0e91169.0
# 1.0000449949232049e91.0e91169.5
# 1.0000450447932049e91.0e91170.0
# 1.0000450946632049e91.0e91170.5
# 1.0000451445332049e91.0e91171.0
# 1.0000451944032049e91.0e91171.5
# 1.0000452442732049e91.0e91172.0
# 1.0000452941432049e91.0e91172.5
# 1.0000453440132049e91.0e91173.0
# 1.0000453938832049e91.0e91173.5
# 1.000045443753205e91.0e91174.0
# 1.000045493623205e91.0e91174.5
# 1.000045543493205e91.0e91175.0
# 1.000045593363205e91.0e91175.5
# 1.000045643233205e91.0e91176.0
# 1.000045693103205e91.0e91176.5
# 1.000045742973205e91.0e91177.0
# 1.000045792843205e91.0e91177.5
# 1.000045842713205e91.0e91178.0
# 1.000045892583205e91.0e91178.5
# 1.000045942453205e91.0e91179.0
# 1.000045992323205e91.0e91179.5
# 1.000046042193205e91.0e91180.0
# 1.000046092063205e91.0e91180.5
# 1.000046141933205e91.0e91181.0
# 1.000046191803205e91.0e91181.5
# 1.0000462416732049e91.0e91182.0
# 1.0000462915432049e91.0e91182.5
# 1.0000463414132049e91.0e91183.0
# 1.0000463912832049e91.0e91183.5
# 1.0000464411532049e91.0e91184.0
# 1.0000464910232049e91.0e91184.5
# 1.0000465408932049e91.0e91185.0
# 1.0000465907632049e91.0e91185.5
# 1.0000466406332049e91.0e91186.0
# 1.000046690503205e91.0e91186.5
# 1.000046740373205e91.0e91187.0
# 1.000046790243205e91.0e91187.5
# 1.000046840113205e91.0e91188.0
# 1.000046889983205e91.0e91188.5
# 1.000046939853205e91.0e91189.0
# 1.000046989723205e91.0e91189.5
# 1.000047039593205e91.0e91190.0
# 1.000047089463205e91.0e91190.5
# 1.000047139333205e91.0e91191.0
# 1.000047189203205e91.0e91191.5
# 1.000047239073205e91.0e91192.0
# 1.000047288943205e91.0e91192.5
# 1.000047338813205e91.0e91193.0
# 1.000047388683205e91.0e91193.5
# 1.000047438553205e91.0e91194.0
# 1.0000474884232049e91.0e91194.5
# 1.0000475382932049e91.0e91195.0
# 1.0000475881632049e91.0e91195.5
# 1.0000476380332049e91.0e91196.0
# 1.0000476879032049e91.0e91196.5
# 1.0000477377732049e91.0e91197.0
# 1.0000477876432049e91.0e91197.5
# 1.0000478375132049e91.0e91198.0
# 1.0000478873832049e91.0e91198.5
# 1.000047937253205e91.0e91199.0
# 1.000047987123205e91.0e91199.5
# 1.000048036993205e91.0e91200.0
# 1.000048086863205e91.0e91200.5
# 1.000048136733205e91.0e91201.0
# 1.000048186603205e91.0e91201.5
# 1.000048236473205e91.0e91202.0
# 1.000048286343205e91.0e91202.5
# 1.000048336213205e91.0e91203.0
# 1.000048386083205e91.0e91203.5
# 1.000048435953205e91.0e91204.0
# 1.000048485823205e91.0e91204.5
# 1.000048535693205e91.0e91205.0
# 1.000048585563205e91.0e91205.5
# 1.000048635433205e91.0e91206.0
# 1.000048685303205e91.0e91206.5
# 1.0000487351732049e91.0e91207.0
# 1.0000487850432049e91.0e91207.5
# 1.0000488349132049e91.0e91208.0
# 1.0000488847832049e91.0e91208.5
# 1.0000489346532049e91.0e91209.0
# 1.0000489845232049e91.0e91209.5
# 1.0000490343932049e91.0e91210.0
# 1.0000490842632049e91.0e91210.5
# 1.0000491341332049e91.0e91211.0
# 1.000049184003205e91.0e91211.5
# 1.000049233873205e91.0e91212.0
# 1.000049283743205e91.0e91212.5
# 1.000049333613205e91.0e91213.0
# 1.000049383483205e91.0e91213.5
# 1.000049433353205e91.0e91214.0
# 1.000049483223205e91.0e91214.5
# 1.000049533093205e91.0e91215.0
# 1.000049582963205e91.0e91215.5
# 1.000049632833205e91.0e91216.0
# 1.000049682703205e91.0e91216.5
# 1.000049732573205e91.0e91217.0
# 1.000049782443205e91.0e91217.5
# 1.000049832313205e91.0e91218.0
# 1.000049882183205e91.0e91218.5
# 1.000049932053205e91.0e91219.0
# 1.0000499819232049e91.0e91219.5
# 1.0000500317932049e91.0e91220.0
# 1.0000500816632049e91.0e91220.5
# 1.0000501315332049e91.0e91221.0
# 1.0000501814032049e91.0e91221.5
# 1.0000502312732049e91.0e91222.0
# 1.0000502811432049e91.0e91222.5
# 1.0000503310132049e91.0e91223.0
# 1.0000503808832049e91.0e91223.5
# 1.000050430753205e91.0e91224.0
# 1.000050480623205e91.0e91224.5
# 1.000050530493205e91.0e91225.0
# 1.000050580363205e91.0e91225.5
# 1.000050630233205e91.0e91226.0
# 1.000050680103205e91.0e91226.5
# 1.000050729973205e91.0e91227.0
# 1.000050779843205e91.0e91227.5
# 1.000050829713205e91.0e91228.0
# 1.000050879583205e91.0e91228.5
# 1.000050929453205e91.0e91229.0
# 1.000050979323205e91.0e91229.5
# 1.000051029193205e91.0e91230.0
# 1.000051079063205e91.0e91230.5
# 1.000051128933205e91.0e91231.0
# 1.000051178803205e91.0e91231.5
# 1.0000512286732049e91.0e91232.0
# 1.0000512785432049e91.0e91232.5
# 1.0000513284132049e91.0e91233.0
# 1.0000513782832049e91.0e91233.5
# 1.0000514281532049e91.0e91234.0
# 1.0000514780232049e91.0e91234.5
# 1.0000515278932049e91.0e91235.0
# 1.0000515777632049e91.0e91235.5
# 1.0000516276332049e91.0e91236.0
# 1.000051677503205e91.0e91236.5
# 1.000051727373205e91.0e91237.0
# 1.000051777243205e91.0e91237.5
# 1.000051827113205e91.0e91238.0
# 1.000051876983205e91.0e91238.5
# 1.000051926853205e91.0e91239.0
# 1.000051976723205e91.0e91239.5
# 1.000052026593205e91.0e91240.0
# 1.000052076463205e91.0e91240.5
# 1.000052126333205e91.0e91241.0
# 1.000052176203205e91.0e91241.5
# 1.000052226073205e91.0e91242.0
# 1.000052275943205e91.0e91242.5
# 1.000052325813205e91.0e91243.0
# 1.000052375683205e91.0e91243.5
# 1.000052425553205e91.0e91244.0
# 1.0000524754232049e91.0e91244.5
# 1.0000525252932049e91.0e91245.0
# 1.0000525751632049e91.0e91245.5
# 1.0000526250332049e91.0e91246.0
# 1.0000526749032049e91.0e91246.5
# 1.0000527247732049e91.0e91247.0
# 1.0000527746432049e91.0e91247.5
# 1.0000528245132049e91.0e91248.0
# 1.0000528743832049e91.0e91248.5
# 1.000052924253205e91.0e91249.0
# 1.000052974123205e91.0e91249.5
# 1.000053023993205e91.0e91250.0
# 1.000053073863205e91.0e91250.5
# 1.000053123733205e91.0e91251.0
# 1.000053173603205e91.0e91251.5
# 1.000053223473205e91.0e91252.0
# 1.000053273343205e91.0e91252.5
# 1.000053323213205e91.0e91253.0
# 1.000053373083205e91.0e91253.5
# 1.000053422953205e91.0e91254.0
# 1.000053472823205e91.0e91254.5
# 1.000053522693205e91.0e91255.0
# 1.000053572563205e91.0e91255.5
# 1.000053622433205e91.0e91256.0
# 1.000053672303205e91.0e91256.5
# 1.0000537221732049e91.0e91257.0
# 1.0000537720432049e91.0e91257.5
# 1.0000538219132049e91.0e91258.0
# 1.0000538717832049e91.0e91258.5
# 1.0000539216532049e91.0e91259.0
# 1.0000539715232049e91.0e91259.5
# 1.0000540213932049e91.0e91260.0
# 1.0000540712632049e91.0e91260.5
# 1.0000541211332049e91.0e91261.0
# 1.000054171003205e91.0e91261.5
# 1.000054220873205e91.0e91262.0
# 1.000054270743205e91.0e91262.5
# 1.000054320613205e91.0e91263.0
# 1.000054370483205e91.0e91263.5
# 1.000054420353205e91.0e91264.0
# 1.000054470223205e91.0e91264.5
# 1.000054520093205e91.0e91265.0
# 1.000054569963205e91.0e91265.5
# 1.000054619833205e91.0e91266.0
# 1.000054669703205e91.0e91266.5
# 1.000054719573205e91.0e91267.0
# 1.000054769443205e91.0e91267.5
# 1.000054819313205e91.0e91268.0
# 1.000054869183205e91.0e91268.5
# 1.000054919053205e91.0e91269.0
# 1.0000549689232049e91.0e91269.5
# 1.0000550187932049e91.0e91270.0
# 1.0000550686632049e91.0e91270.5
# 1.0000551185332049e91.0e91271.0
# 1.0000551684032049e91.0e91271.5
# 1.0000552182732049e91.0e91272.0
# 1.0000552681432049e91.0e91272.5
# 1.0000553180132049e91.0e91273.0
# 1.0000553678832049e91.0e91273.5
# 1.000055417753205e91.0e91274.0
# 1.000055467623205e91.0e91274.5
# 1.000055517493205e91.0e91275.0
# 1.000055567363205e91.0e91275.5
# 1.000055617233205e91.0e91276.0
# 1.000055667103205e91.0e91276.5
# 1.000055716973205e91.0e91277.0
# 1.000055766843205e91.0e91277.5
# 1.000055816713205e91.0e91278.0
# 1.000055866583205e91.0e91278.5
# 1.000055916453205e91.0e91279.0
# 1.000055966323205e91.0e91279.5
# 1.000056016193205e91.0e91280.0
# 1.000056066063205e91.0e91280.5
# 1.000056115933205e91.0e91281.0
# 1.000056165803205e91.0e91281.5
# 1.0000562156732049e91.0e91282.0
# 1.0000562655432049e91.0e91282.5
# 1.0000563154132049e91.0e91283.0
# 1.0000563652832049e91.0e91283.5
# 1.0000564151532049e91.0e91284.0
# 1.0000564650232049e91.0e91284.5
# 1.0000565148932049e91.0e91285.0
# 1.0000565647632049e91.0e91285.5
# 1.0000566146332049e91.0e91286.0
# 1.000056664503205e91.0e91286.5
# 1.000056714373205e91.0e91287.0
# 1.000056764243205e91.0e91287.5
# 1.000056814113205e91.0e91288.0
# 1.000056863983205e91.0e91288.5
# 1.000056913853205e91.0e91289.0
# 1.000056963723205e91.0e91289.5
# 1.000057013593205e91.0e91290.0
# 1.000057063463205e91.0e91290.5
# 1.000057113333205e91.0e91291.0
# 1.000057163203205e91.0e91291.5
# 1.000057213073205e91.0e91292.0
# 1.000057262943205e91.0e91292.5
# 1.000057312813205e91.0e91293.0
# 1.000057362683205e91.0e91293.5
# 1.000057412553205e91.0e91294.0
# 1.0000574624232049e91.0e91294.5
# 1.0000575122932049e91.0e91295.0
# 1.0000575621632049e91.0e91295.5
# 1.0000576120332049e91.0e91296.0
# 1.0000576619032049e91.0e91296.5
# 1.0000577117732049e91.0e91297.0
# 1.0000577616432049e91.0e91297.5
# 1.0000578115132049e91.0e91298.0
# 1.0000578613832049e91.0e91298.5
# 1.000057911253205e91.0e91299.0
# 1.000057961123205e91.0e91299.5
# 1.000058010993205e91.0e91300.0
# 1.000058060863205e91.0e91300.5
# 1.000058110733205e91.0e91301.0
# 1.000058160603205e91.0e91301.5
# 1.000058210473205e91.0e91302.0
# 1.000058260343205e91.0e91302.5
# 1.000058310213205e91.0e91303.0
# 1.000058360083205e91.0e91303.5
# 1.000058409953205e91.0e91304.0
# 1.000058459823205e91.0e91304.5
# 1.000058509693205e91.0e91305.0
# 1.000058559563205e91.0e91305.5
# 1.000058609433205e91.0e91306.0
# 1.000058659303205e91.0e91306.5
# 1.0000587091732049e91.0e91307.0
# 1.0000587590432049e91.0e91307.5
# 1.0000588089132049e91.0e91308.0
# 1.0000588587832049e91.0e91308.5
# 1.0000589086532049e91.0e91309.0
# 1.0000589585232049e91.0e91309.5
# 1.0000590083932049e91.0e91310.0
# 1.0000590582632049e91.0e91310.5
# 1.0000591081332049e91.0e91311.0
# 1.000059158003205e91.0e91311.5
# 1.000059207873205e91.0e91312.0
# 1.000059257743205e91.0e91312.5
# 1.000059307613205e91.0e91313.0
# 1.000059357483205e91.0e91313.5
# 1.000059407353205e91.0e91314.0
# 1.000059457223205e91.0e91314.5
# 1.000059507093205e91.0e91315.0
# 1.000059556963205e91.0e91315.5
# 1.000059606833205e91.0e91316.0
# 1.000059656703205e91.0e91316.5
# 1.000059706573205e91.0e91317.0
# 1.000059756443205e91.0e91317.5
# 1.000059806313205e91.0e91318.0
# 1.000059856183205e91.0e91318.5
# 1.000059906053205e91.0e91319.0
# 1.0000599559232049e91.0e91319.5
# 1.0000600057932049e91.0e91320.0
# 1.0000600556632049e91.0e91320.5
# 1.0000601055332049e91.0e91321.0
# 1.0000601554032049e91.0e91321.5
# 1.0000602052732049e91.0e91322.0
# 1.0000602551432049e91.0e91322.5
# 1.0000603050132049e91.0e91323.0
# 1.0000603548832049e91.0e91323.5
# 1.000060404753205e91.0e91324.0
# 1.000060454623205e91.0e91324.5
# 1.000060504493205e91.0e91325.0
# 1.000060554363205e91.0e91325.5
# 1.000060604233205e91.0e91326.0
# 1.000060654103205e91.0e91326.5
# 1.000060703973205e91.0e91327.0
# 1.000060753843205e91.0e91327.5
# 1.000060803713205e91.0e91328.0
# 1.000060853583205e91.0e91328.5
# 1.000060903453205e91.0e91329.0
# 1.000060953323205e91.0e91329.5
# 1.000061003193205e91.0e91330.0
# 1.000061053063205e91.0e91330.5
# 1.000061102933205e91.0e91331.0
# 1.000061152803205e91.0e91331.5
# 1.0000612026732049e91.0e91332.0
# 1.0000612525432049e91.0e91332.5
# 1.0000613024132049e91.0e91333.0
# 1.0000613522832049e91.0e91333.5
# 1.0000614021532049e91.0e91334.0
# 1.0000614520232049e91.0e91334.5
# 1.0000615018932049e91.0e91335.0
# 1.0000615517632049e91.0e91335.5
# 1.0000616016332049e91.0e91336.0
# 1.000061651503205e91.0e91336.5
# 1.000061701373205e91.0e91337.0
# 1.000061751243205e91.0e91337.5
# 1.000061801113205e91.0e91338.0
# 1.000061850983205e91.0e91338.5
# 1.000061900853205e91.0e91339.0
# 1.000061950723205e91.0e91339.5
# 1.000062000593205e91.0e91340.0
# 1.000062050463205e91.0e91340.5
# 1.000062100333205e91.0e91341.0
# 1.000062150203205e91.0e91341.5
# 1.000062200073205e91.0e91342.0
# 1.000062249943205e91.0e91342.5
# 1.000062299813205e91.0e91343.0
# 1.000062349683205e91.0e91343.5
# 1.000062399553205e91.0e91344.0
# 1.0000624494232049e91.0e91344.5
# 1.0000624992932049e91.0e91345.0
# 1.0000625491632049e91.0e91345.5
# 1.0000625990332049e91.0e91346.0
# 1.0000626489032049e91.0e91346.5
# 1.0000626987732049e91.0e91347.0
# 1.0000627486432049e91.0e91347.5
# 1.0000627985132049e91.0e91348.0
# 1.0000628483832049e91.0e91348.5
# 1.000062898253205e91.0e91349.0
# 1.000062948123205e91.0e91349.5
# 1.000062997993205e91.0e91350.0
# 1.000063047863205e91.0e91350.5
# 1.000063097733205e91.0e91351.0
# 1.000063147603205e91.0e91351.5
# 1.000063197473205e91.0e91352.0
# 1.000063247343205e91.0e91352.5
# 1.000063297213205e91.0e91353.0
# 1.000063347083205e91.0e91353.5
# 1.000063396953205e91.0e91354.0
# 1.000063446823205e91.0e91354.5
# 1.000063496693205e91.0e91355.0
# 1.000063546563205e91.0e91355.5
# 1.000063596433205e91.0e91356.0
# 1.000063646303205e91.0e91356.5
# 1.0000636961732049e91.0e91357.0
# 1.0000637460432049e91.0e91357.5
# 1.0000637959132049e91.0e91358.0
# 1.0000638457832049e91.0e91358.5
# 1.0000638956532049e91.0e91359.0
# 1.0000639455232049e91.0e91359.5
# 1.0000639953932049e91.0e91360.0
# 1.0000640452632049e91.0e91360.5
# 1.0000640951332049e91.0e91361.0
# 1.000064145003205e91.0e91361.5
# 1.000064194873205e91.0e91362.0
# 1.000064244743205e91.0e91362.5
# 1.000064294613205e91.0e91363.0
# 1.000064344483205e91.0e91363.5
# 1.000064394353205e91.0e91364.0
# 1.000064444223205e91.0e91364.5
# 1.000064494093205e91.0e91365.0
# 1.000064543963205e91.0e91365.5
# 1.000064593833205e91.0e91366.0
# 1.000064643703205e91.0e91366.5
# 1.000064693573205e91.0e91367.0
# 1.000064743443205e91.0e91367.5
# 1.000064793313205e91.0e91368.0
# 1.000064843183205e91.0e91368.5
# 1.000064893053205e91.0e91369.0
# 1.0000649429232049e91.0e91369.5
# 1.0000649927932049e91.0e91370.0
# 1.0000650426632049e91.0e91370.5
# 1.0000650925332049e91.0e91371.0
# 1.0000651424032049e91.0e91371.5
# 1.0000651922732049e91.0e91372.0
# 1.0000652421432049e91.0e91372.5
# 1.0000652920132049e91.0e91373.0
# 1.0000653418832049e91.0e91373.5
# 1.000065391753205e91.0e91374.0
# 1.000065441623205e91.0e91374.5
# 1.000065491493205e91.0e91375.0
# 1.000065541363205e91.0e91375.5
# 1.000065591233205e91.0e91376.0
# 1.000065641103205e91.0e91376.5
# 1.000065690973205e91.0e91377.0
# 1.000065740843205e91.0e91377.5
# 1.000065790713205e91.0e91378.0
# 1.000065840583205e91.0e91378.5
# 1.000065890453205e91.0e91379.0
# 1.000065940323205e91.0e91379.5
# 1.000065990193205e91.0e91380.0
# 1.000066040063205e91.0e91380.5
# 1.000066089933205e91.0e91381.0
# 1.000066139803205e91.0e91381.5
# 1.0000661896732049e91.0e91382.0
# 1.0000662395432049e91.0e91382.5
# 1.0000662894132049e91.0e91383.0
# 1.0000663392832049e91.0e91383.5
# 1.0000663891532049e91.0e91384.0
# 1.0000664390232049e91.0e91384.5
# 1.0000664888932049e91.0e91385.0
# 1.0000665387632049e91.0e91385.5
# 1.0000665886332049e91.0e91386.0
# 1.000066638503205e91.0e91386.5
# 1.000066688373205e91.0e91387.0
# 1.000066738243205e91.0e91387.5
# 1.000066788113205e91.0e91388.0
# 1.000066837983205e91.0e91388.5
# 1.000066887853205e91.0e91389.0
# 1.000066937723205e91.0e91389.5
# 1.000066987593205e91.0e91390.0
# 1.000067037463205e91.0e91390.5
# 1.000067087333205e91.0e91391.0
# 1.000067137203205e91.0e91391.5
# 1.000067187073205e91.0e91392.0
# 1.000067236943205e91.0e91392.5
# 1.000067286813205e91.0e91393.0
# 1.000067336683205e91.0e91393.5
# 1.000067386553205e91.0e91394.0
# 1.0000674364232049e91.0e91394.5
# 1.0000674862932049e91.0e91395.0
# 1.0000675361632049e91.0e91395.5
# 1.0000675860332049e91.0e91396.0
# 1.0000676359032049e91.0e91396.5
# 1.0000676857732049e91.0e91397.0
# 1.0000677356432049e91.0e91397.5
# 1.0000677855132049e91.0e91398.0
# 1.0000678353832049e91.0e91398.5
# 1.000067885253205e91.0e91399.0
# 1.000067935123205e91.0e91399.5
# 1.000067984993205e91.0e91400.0
# 1.000068034863205e91.0e91400.5
# 1.000068084733205e91.0e91401.0
# 1.000068134603205e91.0e91401.5
# 1.000068184473205e91.0e91402.0
# 1.000068234343205e91.0e91402.5
# 1.000068284213205e91.0e91403.0
# 1.000068334083205e91.0e91403.5
# 1.000068383953205e91.0e91404.0
# 1.000068433823205e91.0e91404.5
# 1.000068483693205e91.0e91405.0
# 1.000068533563205e91.0e91405.5
# 1.000068583433205e91.0e91406.0
# 1.000068633303205e91.0e91406.5
# 1.0000686831732049e91.0e91407.0
# 1.0000687330432049e91.0e91407.5
# 1.0000687829132049e91.0e91408.0
# 1.0000688327832049e91.0e91408.5
# 1.0000688826532049e91.0e91409.0
# 1.0000689325232049e91.0e91409.5
# 1.0000689823932049e91.0e91410.0
# 1.0000690322632049e91.0e91410.5
# 1.0000690821332049e91.0e91411.0
# 1.000069132003205e91.0e91411.5
# 1.000069181873205e91.0e91412.0
# 1.000069231743205e91.0e91412.5
# 1.000069281613205e91.0e91413.0
# 1.000069331483205e91.0e91413.5
# 1.000069381353205e91.0e91414.0
# 1.000069431223205e91.0e91414.5
# 1.000069481093205e91.0e91415.0
# 1.000069530963205e91.0e91415.5
# 1.000069580833205e91.0e91416.0
# 1.000069630703205e91.0e91416.5
# 1.000069680573205e91.0e91417.0
# 1.000069730443205e91.0e91417.5
# 1.000069780313205e91.0e91418.0
# 1.000069830183205e91.0e91418.5
# 1.000069880053205e91.0e91419.0
# 1.0000699299232049e91.0e91419.5
# 1.0000699797932049e91.0e91420.0
# 1.0000700296632049e91.0e91420.5
# 1.0000700795332049e91.0e91421.0
# 1.0000701294032049e91.0e91421.5
# 1.0000701792732049e91.0e91422.0
# 1.0000702291432049e91.0e91422.5
# 1.0000702790132049e91.0e91423.0
# 1.0000703288832049e91.0e91423.5
# 1.000070378753205e91.0e91424.0
# 1.000070428623205e91.0e91424.5
# 1.000070478493205e91.0e91425.0
# 1.000070528363205e91.0e91425.5
# 1.000070578233205e91.0e91426.0
# 1.000070628103205e91.0e91426.5
# 1.000070677973205e91.0e91427.0
# 1.000070727843205e91.0e91427.5
# 1.000070777713205e91.0e91428.0
# 1.000070827583205e91.0e91428.5
# 1.000070877453205e91.0e91429.0
# 1.000070927323205e91.0e91429.5
# 1.000070977193205e91.0e91430.0
# 1.000071027063205e91.0e91430.5
# 1.000071076933205e91.0e91431.0
# 1.000071126803205e91.0e91431.5
# 1.0000711766732049e91.0e91432.0
# 1.0000712265432049e91.0e91432.5
# 1.0000712764132049e91.0e91433.0
# 1.0000713262832049e91.0e91433.5
# 1.0000713761532049e91.0e91434.0
# 1.0000714260232049e91.0e91434.5
# 1.0000714758932049e91.0e91435.0
# 1.0000715257632049e91.0e91435.5
# 1.0000715756332049e91.0e91436.0
# 1.000071625503205e91.0e91436.5
# 1.000071675373205e91.0e91437.0
# 1.000071725243205e91.0e91437.5
# 1.000071775113205e91.0e91438.0
# 1.000071824983205e91.0e91438.5
# 1.000071874853205e91.0e91439.0
# 1.000071924723205e91.0e91439.5
# 1.000071974593205e91.0e91440.0
# 1.000072024463205e91.0e91440.5
# 1.000072074333205e91.0e91441.0
# 1.000072124203205e91.0e91441.5
# 1.000072174073205e91.0e91442.0
# 1.000072223943205e91.0e91442.5
# 1.000072273813205e91.0e91443.0
# 1.000072323683205e91.0e91443.5
# 1.000072373553205e91.0e91444.0
# 1.0000724234232049e91.0e91444.5
# 1.0000724732932049e91.0e91445.0
# 1.0000725231632049e91.0e91445.5
# 1.0000725730332049e91.0e91446.0
# 1.0000726229032049e91.0e91446.5
# 1.0000726727732049e91.0e91447.0
# 1.0000727226432049e91.0e91447.5
# 1.0000727725132049e91.0e91448.0
# 1.0000728223832049e91.0e91448.5
# 1.000072872253205e91.0e91449.0
# 1.000072922123205e91.0e91449.5
# 1.000072971993205e91.0e91450.0
# 1.000073021863205e91.0e91450.5
# 1.000073071733205e91.0e91451.0
# 1.000073121603205e91.0e91451.5
# 1.000073171473205e91.0e91452.0
# 1.000073221343205e91.0e91452.5
# 1.000073271213205e91.0e91453.0
# 1.000073321083205e91.0e91453.5
# 1.000073370953205e91.0e91454.0
# 1.000073420823205e91.0e91454.5
# 1.000073470693205e91.0e91455.0
# 1.000073520563205e91.0e91455.5
# 1.000073570433205e91.0e91456.0
# 1.000073620303205e91.0e91456.5
# 1.0000736701732049e91.0e91457.0
# 1.0000737200432049e91.0e91457.5
# 1.0000737699132049e91.0e91458.0
# 1.0000738197832049e91.0e91458.5
# 1.0000738696532049e91.0e91459.0
# 1.0000739195232049e91.0e91459.5
# 1.0000739693932049e91.0e91460.0
# 1.0000740192632049e91.0e91460.5
# 1.0000740691332049e91.0e91461.0
# 1.000074119003205e91.0e91461.5
# 1.000074168873205e91.0e91462.0
# 1.000074218743205e91.0e91462.5
# 1.000074268613205e91.0e91463.0
# 1.000074318483205e91.0e91463.5
# 1.000074368353205e91.0e91464.0
# 1.000074418223205e91.0e91464.5
# 1.000074468093205e91.0e91465.0
# 1.000074517963205e91.0e91465.5
# 1.000074567833205e91.0e91466.0
# 1.000074617703205e91.0e91466.5
# 1.000074667573205e91.0e91467.0
# 1.000074717443205e91.0e91467.5
# 1.000074767313205e91.0e91468.0
# 1.000074817183205e91.0e91468.5
# 1.000074867053205e91.0e91469.0
# 1.0000749169232049e91.0e91469.5
# 1.0000749667932049e91.0e91470.0
# 1.0000750166632049e91.0e91470.5
# 1.0000750665332049e91.0e91471.0
# 1.0000751164032049e91.0e91471.5
# 1.0000751662732049e91.0e91472.0
# 1.0000752161432049e91.0e91472.5
# 1.0000752660132049e91.0e91473.0
# 1.0000753158832049e91.0e91473.5
# 1.000075365753205e91.0e91474.0
# 1.000075415623205e91.0e91474.5
# 1.000075465493205e91.0e91475.0
# 1.000075515363205e91.0e91475.5
# 1.000075565233205e91.0e91476.0
# 1.000075615103205e91.0e91476.5
# 1.000075664973205e91.0e91477.0
# 1.000075714843205e91.0e91477.5
# 1.000075764713205e91.0e91478.0
# 1.000075814583205e91.0e91478.5
# 1.000075864453205e91.0e91479.0
# 1.000075914323205e91.0e91479.5
# 1.000075964193205e91.0e91480.0
# 1.000076014063205e91.0e91480.5
# 1.000076063933205e91.0e91481.0
# 1.000076113803205e91.0e91481.5
# 1.0000761636732049e91.0e91482.0
# 1.0000762135432049e91.0e91482.5
# 1.0000762634132049e91.0e91483.0
# 1.0000763132832049e91.0e91483.5
# 1.0000763631532049e91.0e91484.0
# 1.0000764130232049e91.0e91484.5
# 1.0000764628932049e91.0e91485.0
# 1.0000765127632049e91.0e91485.5
# 1.0000765626332049e91.0e91486.0
# 1.000076612503205e91.0e91486.5
# 1.000076662373205e91.0e91487.0
# 1.000076712243205e91.0e91487.5
# 1.000076762113205e91.0e91488.0
# 1.000076811983205e91.0e91488.5
# 1.000076861853205e91.0e91489.0
# 1.000076911723205e91.0e91489.5
# 1.000076961593205e91.0e91490.0
# 1.000077011463205e91.0e91490.5
# 1.000077061333205e91.0e91491.0
# 1.000077111203205e91.0e91491.5
# 1.000077161073205e91.0e91492.0
# ...
# 1.0008093025432049e91.0e98832.5
# 1.0008093524132049e91.0e98833.0
# 1.0008094022832049e91.0e98833.5
# 1.0008094521532049e91.0e98834.0
# 1.0008095020232049e91.0e98834.5
# 1.0008095518932049e91.0e98835.0
# 1.0008096017632049e91.0e98835.5
# 1.0008096516332049e91.0e98836.0
# 1.000809701503205e91.0e98836.5
# 1.000809751373205e91.0e98837.0
# 1.000809801243205e91.0e98837.5
# 1.000809851113205e91.0e98838.0
# 1.000809900983205e91.0e98838.5
# 1.000809950853205e91.0e98839.0
# 1.000810000723205e91.0e98839.5
# 1.000810050593205e91.0e98840.0
# 1.000810100463205e91.0e98840.5
# 1.000810150333205e91.0e98841.0
# 1.000810200203205e91.0e98841.5
# 1.000810250073205e91.0e98842.0
# 1.000810299943205e91.0e98842.5
# 1.000810349813205e91.0e98843.0
# 1.000810399683205e91.0e98843.5
# 1.000810449553205e91.0e98844.0
# 1.0008104994232049e91.0e98844.5
# 1.0008105492932049e91.0e98845.0
# 1.0008105991632049e91.0e98845.5
# 1.0008106490332049e91.0e98846.0
# 1.0008106989032049e91.0e98846.5
# 1.0008107487732049e91.0e98847.0
# 1.0008107986432049e91.0e98847.5
# 1.0008108485132049e91.0e98848.0
# 1.0008108983832049e91.0e98848.5
# 1.000810948253205e91.0e98849.0
# 1.000810998123205e91.0e98849.5
# 1.000811047993205e91.0e98850.0
# 1.000811097863205e91.0e98850.5
# 1.000811147733205e91.0e98851.0
# 1.000811197603205e91.0e98851.5
# 1.000811247473205e91.0e98852.0
# 1.000811297343205e91.0e98852.5
# 1.000811347213205e91.0e98853.0
# 1.000811397083205e91.0e98853.5
# 1.000811446953205e91.0e98854.0
# 1.000811496823205e91.0e98854.5
# 1.000811546693205e91.0e98855.0
# 1.000811596563205e91.0e98855.5
# 1.000811646433205e91.0e98856.0
# 1.000811696303205e91.0e98856.5
# 1.0008117461732049e91.0e98857.0
# 1.0008117960432049e91.0e98857.5
# 1.0008118459132049e91.0e98858.0
# 1.0008118957832049e91.0e98858.5
# 1.0008119456532049e91.0e98859.0
# 1.0008119955232049e91.0e98859.5
# 1.0008120453932049e91.0e98860.0
# 1.0008120952632049e91.0e98860.5
# 1.0008121451332049e91.0e98861.0
# 1.000812195003205e91.0e98861.5
# 1.000812244873205e91.0e98862.0
# 1.000812294743205e91.0e98862.5
# 1.000812344613205e91.0e98863.0
# 1.000812394483205e91.0e98863.5
# 1.000812444353205e91.0e98864.0
# 1.000812494223205e91.0e98864.5
# 1.000812544093205e91.0e98865.0
# 1.000812593963205e91.0e98865.5
# 1.000812643833205e91.0e98866.0
# 1.000812693703205e91.0e98866.5
# 1.000812743573205e91.0e98867.0
# 1.000812793443205e91.0e98867.5
# 1.000812843313205e91.0e98868.0
# 1.000812893183205e91.0e98868.5
# 1.000812943053205e91.0e98869.0
# 1.0008129929232049e91.0e98869.5
# 1.0008130427932049e91.0e98870.0
# 1.0008130926632049e91.0e98870.5
# 1.0008131425332049e91.0e98871.0
# 1.0008131924032049e91.0e98871.5
# 1.0008132422732049e91.0e98872.0
# 1.0008132921432049e91.0e98872.5
# 1.0008133420132049e91.0e98873.0
# 1.0008133918832049e91.0e98873.5
# 1.000813441753205e91.0e98874.0
# 1.000813491623205e91.0e98874.5
# 1.000813541493205e91.0e98875.0
# 1.000813591363205e91.0e98875.5
# 1.000813641233205e91.0e98876.0
# 1.000813691103205e91.0e98876.5
# 1.000813740973205e91.0e98877.0
# 1.000813790843205e91.0e98877.5
# 1.000813840713205e91.0e98878.0
# 1.000813890583205e91.0e98878.5
# 1.000813940453205e91.0e98879.0
# 1.000813990323205e91.0e98879.5
# 1.000814040193205e91.0e98880.0
# 1.000814090063205e91.0e98880.5
# 1.000814139933205e91.0e98881.0
# 1.000814189803205e91.0e98881.5
# 1.0008142396732049e91.0e98882.0
# 1.0008142895432049e91.0e98882.5
# 1.0008143394132049e91.0e98883.0
# 1.0008143892832049e91.0e98883.5
# 1.0008144391532049e91.0e98884.0
# 1.0008144890232049e91.0e98884.5
# 1.0008145388932049e91.0e98885.0
# 1.0008145887632049e91.0e98885.5
# 1.0008146386332049e91.0e98886.0
# 1.000814688503205e91.0e98886.5
# 1.000814738373205e91.0e98887.0
# 1.000814788243205e91.0e98887.5
# 1.000814838113205e91.0e98888.0
# 1.000814887983205e91.0e98888.5
# 1.000814937853205e91.0e98889.0
# 1.000814987723205e91.0e98889.5
# 1.000815037593205e91.0e98890.0
# 1.000815087463205e91.0e98890.5
# 1.000815137333205e91.0e98891.0
# 1.000815187203205e91.0e98891.5
# 1.000815237073205e91.0e98892.0
# 1.000815286943205e91.0e98892.5
# 1.000815336813205e91.0e98893.0
# 1.000815386683205e91.0e98893.5
# 1.000815436553205e91.0e98894.0
# 1.0008154864232049e91.0e98894.5
# 1.0008155362932049e91.0e98895.0
# 1.0008155861632049e91.0e98895.5
# 1.0008156360332049e91.0e98896.0
# 1.0008156859032049e91.0e98896.5
# 1.0008157357732049e91.0e98897.0
# 1.0008157856432049e91.0e98897.5
# 1.0008158355132049e91.0e98898.0
# 1.0008158853832049e91.0e98898.5
# 1.000815935253205e91.0e98899.0
# 1.000815985123205e91.0e98899.5
# 1.000816034993205e91.0e98900.0
# 1.000816084863205e91.0e98900.5
# 1.000816134733205e91.0e98901.0
# 1.000816184603205e91.0e98901.5
# 1.000816234473205e91.0e98902.0
# 1.000816284343205e91.0e98902.5
# 1.000816334213205e91.0e98903.0
# 1.000816384083205e91.0e98903.5
# 1.000816433953205e91.0e98904.0
# 1.000816483823205e91.0e98904.5
# 1.000816533693205e91.0e98905.0
# 1.000816583563205e91.0e98905.5
# 1.000816633433205e91.0e98906.0
# 1.000816683303205e91.0e98906.5
# 1.0008167331732049e91.0e98907.0
# 1.0008167830432049e91.0e98907.5
# 1.0008168329132049e91.0e98908.0
# 1.0008168827832049e91.0e98908.5
# 1.0008169326532049e91.0e98909.0
# 1.0008169825232049e91.0e98909.5
# 1.0008170323932049e91.0e98910.0
# 1.0008170822632049e91.0e98910.5
# 1.0008171321332049e91.0e98911.0
# 1.000817182003205e91.0e98911.5
# 1.000817231873205e91.0e98912.0
# 1.000817281743205e91.0e98912.5
# 1.000817331613205e91.0e98913.0
# 1.000817381483205e91.0e98913.5
# 1.000817431353205e91.0e98914.0
# 1.000817481223205e91.0e98914.5
# 1.000817531093205e91.0e98915.0
# 1.000817580963205e91.0e98915.5
# 1.000817630833205e91.0e98916.0
# 1.000817680703205e91.0e98916.5
# 1.000817730573205e91.0e98917.0
# 1.000817780443205e91.0e98917.5
# 1.000817830313205e91.0e98918.0
# 1.000817880183205e91.0e98918.5
# 1.000817930053205e91.0e98919.0
# 1.0008179799232049e91.0e98919.5
# 1.0008180297932049e91.0e98920.0
# 1.0008180796632049e91.0e98920.5
# 1.0008181295332049e91.0e98921.0
# 1.0008181794032049e91.0e98921.5
# 1.0008182292732049e91.0e98922.0
# 1.0008182791432049e91.0e98922.5
# 1.0008183290132049e91.0e98923.0
# 1.0008183788832049e91.0e98923.5
# 1.000818428753205e91.0e98924.0
# 1.000818478623205e91.0e98924.5
# 1.000818528493205e91.0e98925.0
# 1.000818578363205e91.0e98925.5
# 1.000818628233205e91.0e98926.0
# 1.000818678103205e91.0e98926.5
# 1.000818727973205e91.0e98927.0
# 1.000818777843205e91.0e98927.5
# 1.000818827713205e91.0e98928.0
# 1.000818877583205e91.0e98928.5
# 1.000818927453205e91.0e98929.0
# 1.000818977323205e91.0e98929.5
# 1.000819027193205e91.0e98930.0
# 1.000819077063205e91.0e98930.5
# 1.000819126933205e91.0e98931.0
# 1.000819176803205e91.0e98931.5
# 1.0008192266732049e91.0e98932.0
# 1.0008192765432049e91.0e98932.5
# 1.0008193264132049e91.0e98933.0
# 1.0008193762832049e91.0e98933.5
# 1.0008194261532049e91.0e98934.0
# 1.0008194760232049e91.0e98934.5
# 1.0008195258932049e91.0e98935.0
# 1.0008195757632049e91.0e98935.5
# 1.0008196256332049e91.0e98936.0
# 1.000819675503205e91.0e98936.5
# 1.000819725373205e91.0e98937.0
# 1.000819775243205e91.0e98937.5
# 1.000819825113205e91.0e98938.0
# 1.000819874983205e91.0e98938.5
# 1.000819924853205e91.0e98939.0
# 1.000819974723205e91.0e98939.5
# 1.000820024593205e91.0e98940.0
# 1.000820074463205e91.0e98940.5
# 1.000820124333205e91.0e98941.0
# 1.000820174203205e91.0e98941.5
# 1.000820224073205e91.0e98942.0
# 1.000820273943205e91.0e98942.5
# 1.000820323813205e91.0e98943.0
# 1.000820373683205e91.0e98943.5
# 1.000820423553205e91.0e98944.0
# 1.0008204734232049e91.0e98944.5
# 1.0008205232932049e91.0e98945.0
# 1.0008205731632049e91.0e98945.5
# 1.0008206230332049e91.0e98946.0
# 1.0008206729032049e91.0e98946.5
# 1.0008207227732049e91.0e98947.0
# 1.0008207726432049e91.0e98947.5
# 1.0008208225132049e91.0e98948.0
# 1.0008208723832049e91.0e98948.5
# 1.000820922253205e91.0e98949.0
# 1.000820972123205e91.0e98949.5
# 1.000821021993205e91.0e98950.0
# 1.000821071863205e91.0e98950.5
# 1.000821121733205e91.0e98951.0
# 1.000821171603205e91.0e98951.5
# 1.000821221473205e91.0e98952.0
# 1.000821271343205e91.0e98952.5
# 1.000821321213205e91.0e98953.0
# 1.000821371083205e91.0e98953.5
# 1.000821420953205e91.0e98954.0
# 1.000821470823205e91.0e98954.5
# 1.000821520693205e91.0e98955.0
# 1.000821570563205e91.0e98955.5
# 1.000821620433205e91.0e98956.0
# 1.000821670303205e91.0e98956.5
# 1.0008217201732049e91.0e98957.0
# 1.0008217700432049e91.0e98957.5
# 1.0008218199132049e91.0e98958.0
# 1.0008218697832049e91.0e98958.5
# 1.0008219196532049e91.0e98959.0
# 1.0008219695232049e91.0e98959.5
# 1.0008220193932049e91.0e98960.0
# 1.0008220692632049e91.0e98960.5
# 1.0008221191332049e91.0e98961.0
# 1.000822169003205e91.0e98961.5
# 1.000822218873205e91.0e98962.0
# 1.000822268743205e91.0e98962.5
# 1.000822318613205e91.0e98963.0
# 1.000822368483205e91.0e98963.5
# 1.000822418353205e91.0e98964.0
# 1.000822468223205e91.0e98964.5
# 1.000822518093205e91.0e98965.0
# 1.000822567963205e91.0e98965.5
# 1.000822617833205e91.0e98966.0
# 1.000822667703205e91.0e98966.5
# 1.000822717573205e91.0e98967.0
# 1.000822767443205e91.0e98967.5
# 1.000822817313205e91.0e98968.0
# 1.000822867183205e91.0e98968.5
# 1.000822917053205e91.0e98969.0
# 1.0008229669232049e91.0e98969.5
# 1.0008230167932049e91.0e98970.0
# 1.0008230666632049e91.0e98970.5
# 1.0008231165332049e91.0e98971.0
# 1.0008231664032049e91.0e98971.5
# 1.0008232162732049e91.0e98972.0
# 1.0008232661432049e91.0e98972.5
# 1.0008233160132049e91.0e98973.0
# 1.0008233658832049e91.0e98973.5
# 1.000823415753205e91.0e98974.0
# 1.000823465623205e91.0e98974.5
# 1.000823515493205e91.0e98975.0
# 1.000823565363205e91.0e98975.5
# 1.000823615233205e91.0e98976.0
# 1.000823665103205e91.0e98976.5
# 1.000823714973205e91.0e98977.0
# 1.000823764843205e91.0e98977.5
# 1.000823814713205e91.0e98978.0
# 1.000823864583205e91.0e98978.5
# 1.000823914453205e91.0e98979.0
# 1.000823964323205e91.0e98979.5
# 1.000824014193205e91.0e98980.0
# 1.000824064063205e91.0e98980.5
# 1.000824113933205e91.0e98981.0
# 1.000824163803205e91.0e98981.5
# 1.0008242136732049e91.0e98982.0
# 1.0008242635432049e91.0e98982.5
# 1.0008243134132049e91.0e98983.0
# 1.0008243632832049e91.0e98983.5
# 1.0008244131532049e91.0e98984.0
# 1.0008244630232049e91.0e98984.5
# 1.0008245128932049e91.0e98985.0
# 1.0008245627632049e91.0e98985.5
# 1.0008246126332049e91.0e98986.0
# 1.000824662503205e91.0e98986.5
# 1.000824712373205e91.0e98987.0
# 1.000824762243205e91.0e98987.5
# 1.000824812113205e91.0e98988.0
# 1.000824861983205e91.0e98988.5
# 1.000824911853205e91.0e98989.0
# 1.000824961723205e91.0e98989.5
# 1.000825011593205e91.0e98990.0
# 1.000825061463205e91.0e98990.5
# 1.000825111333205e91.0e98991.0
# 1.000825161203205e91.0e98991.5
# 1.000825211073205e91.0e98992.0
# 1.000825260943205e91.0e98992.5
# 1.000825310813205e91.0e98993.0
# 1.000825360683205e91.0e98993.5
# 1.000825410553205e91.0e98994.0
# 1.0008254604232049e91.0e98994.5
# 1.0008255102932049e91.0e98995.0
# 1.0008255601632049e91.0e98995.5
# 1.0008256100332049e91.0e98996.0
# 1.0008256599032049e91.0e98996.5
# 1.0008257097732049e91.0e98997.0
# 1.0008257596432049e91.0e98997.5
# 1.0008258095132049e91.0e98998.0
# 1.0008258593832049e91.0e98998.5
# 1.000825909253205e91.0e98999.0
# 1.000825959123205e91.0e98999.5
# 1.000826008993205e91.0e99000.0
# 1.000826058863205e91.0e99000.5
# 1.000826108733205e91.0e99001.0
# 1.000826158603205e91.0e99001.5
# 1.000826208473205e91.0e99002.0
# 1.000826258343205e91.0e99002.5
# 1.000826308213205e91.0e99003.0
# 1.000826358083205e91.0e99003.5
# 1.000826407953205e91.0e99004.0
# 1.000826457823205e91.0e99004.5
# 1.000826507693205e91.0e99005.0
# 1.000826557563205e91.0e99005.5
# 1.000826607433205e91.0e99006.0
# 1.000826657303205e91.0e99006.5
# 1.0008267071732049e91.0e99007.0
# 1.0008267570432049e91.0e99007.5
# 1.0008268069132049e91.0e99008.0
# 1.0008268567832049e91.0e99008.5
# 1.0008269066532049e91.0e99009.0
# 1.0008269565232049e91.0e99009.5
# 1.0008270063932049e91.0e99010.0
# 1.0008270562632049e91.0e99010.5
# 1.0008271061332049e91.0e99011.0
# 1.000827156003205e91.0e99011.5
# 1.000827205873205e91.0e99012.0
# 1.000827255743205e91.0e99012.5
# 1.000827305613205e91.0e99013.0
# 1.000827355483205e91.0e99013.5
# 1.000827405353205e91.0e99014.0
# 1.000827455223205e91.0e99014.5
# 1.000827505093205e91.0e99015.0
# 1.000827554963205e91.0e99015.5
# 1.000827604833205e91.0e99016.0
# 1.000827654703205e91.0e99016.5
# 1.000827704573205e91.0e99017.0
# 1.000827754443205e91.0e99017.5
# 1.000827804313205e91.0e99018.0
# 1.000827854183205e91.0e99018.5
# 1.000827904053205e91.0e99019.0
# 1.0008279539232049e91.0e99019.5
# 1.0008280037932049e91.0e99020.0
# 1.0008280536632049e91.0e99020.5
# 1.0008281035332049e91.0e99021.0
# 1.0008281534032049e91.0e99021.5
# 1.0008282032732049e91.0e99022.0
# 1.0008282531432049e91.0e99022.5
# 1.0008283030132049e91.0e99023.0
# 1.0008283528832049e91.0e99023.5
# 1.000828402753205e91.0e99024.0
# 1.000828452623205e91.0e99024.5
# 1.000828502493205e91.0e99025.0
# 1.000828552363205e91.0e99025.5
# 1.000828602233205e91.0e99026.0
# 1.000828652103205e91.0e99026.5
# 1.000828701973205e91.0e99027.0
# 1.000828751843205e91.0e99027.5
# 1.000828801713205e91.0e99028.0
# 1.000828851583205e91.0e99028.5
# 1.000828901453205e91.0e99029.0
# 1.000828951323205e91.0e99029.5
# 1.000829001193205e91.0e99030.0
# 1.000829051063205e91.0e99030.5
# 1.000829100933205e91.0e99031.0
# 1.000829150803205e91.0e99031.5
# 1.0008292006732049e91.0e99032.0
# 1.0008292505432049e91.0e99032.5
# 1.0008293004132049e91.0e99033.0
# 1.0008293502832049e91.0e99033.5
# 1.0008294001532049e91.0e99034.0
# 1.0008294500232049e91.0e99034.5
# 1.0008294998932049e91.0e99035.0
# 1.0008295497632049e91.0e99035.5
# 1.0008295996332049e91.0e99036.0
# 1.000829649503205e91.0e99036.5
# 1.000829699373205e91.0e99037.0
# 1.000829749243205e91.0e99037.5
# 1.000829799113205e91.0e99038.0
# 1.000829848983205e91.0e99038.5
# 1.000829898853205e91.0e99039.0
# 1.000829948723205e91.0e99039.5
# 1.000829998593205e91.0e99040.0
# 1.000830048463205e91.0e99040.5
# 1.000830098333205e91.0e99041.0
# 1.000830148203205e91.0e99041.5
# 1.000830198073205e91.0e99042.0
# 1.000830247943205e91.0e99042.5
# 1.000830297813205e91.0e99043.0
# 1.000830347683205e91.0e99043.5
# 1.000830397553205e91.0e99044.0
# 1.0008304474232049e91.0e99044.5
# 1.0008304972932049e91.0e99045.0
# 1.0008305471632049e91.0e99045.5
# 1.0008305970332049e91.0e99046.0
# 1.0008306469032049e91.0e99046.5
# 1.0008306967732049e91.0e99047.0
# 1.0008307466432049e91.0e99047.5
# 1.0008307965132049e91.0e99048.0
# 1.0008308463832049e91.0e99048.5
# 1.000830896253205e91.0e99049.0
# 1.000830946123205e91.0e99049.5
# 1.000830995993205e91.0e99050.0
# 1.000831045863205e91.0e99050.5
# 1.000831095733205e91.0e99051.0
# 1.000831145603205e91.0e99051.5
# 1.000831195473205e91.0e99052.0
# 1.000831245343205e91.0e99052.5
# 1.000831295213205e91.0e99053.0
# 1.000831345083205e91.0e99053.5
# 1.000831394953205e91.0e99054.0
# 1.000831444823205e91.0e99054.5
# 1.000831494693205e91.0e99055.0
# 1.000831544563205e91.0e99055.5
# 1.000831594433205e91.0e99056.0
# 1.000831644303205e91.0e99056.5
# 1.0008316941732049e91.0e99057.0
# 1.0008317440432049e91.0e99057.5
# 1.0008317939132049e91.0e99058.0
# 1.0008318437832049e91.0e99058.5
# 1.0008318936532049e91.0e99059.0
# 1.0008319435232049e91.0e99059.5
# 1.0008319933932049e91.0e99060.0
# 1.0008320432632049e91.0e99060.5
# 1.0008320931332049e91.0e99061.0
# 1.000832143003205e91.0e99061.5
# 1.000832192873205e91.0e99062.0
# 1.000832242743205e91.0e99062.5
# 1.000832292613205e91.0e99063.0
# 1.000832342483205e91.0e99063.5
# 1.000832392353205e91.0e99064.0
# 1.000832442223205e91.0e99064.5
# 1.000832492093205e91.0e99065.0
# 1.000832541963205e91.0e99065.5
# 1.000832591833205e91.0e99066.0
# 1.000832641703205e91.0e99066.5
# 1.000832691573205e91.0e99067.0
# 1.000832741443205e91.0e99067.5
# 1.000832791313205e91.0e99068.0
# 1.000832841183205e91.0e99068.5
# 1.000832891053205e91.0e99069.0
# 1.0008329409232049e91.0e99069.5
# 1.0008329907932049e91.0e99070.0
# 1.0008330406632049e91.0e99070.5
# 1.0008330905332049e91.0e99071.0
# 1.0008331404032049e91.0e99071.5
# 1.0008331902732049e91.0e99072.0
# 1.0008332401432049e91.0e99072.5
# 1.0008332900132049e91.0e99073.0
# 1.0008333398832049e91.0e99073.5
# 1.000833389753205e91.0e99074.0
# 1.000833439623205e91.0e99074.5
# 1.000833489493205e91.0e99075.0
# 1.000833539363205e91.0e99075.5
# 1.000833589233205e91.0e99076.0
# 1.000833639103205e91.0e99076.5
# 1.000833688973205e91.0e99077.0
# 1.000833738843205e91.0e99077.5
# 1.000833788713205e91.0e99078.0
# 1.000833838583205e91.0e99078.5
# 1.000833888453205e91.0e99079.0
# 1.000833938323205e91.0e99079.5
# 1.000833988193205e91.0e99080.0
# 1.000834038063205e91.0e99080.5
# 1.000834087933205e91.0e99081.0
# 1.000834137803205e91.0e99081.5
# 1.0008341876732049e91.0e99082.0
# 1.0008342375432049e91.0e99082.5
# 1.0008342874132049e91.0e99083.0
# Excessive output truncated after 524307 bytes.
# 1.0008343372832049e91.0e99083.5
# 1.0008343871532049e91.0e99084.0
# 1.0008344370232049e91.0e99084.5
# 1.0008344868932049e91.0e99085.0
# 1.0008345367632049e91.0e99085.5
# 1.0008345866332049e91.0e99086.0

# %%
#71.5 to minimalna skladka przy ktorej nadwyzka końcowa bedzie rowna koncowej

# %%
# zmienne i parametry w modelu:
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
nadwyzka = 10000.0:10000.0:10000.0
skladka = 500.0:500.0:500.0
LICZBA_POWTORZEN = 100

for nd in nadwyzka, skl in skladka
    wynik = wywolanie(nd, skl, LICZBA_POWTORZEN, LICZBA_KLIENTOW, srednia_liczba_szkod, SR_SZKODA_LN, STD_SZKODA_LN, HORYZONT)
    push!(liczba_ruin, wynik.liczba_ruin)
    push!(prawd_bankr, wynik.p_bankructwa)
    push!(sr_wynik, wynik.sredni_wynik)
    println("Nadwyzka: ", nd, " Skladka: ", skl, " Liczba ruin: ", wynik.liczba_ruin, " Średni wynik: ",round(wynik.sredni_wynik), " Prawd_bankr: ", wynik.p_bankructwa)
end
# Out:
# Any[24567.245154600474, -13760.798696175178, -17423.004524034815, 20870.46993813547, 4221.913502693855, 40253.52818983296, 233.24356572643092, 24738.634768847936, -3948.997019825062, 18799.458279144175, -570.5120173022997, 5932.250431520458, -1908.3389005308018, 8086.404855104046, -2695.0328909623404, -1827.8111859841083, -721.3872295176354, -2196.651410182044, -3264.3852065974443, 2756.029496828909, 19591.39676425859, -3771.213629903058, -4593.175775390442, -13710.07356835927, -8978.622629035615, -1232.9822575465214, 5357.8581050321645, -1170.475638921298, 13915.135630729468, 12040.005571923033, -3220.81490771907, -9883.239088776078, 796.654396067577, -6901.83261776214, -5912.738297945715, 831.253750961863, 28735.174038471898, -50729.838101425965, -1662.7639121136344, -973.2624783076744, -668.376512499317, -24098.570399501736, 10281.753667991958, -15735.13780236918, 5646.387008546775, -7764.08497903074, -204.4396858184664, -1944.6398836555582, 270.6669221634491, 27419.43707816881, -6946.4491982458185, 7853.845386610624, -5036.991600913641, 11582.798310407396, -36.94054895465615, 13935.14426486464, -10663.99075403814, 18642.24827035845, -2516.8522738336615, 23237.78290717454, -11990.291654801134, -4690.0180949725345, -2265.9417430303765, -4918.334626489506, -14291.575357325497, -10855.976719422562, -10134.52930454231, -1150.6021316804472, 30869.71322091687, -7182.515431844973, -8030.347400218248, -3946.011896348733, 30909.759011406575, -1318.3601531393506, -3668.5941055996336, -4960.179315650823, -4148.1215792442545, 17080.69805211825, 27741.76029456844, 12610.87718273154, 34174.87398507049, 14625.370175083177, 4952.954362292401, -5703.932027108878, -12185.145560178456, -16610.560377924314, -15538.318463717169, -1293.5578965942823, 1166.501538031511, 22996.956063934093, -14984.245447765934, 23178.194721154592, 22181.052730309213, 15874.956135965076, 22129.22352375827, -2586.872708990608, -4156.999875937594, -1065.440093403542, -1530.3029489964756, -317.0324097496841]Nadwyzka: 10000.0 Skladka: 500.0 Liczba ruin: 60 Średni wynik: 15777.0 Prawd_bankr: 0.6

# %%
nadwyzka[1]
# Out:
# 10000.0

# %%
# miejsce na odpowiedź

# %% [markdown]
# # 4. Jak liczba symulacji wpływa na wyniki?

# %%
function model(liczba_klientow::S, 
                srednia_liczba_szkod::T, 
                sr_szkoda_ln::T, 
                std_szkoda_ln::T, 
                horyzont::S, 
                nadwyzka::T, 
                skladka::T;
                seed::S=-1) where {T<:AbstractFloat, S<:Int} #domyślna wartość to -1
    
    # Common Random Numbers aby móc porównać różne scenariusze:
    seed == -1 || Random.seed!(seed) #-1 nie będzie porównywalnosci, trzeba ustawic inne żeby była powtarzalność
    #|| - OR, czyli albo to jest spełnione, albo to po prawej
    #dobrze ustawić ziarno

    # Definiujemy daty umów klientów w symulacji:
    daty_umow = [rand(1:365) for i in 1:liczba_klientow]
    kalendarz_wplat = zeros(Int,365)
    for dataUmowy in daty_umow
        kalendarz_wplat[dataUmowy] += 1
    end
    # Liczymy liczbę szkód przypadających na jednego klienta:
    liczba_szkod_klienta = rand(Poisson(srednia_liczba_szkod),liczba_klientow)
    
    # Ustalamy daty wypłaty dla wszystkich polis:
    kalendarz_wyplat = zeros(Int,365*horyzont) 
    for k in 1:liczba_klientow
        for s in 1:liczba_szkod_klienta[k]
            data_wyplaty = daty_umow[k] + rand(1:365) #symulujemy 1rok polisy, jeden cykl życia polisy
            kalendarz_wyplat[data_wyplaty] += 1
        end
    end
    
    # Analiza wyników firmy dla danego horyzontu czasowego i danych szkód:
    for dzien in 1:365*horyzont
        dzien ≤ 364 && (nadwyzka += kalendarz_wplat[dzien] * skladka)
        liczba_wyplat = kalendarz_wyplat[dzien]
        odszkodowania = sum(exp.(rand(Normal(sr_szkoda_ln,std_szkoda_ln),liczba_wyplat)))
        nadwyzka -= odszkodowania
        nadwyzka ≤ 0 && return nadwyzka #można zakomentować, wtedy nie trzeba wysokiej nadwyżki ustawiać - tylko mozna komentowac dla 3 podejścia
    end
    return nadwyzka
end

# %%
function wywolanie(nadwyzka::T, skladka::T, liczba_powtorzen::T, 
              liczba_klientow::S, srednia_liczba_szkod::T, 
              sr_szkoda_ln::T, std_szkoda_ln::T, horyzont::S) where {T<:AbstractFloat,S<:Int}
    wynik = []
    liczba_powtorzen = trunc(Int, liczba_powtorzen)
    for seed in 1:liczba_powtorzen
        push!(wynik, model(liczba_klientow, srednia_liczba_szkod, sr_szkoda_ln, std_szkoda_ln, horyzont, nadwyzka, skladka, seed = seed))
    end
    
    return (liczba_ruin = sum(wynik.<=0), p_bankructwa = sum(wynik.<0)/liczba_powtorzen, 
        sredni_wynik = mean(wynik[wynik.>0]),
        mediana_wynik = median(wynik[wynik.>0]),
        q0_05_wynik = quantile(wynik[wynik.>0], 0.05),
        q0_95_wynik = quantile(wynik[wynik.>0], 0.95)
        ) #wazne w pkt 3 zeby pozwolic sie kręcic po 0
end
# Out:
# wywolanie (generic function with 2 methods)

# %%
#sprawdzam wyniki symulacji przy większej licznie powtórzeń symulacji
nadwyzka = 10000.0:10000.0:10000.0
skladka = 500.0:500.0:2000.0
sr_wynik = [] # Średni wynik finansowy firmy
prawd_bankr = []
liczba_ruin = [] 
lower_quants = []
upper_quants = []
medians = []
LICZBA_POWTORZEN = 1.0:50.0:10000.0
nd = nadwyzka[1]
skl = skladka[1]
for lp in LICZBA_POWTORZEN
    wynik = wywolanie(nd, skl, lp, LICZBA_KLIENTOW, srednia_liczba_szkod, SR_SZKODA_LN, STD_SZKODA_LN, HORYZONT)
    push!(liczba_ruin, wynik.liczba_ruin)
    push!(prawd_bankr, wynik.p_bankructwa)
    push!(sr_wynik, wynik.sredni_wynik)
    push!(medians, wynik.mediana_wynik)
    push!(lower_quants, wynik.q0_05_wynik)
    push!(upper_quants, wynik.q0_95_wynik)
    #println("Nadwyzka: ", nd, " Skladka: ", skl, " Liczba ruin: ", wynik.liczba_ruin, " Średni wynik: ",round(wynik.sredni_wynik), " Prawd_bankr: ", wynik.p_bankructwa)
end

# %%
nd
# Out:
# 1000.0

# %%
upper_quants
# Out:
# 200-element Vector{Any}:
#  15567.245154600485
#  26070.26882172049
#  24521.8509903377
#  26328.248709242664
#  27769.9671144579
#  26760.76423080723
#  24891.613597505806
#  24608.353209941135
#  24230.67269318825
#  25433.569922992054
#  24891.613597505802
#  25593.068141430675
#  25525.449551399724
#      ⋮
#  28079.29920861239
#  28065.806657326462
#  28048.240017023447
#  28032.93149940187
#  28025.07489068574
#  28030.31262982983
#  28058.31079550095
#  28047.232939175705
#  28080.79838097748
#  28088.991170910387
#  28073.30251915197
#  28094.566595769564

# %%
# medians = convert(Array{Float64,1}, medians)
# medians = [x::Float64 for x in medians];
# lower_quants = convert(Array{Float64,1}, lower_quants)
# lower_quants = [x::Float64 for x in lower_quants];
# upper_quants = convert(Array{Float64,1}, upper_quants)
# upper_quants = [x::Float64 for x in upper_quants];

# %%
#x_value = reshape(LICZBA_POWTORZEN, length(LICZBA_POWTORZEN), 1)
# Out:
# 10×1 reshape(::StepRange{Int64, Int64}, 10, 1) with eltype Int64:
#   100
#   200
#   300
#   400
#   500
#   600
#   700
#   800
#   900
#  1000

# %%
x_values = LICZBA_POWTORZEN
# Out:
# 1.0:50.0:951.0

# %%
#dla x_values: 1.0:50.0:951.0
using PyPlot

# szacowanie pi dla 1000 symulacji dla k = 1, 2, 3, 4, 5
#ks = [1, 2, 3, 4, 5]
#ls = 1000 .* 10 .^ ks 
#results = [[pi(l) for i in 1:1000] for l in ls]

# wykres percentyli i średniej od liczby symulacji
#medians = [median(result) for result in prawd_bankr]
#lower_quants = [quantile(result, 0.05) for result in prawd_bankr]
#upper_quants = [quantile(result, 0.95) for result in prawd_bankr]

# plot(x_values, upper_quants)
# plot!(x_values,  medians)
# plot!(x_values, lower_quants)
plot(x_values, [upper_quants, medians, sr_wynik, lower_quants], label=["kwantyl 0.95" "srednia" "mediana" "kwantyl 0.05"])
#xlabel("Liczba symulacji")
#ylabel("Szacowanie pi")
#ticklabel_format(axis="x", style="plain", useOffset=false);

# %%
using PyPlot
x_values = LICZBA_POWTORZEN
plot(x_values, [upper_quants, medians, sr_wynik, lower_quants], label=["kwantyl 0.95" "srednia" "mediana" "kwantyl 0.05"])
#xlabel("Liczba symulacji")

# %%
x_values
# Out:
# 1.0:50.0:9951.0

# %%
x = range(0, 10, length=100)
y1 = sin.(x)
y2 = cos.(x)
plot(x, [y1 y2])

# %%
x_values = reshape(LICZBA_POWTORZEN, length(LICZBA_POWTORZEN), 1)
# Out:
# 10×1 reshape(::StepRange{Int64, Int64}, 10, 1) with eltype Int64:
#   100
#   200
#   300
#   400
#   500
#   600
#   700
#   800
#   900
#  1000

# %%
upper_quants
# Out:
# 10-element Vector{Any}:
#  127735.50335127667
#  127442.47481422081
#  127537.95256703455
#  127419.81870385495
#  126972.9319764303
#  127428.15404812963
#  127448.78567791841
#  127468.6735532066
#  127468.6735532066
#  127494.39377321936

# %%
 convert(Array{Float64,1}, upper_quants)
# Out:
# 10-element Vector{Float64}:
#  127735.50335127667
#  127442.47481422081
#  127537.95256703455
#  127419.81870385495
#  126972.9319764303
#  127428.15404812963
#  127448.78567791841
#  127468.6735532066
#  127468.6735532066
#  127494.39377321936

# %%
ks = [1, 2, 3, 4, 5]
ls = 1000 .* 10 .^ ks 

ls
# Out:
# 5-element Vector{Int64}:
#      10000
#     100000
#    1000000
#   10000000
#  100000000

# %%
using Plots

x = 1:10
y = rand(10)

Plots.plot(x, y)
ticklabel_format(:y, :scientific)  # Formatowanie etykiet na osi Y w notacji naukowej
# Out:
# PyError ($(Expr(:escape, :(ccall(#= /Users/aleksandrarozwadowska/.julia/packages/PyCall/twYvK/src/pyfncall.jl:43 =# @pysym(:PyObject_Call), PyPtr, (PyPtr, PyPtr, PyPtr), o, pyargsptr, kw))))) <class 'TypeError'>
# TypeError('ticklabel_format() takes 0 positional arguments but 2 were given')
#
#
# Stacktrace:
#   [1] pyerr_check
#     @ ~/.julia/packages/PyCall/twYvK/src/exception.jl:75 [inlined]
#   [2] pyerr_check
#     @ ~/.julia/packages/PyCall/twYvK/src/exception.jl:79 [inlined]
#   [3] _handle_error(msg::String)
#     @ PyCall ~/.julia/packages/PyCall/twYvK/src/exception.jl:96
#   [4] macro expansion
#     @ ~/.julia/packages/PyCall/twYvK/src/exception.jl:110 [inlined]
#   [5] #107
#     @ ~/.julia/packages/PyCall/twYvK/src/pyfncall.jl:43 [inlined]
#   [6] disable_sigint
#     @ ./c.jl:473 [inlined]
#   [7] __pycall!
#     @ ~/.julia/packages/PyCall/twYvK/src/pyfncall.jl:42 [inlined]
#   [8] _pycall!(ret::PyCall.PyObject, o::PyCall.PyObject, args::Tuple{Symbol, Symbol}, nargs::Int64, kw::Ptr{Nothing})
#     @ PyCall ~/.julia/packages/PyCall/twYvK/src/pyfncall.jl:29
#   [9] _pycall!(ret::PyCall.PyObject, o::PyCall.PyObject, args::Tuple{Symbol, Symbol}, kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ PyCall ~/.julia/packages/PyCall/twYvK/src/pyfncall.jl:11
#  [10] pycall(::PyCall.PyObject, ::Type{PyCall.PyAny}, ::Symbol, ::Vararg{Symbol}; kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ PyCall ~/.julia/packages/PyCall/twYvK/src/pyfncall.jl:83
#  [11] pycall(::PyCall.PyObject, ::Type{PyCall.PyAny}, ::Symbol, ::Vararg{Symbol})
#     @ PyCall ~/.julia/packages/PyCall/twYvK/src/pyfncall.jl:83
#  [12] ticklabel_format(::Symbol, ::Vararg{Symbol}; kws::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ PyPlot ~/.julia/packages/PyPlot/H01LC/src/PyPlot.jl:194
#  [13] ticklabel_format(::Symbol, ::Vararg{Symbol})
#     @ PyPlot ~/.julia/packages/PyPlot/H01LC/src/PyPlot.jl:190
#  [14] top-level scope
#     @ In[80]:7
